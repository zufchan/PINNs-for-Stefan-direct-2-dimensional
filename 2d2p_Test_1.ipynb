# %% [markdown]
# <a href="https://colab.research.google.com/github/zufchan/PINNs-for-Stefan/blob/main/2d2p_Test_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
import timeit


class Sampler:
    # Initialize the class
    def __init__(self, dim, coords, func, name=None):
        self.dim = dim
        self.coords = coords
        self.func = func
        self.name = name

    def sample(self, N):
        x = self.coords[0:1, :] + (self.coords[1:2, :] - self.coords[0:1, :]) * np.random.uniform(0, 1,
                                                                                                  size=(N, self.dim))
        y = self.func(x)
        return x, y


class DataSampler:
    # Initialize the class
    def __init__(self, X, Y, name=None):
        self.X = X
        self.Y = Y
        self.N = self.X.shape[0]

    def sample(self, batch_size):
        idx = np.random.choice(self.N, batch_size, replace=True)
        X_batch = self.X[idx, :]
        Y_batch = self.Y[idx, :]
        return X_batch, Y_batch


class Stefan2D_direct:
    def __init__(self, layers_u, layers_s, ics_sampler, bcs_sampler, res_sampler):
        # Normalization constants
        X, _ = res_sampler.sample(np.int32(1e5))
        self.mu_X, self.sigma_X = X.mean(0), X.std(0)
        self.mu_x, self.sigma_x = self.mu_X[0], self.sigma_X[0]
        self.mu_y, self.sigma_y = self.mu_X[1], self.sigma_X[1]
        self.mu_t, self.sigma_t = self.mu_X[2], self.sigma_X[2]
        
        self.error_s_list = [] 
        self.error_u_list = []
        
        # Samplers
        self.ics_sampler = ics_sampler
        self.bcs_sampler = bcs_sampler
        self.res_sampler = res_sampler

        # Initialize network weights and biases
        with tf.variable_scope('layers'):
          self.layers_u = layers_u

          self.weights_u, self.biases_u = self.initialize_NN(layers_u)
          
          # Initialize encoder weights and biases
          self.layers_s = layers_s
          self.weights_s, self.biases_s = self.initialize_NN(layers_s)

        # Define Tensorflow session
        self.sess = tf.Session(config=tf.ConfigProto(log_device_placement=True))

        with tf.variable_scope('input'):
        # Define placeholders and computational graph
          self.x_u_tf = tf.placeholder(tf.float32, shape=(None, 1))  
          self.y_u_tf = tf.placeholder(tf.float32, shape=(None, 1))  
          self.t_u_tf = tf.placeholder(tf.float32, shape=(None, 1)) 
          self.u_tf = tf.placeholder(tf.float32, shape=(None, 1)) 
          self.s_tf = tf.placeholder(tf.float32, shape=(None, 1))

        #with tf.variable_scope('boundary_conditions_1'):
          self.x_bc1_tf = tf.placeholder(tf.float32, shape=(None, 1))
          self.y_bc1_tf = tf.placeholder(tf.float32, shape=(None, 1))
          self.t_bc1_tf = tf.placeholder(tf.float32, shape=(None, 1))
          self.u_bc1_tf = tf.placeholder(tf.float32, shape=(None, 1))

        #with tf.variable_scope('boundary_conditions_2'):
          self.x_bc2_tf = tf.placeholder(tf.float32, shape=(None, 1))
          self.y_bc2_tf = tf.placeholder(tf.float32, shape=(None, 1))
          self.t_bc2_tf = tf.placeholder(tf.float32, shape=(None, 1))
          self.u_bc2_tf = tf.placeholder(tf.float32, shape=(None, 1))
        
        #with tf.variable_scope('boundary_conditions_3'):
          self.x_bc3_tf = tf.placeholder(tf.float32, shape=(None, 1))
          self.y_bc3_tf = tf.placeholder(tf.float32, shape=(None, 1))
          self.t_bc3_tf = tf.placeholder(tf.float32, shape=(None, 1))
          self.u_bc3_tf = tf.placeholder(tf.float32, shape=(None, 1))

        #with tf.variable_scope('boundary_conditions_4'):
          self.x_bc4_tf = tf.placeholder(tf.float32, shape=(None, 1))
          self.y_bc4_tf = tf.placeholder(tf.float32, shape=(None, 1))
          self.t_bc4_tf = tf.placeholder(tf.float32, shape=(None, 1))
          self.u_bc4_tf = tf.placeholder(tf.float32, shape=(None, 1))

        #with tf.variable_scope('initial_conditions'):
          self.x_ic1_tf = tf.placeholder(tf.float32, shape=(None, 1))
          self.y_ic1_tf = tf.placeholder(tf.float32, shape=(None, 1))
          self.t_ic1_tf = tf.placeholder(tf.float32, shape=(None, 1))
          self.u_ic1_tf = tf.placeholder(tf.float32, shape=(None, 1))  
          self.s_ic1_tf = tf.placeholder(tf.float32, shape=(None, 1))  

        #with tf.variable_scope('initial_conditions'):
          self.x_ic2_tf = tf.placeholder(tf.float32, shape=(None, 1))
          self.y_ic2_tf = tf.placeholder(tf.float32, shape=(None, 1))
          self.t_ic2_tf = tf.placeholder(tf.float32, shape=(None, 1))
          self.u_ic2_tf = tf.placeholder(tf.float32, shape=(None, 1))  
          self.s_ic2_tf = tf.placeholder(tf.float32, shape=(None, 1))  

        #with tf.variable_scope('Normalization_constants'):
          self.y_Nc_tf = tf.placeholder(tf.float32, shape=(None, 1))
          self.t_Nc_tf = tf.placeholder(tf.float32, shape=(None, 1))
          self.u_Nc_tf = tf.placeholder(tf.float32, shape=(None, 1))

        #with tf.variable_scope('residual_conditions'):
          self.x_r_tf = tf.placeholder(tf.float32, shape=(None, 1))
          self.y_r_tf = tf.placeholder(tf.float32, shape=(None, 1))
          self.t_r_tf = tf.placeholder(tf.float32, shape=(None, 1))


        # Evaluate predictions
        self.s_pred = self.net_s(self.y_u_tf, self.t_u_tf)
        self.s_0_pred = self.net_s(self.y_ic1_tf, self.t_ic1_tf)

        # self.u_pred = self.net_u(self.x_u_tf, self.y_u_tf, self.t_u_tf)
        self.u1_pred, self.u2_pred = self.net_u1u2(self.x_u_tf, self.y_u_tf, self.t_u_tf)
        self.u_pred = self.net_u(self.x_u_tf, self.y_u_tf, self.t_u_tf)

        # self.u_0_pred = self.net_u(self.x_0_tf, self.y_0_tf, self.t_0_tf)
        self.u1_0_pred,_ = self.net_u1u2(self.x_ic1_tf, self.y_ic1_tf, self.t_ic1_tf)
        _, self.u2_0_pred = self.net_u1u2(self.x_ic2_tf, self.y_ic2_tf, self.t_ic2_tf)

        #2131231231

        self.u_bc1_pred = self.net_u(self.x_bc1_tf, self.y_bc1_tf, self.t_bc1_tf)
        self.u_bc2_pred,_ = self.net_u1u2(self.x_bc2_tf, self.y_bc2_tf, self.t_bc2_tf)
        self.u_bc3_pred = self.net_u(self.x_bc3_tf, self.y_bc3_tf, self.t_bc3_tf)
        _,self.u_bc4_pred = self.net_u1u2(self.x_bc4_tf, self.y_bc4_tf, self.t_bc4_tf)
        
        self.S_bc1_pred, self.S_bc2_pred = self.net_u1u2((self.s_pred - self.mu_x) / self.sigma_x,
                                    self.y_u_tf,
                                    self.t_u_tf)
        self.r_Nc_pred = self.net_r_Nc(self.y_Nc_tf, self.t_Nc_tf)
        self.r_u1_pred, self.r_u2_pred = self.net_r_u1u2(self.x_r_tf, self.y_r_tf, self.t_r_tf)

        # Stefan Boundary loss
        with tf.variable_scope('loss'):

          #      changed
          self.loss_Sbc1 = tf.reduce_mean(tf.square(self.S_bc1_pred))
          self.loss_Sbc2 = tf.reduce_mean(tf.square(self.S_bc2_pred))

          self.loss_s_0 = tf.reduce_mean(tf.square(self.s_0_pred - (0.5 * (self.y_ic1_tf * self.sigma_y + self.mu_y) + 0.5))) # s(y, 0) = y/2   + 1/2
          self.loss_SNc = tf.reduce_mean(tf.square(self.r_Nc_pred)) 

          # Boundary and Initial loss
          self.loss_u_bc1 = tf.reduce_mean(tf.square(self.u_bc1_pred- self.u_bc1_tf))
          self.loss_u_bc2 = tf.reduce_mean(tf.square(self.u_bc2_pred- self.u_bc2_tf))
          self.loss_u_bc3 = tf.reduce_mean(tf.square(self.u_bc3_pred- self.u_bc3_tf))
          self.loss_u_bc4 = tf.reduce_mean(tf.square(self.u_bc4_pred- self.u_bc4_tf))

          self.loss_u1_ic = tf.reduce_mean(tf.square(self.u1_0_pred - self.u_ic1_tf))
          self.loss_u2_ic = tf.reduce_mean(tf.square(self.u2_0_pred - self.u_ic2_tf))
          self.loss_u_ic = self.loss_u1_ic + self.loss_u2_ic

          self.loss_u_bcs = self.loss_u_bc1 + self.loss_u_bc2 + self.loss_u_bc3 + self.loss_u_bc4
          # Stefan loss
          self.loss_Scs = self.loss_Sbc1 + self.loss_Sbc2 + self.loss_s_0 + self.loss_SNc 


          # Residual loss
          self.loss_res_u1 = tf.reduce_mean(tf.square(self.r_u1_pred))
          self.loss_res_u2 = tf.reduce_mean(tf.square(self.r_u2_pred))  # u_t - u_xx = 0
          self.loss_res = self.loss_res_u1 + self.loss_res_u2

          # Total loss
          self.loss = self.loss_u_bcs + self.loss_u_ic + self.loss_Scs + self.loss_res

        with tf.variable_scope('residual_conditions'):
          tf.summary.scalar('loss', self.loss)
          tf.summary.histogram(name="distribution", values=self.loss)
          tf.summary.scalar('loss_SNc', self.loss_SNc)
          tf.summary.scalar('loss_s_0', self.loss_s_0)
          tf.summary.scalar('loss_u_bcs', self.loss_u_bcs)
          tf.summary.scalar('loss_u_ic', self.loss_u_ic)
          tf.summary.scalar('loss_res', self.loss_res)
          self.summary = tf.summary.merge_all()
        
        # Define optimizer with learning rate schedule
        with tf.variable_scope('train'):
          self.global_step = tf.Variable(0, trainable=False)
          starter_learning_rate = 1e-3
          self.learning_rate = tf.train.exponential_decay(starter_learning_rate, self.global_step,
                                                          1000, 0.9, staircase=False)
        # Passing global_step to minimize() will increment it at each step
          self.train_op = tf.train.AdamOptimizer(self.learning_rate).minimize(self.loss, global_step=self.global_step)

        self.loss_u_bcs_log = []
        self.loss_u_ic_log = []
        self.loss_res_log = []
        self.saver = tf.train.Saver()
        
        # Initialize Tensorflow variables
        init = tf.global_variables_initializer()
        self.sess.run(init)
        self.training_writer = tf.summary.FileWriter('./logs/training', self.sess.graph)
        #self.testing_writer = tf.summary.FileWriter('./logs/testing', self.sess.graph)

     # Xavier initialization
    def xavier_init(self, size):
        in_dim = size[0]
        out_dim = size[1]
        xavier_stddev = 1. / np.sqrt((in_dim + out_dim) / 2.)
        return tf.Variable(tf.random_normal([in_dim, out_dim], dtype=tf.float32) * xavier_stddev,
                           dtype=tf.float32)

    # Initialize network weights and biases using Xavier initialization
    def initialize_NN(self, layers):
        weights = []
        biases = []
        num_layers = len(layers)
        for l in range(0, num_layers - 1):
          
            W = self.xavier_init(size=[layers[l], layers[l + 1]])
            b = tf.Variable(tf.zeros([1, layers[l + 1]], dtype=tf.float32), dtype=tf.float32)
            weights.append(W)
            biases.append(b)
        return weights, biases

    # Evaluates the forward pass
    def forward_pass_u(self, H):
        num_layers = len(self.layers_u)
        for l in range(0, num_layers - 2):
          
            W = self.weights_u[l]
            b = self.biases_u[l]
            H = tf.tanh(tf.add(tf.matmul(H, W), b))
        W = self.weights_u[-1]
        b = self.biases_u[-1]
        H = tf.add(tf.matmul(H, W), b)
        return H
    
    def forward_pass_s(self, H):
        num_layers = len(self.layers_s)
        for l in range(0, num_layers - 2):
         
            W = self.weights_s[l]
            b = self.biases_s[l]
            H = tf.tanh(tf.add(tf.matmul(H, W), b))
        W = self.weights_s[-1]
        b = self.biases_s[-1]
        H = tf.add(tf.matmul(H, W), b)
        return H

     # Forward pass for u
    def net_u1u2(self, x, y, t):
        u = self.forward_pass_u(tf.concat([x, y, t], 1))
        u1 = u[:,0:1]
        u2 = u[:,1:2]
        return u1, u2

     # Forward pass for s
    def net_s(self, y, t):
        s = self.forward_pass_s(tf.concat([y, t], 1))
        return s

    def net_u1u2_x(self, x, y, t):
        u = self.forward_pass_u(tf.concat([x, y, t], 1))

        u1 = u[:,0:1]
        u2 = u[:,1:2]

        u1_x = tf.gradients(u1, x)[0] / self.sigma_x
        u1_y = tf.gradients(u1, y)[0] / self.sigma_y
        u2_x = tf.gradients(u2, x)[0] / self.sigma_x
        u2_y = tf.gradients(u2, y)[0] / self.sigma_y
        return  u1_x, u2_x, u1_y, u2_y

    def net_u(self, x, y, t):
        u1, u2 = self.net_u1u2(x, y, t)
        s = self.net_s(y, t)  # consider normalization

        # demoralizing x coordinates
        x_hat = x * self.sigma_x + self.mu_x
        # consider s = x_hat
        u = tf.multiply(u1, 0.5 * (tf.sign(s - x_hat) + 1)) + tf.multiply(u2, 0.5 * (tf.sign(x_hat - s) + 1))
        return u

    # Forward pass for residual
    def net_r_u1u2(self, x, y, t):
        u1,u2 = self.net_u1u2(x, y, t)
        u1_t = tf.gradients(u1, t)[0] / self.sigma_t

        u1_x = tf.gradients(u1, x)[0] / self.sigma_x
        u1_y = tf.gradients(u1, y)[0] / self.sigma_y

        u1_xx = tf.gradients(u1_x, x)[0] / self.sigma_x
        u1_yy = tf.gradients(u1_y, y)[0] / self.sigma_y
        r_u1 = u1_t - 1 * (u1_xx + u1_yy) #1

        u2_t = tf.gradients(u2, t)[0] / self.sigma_t

        u2_x = tf.gradients(u2, x)[0] / self.sigma_x
        u2_y = tf.gradients(u2, y)[0] / self.sigma_y

        u2_xx = tf.gradients(u2_x, x)[0] / self.sigma_x
        u2_yy = tf.gradients(u2_y, y)[0] / self.sigma_y
        r_u2 = u2_t - 0.5 * (u2_xx + u2_yy) #2

        return r_u1, r_u2

    def net_r_Nc(self, y, t):
        s = self.net_s(y, t)
        s_y = tf.gradients(s, y)[0] / self.sigma_y
        s_t = tf.gradients(s, t)[0] / self.sigma_t

        # Normalizing s
        s = (s - self.mu_x) / self.sigma_x
        u1_x, u2_x, u1_y, u2_y = self.net_u1u2_x(s, y, t) #* self.sigma_y + self.mu_y

        residual = s_t - 7/(2*np.sqrt(5)) * (u1_x - u1_y * s_y) + 3/(np.sqrt(5)) * (u2_x - u2_y * s_y)

        # residual = s_t + 7/(2*np.sqrt(5)) * np.sqrt(5/4) - 3/(np.sqrt(5)) * np.sqrt(5)
        return residual

    def fetch_minibatch(self, sampler, N):
        X, Y = sampler.sample(N)
        X = (X - self.mu_X) / self.sigma_X
        return X, Y

    def train(self, nIter=10000, batch_size=128):
        start_time = timeit.default_timer()

        for it in range(nIter):

            # Fetch boundary and data mini-batches
            X_ic1_batch, u_ic1_batch = self.fetch_minibatch(self.ics_sampler[0], batch_size)
            X_ic2_batch, u_ic2_batch = self.fetch_minibatch(self.ics_sampler[1], batch_size)

            X_bc1_batch, u_bc1_batch = self.fetch_minibatch(self.bcs_sampler[0], batch_size)
            X_bc2_batch, u_bc2_batch = self.fetch_minibatch(self.bcs_sampler[1], batch_size)
            X_bc3_batch, u_bc3_batch = self.fetch_minibatch(self.bcs_sampler[2], batch_size)
            X_bc4_batch, u_bc4_batch = self.fetch_minibatch(self.bcs_sampler[3], batch_size)
            # Fetch residual mini-batch
            X_res_batch, _ = self.fetch_minibatch(self.res_sampler, batch_size)

            # Define a dictionary for associating placeholders with data
            tf_dict = {self.x_u_tf: X_res_batch[:, 0:1], self.y_u_tf: X_res_batch[:, 1:2],
                       self.t_u_tf: X_res_batch[:, 2:3],
                       self.x_ic1_tf: X_ic1_batch[:, 0:1], self.y_ic1_tf: X_ic1_batch[:, 1:2],
                       self.t_ic1_tf: X_ic1_batch[:, 2:3], self.u_ic1_tf: u_ic1_batch,
                       self.x_ic2_tf: X_ic2_batch[:, 0:1], self.y_ic2_tf: X_ic2_batch[:, 1:2],
                       self.t_ic2_tf: X_ic2_batch[:, 2:3], self.u_ic2_tf: u_ic2_batch,
                       self.x_bc1_tf: X_bc1_batch[:, 0:1], self.y_bc1_tf: X_bc1_batch[:, 1:2],
                       self.t_bc1_tf: X_bc1_batch[:, 2:3], self.u_bc1_tf: u_bc1_batch,
                       self.x_bc2_tf: X_bc2_batch[:, 0:1], self.y_bc2_tf: X_bc2_batch[:, 1:2],
                       self.t_bc2_tf: X_bc2_batch[:, 2:3], self.u_bc2_tf: u_bc2_batch,
                       self.x_bc3_tf: X_bc3_batch[:, 0:1], self.y_bc3_tf: X_bc3_batch[:, 1:2],
                       self.t_bc3_tf: X_bc3_batch[:, 2:3], self.u_bc3_tf: u_bc3_batch,
                       self.x_bc4_tf: X_bc4_batch[:, 0:1], self.y_bc4_tf: X_bc4_batch[:, 1:2],
                       self.t_bc4_tf: X_bc4_batch[:, 2:3], self.u_bc4_tf: u_bc4_batch,
                       self.y_Nc_tf: X_res_batch[:, 1:2], self.t_Nc_tf: X_res_batch[:, 2:3],
                       self.x_r_tf: X_res_batch[:, 0:1], self.y_r_tf: X_res_batch[:, 1:2],
                       self.t_r_tf: X_res_batch[:, 2:3]}

            self.sess.run(self.train_op, tf_dict)
            

            # Print
            if it % 10 == 0:
                elapsed = timeit.default_timer() - start_time
                loss_value = self.sess.run(self.loss, tf_dict)
                loss_u_bcs_value, loss_u_ic_value, loss_res_value = self.sess.run(
                    [self.loss_u_bcs, self.loss_u_ic, self.loss_res], tf_dict)
                self.loss_u_bcs_log.append(loss_u_bcs_value)
                self.loss_u_ic_log.append(loss_u_ic_value)
                self.loss_res_log.append(loss_res_value)
                print('It: %d, Loss: %.3e, Loss_bcs: %.3e, Loss_ics: %.3e, Loss_res: %.3e, Time: %.2f' %
                      (it, loss_value, loss_u_bcs_value, loss_u_ic_value, loss_res_value, elapsed))
                start_time = timeit.default_timer()

    # Predictions for u
    def predict_u(self, X_star):
        X_star = (X_star - self.mu_X) / self.sigma_X
        tf_dict = {self.x_u_tf: X_star[:, 0:1], self.y_u_tf: X_star[:, 1:2], self.t_u_tf: X_star[:, 2:3]}
        u_star = self.sess.run(self.u_pred, tf_dict)
        return u_star

    # Predictions for s
    def predict_s(self, X_star):
        X_star = (X_star - self.mu_X[1:3]) / self.sigma_X[1:3]
        tf_dict = {self.y_u_tf: X_star[:, 0:1], self.t_u_tf: X_star[:, 1:2]}
        s_star = self.sess.run(self.s_pred, tf_dict)
        return s_star

# %%
import tensorflow as tf
import numpy as np
from mpl_toolkits import mplot3d
import matplotlib.pyplot as plt
from scipy.interpolate import griddata
import seaborn as sns
import pandas as pd
import os
from google.colab import drive
drive.mount('/content/drive')
import tensorflow.compat.v1 as tf 
tf.disable_v2_behavior()
tf.reset_default_graph()
import gc
import matplotlib

font = {'size' : 15}

matplotlib.rc('font', **font)

if __name__ == '__main__':
    
    # Exact u
    def u1(z):
        # x = (x, y, t)
        x = z[:, 0: 1]
        y = z[:, 1: 2]
        t = z[:, 2: 3]

        u = np.exp(1.25 * t - x + 0.5 * y + 0.5) - 1
        return u

    def u2(z):
        # x = (x, y, t)
        x = z[:, 0: 1]
        y = z[:, 1: 2]
        t = z[:, 2: 3]

        u = np.exp(y + 1 + 2.5 * t - 2 * x) - 1
        return u

        # Exact u
    def u(z):
       return np.where(z[:, 0:1] <= s(z[:, 1:]), u1(z), u2(z))

    # Exact s
    def s(z):
        y = z[:, 0: 1]
        t = z[:, 1: 2]
        # s = 0.5 * y + 1.25 * t + 0.5
        s = 0.5 * y + 1.25 * t + 0.5
        return s
    
    # Initial condition u1(x, y, 0) = exp(-x + y/2 + 1/2) -1
    def f_1(z):
        x = z[:, 0: 1]
        y = z[:, 1: 2]
        f = np.exp(- x + 0.5 * y + 0.5) - 1
        return f

    # Initial condition u2(x, y, 0)
    def f_2(z):
        x = z[:, 0: 1]
        y = z[:, 1: 2]
        f = np.exp(y + 1 - 2 * x) - 1
        return f

    def z(x):
        N = x.shape[0]
        return np.zeros((N, 1))

    # Domain boundaries
    ic_coords = np.array([[0.0, 0.0, 0.0],
                          [3.0, 1.0, 0.0]])
    
    bc1_coords = np.array([[0.0, 0.0, 0.0],
                           [3.0, 0.0, 1.0]]) #both
    
    bc2_coords = np.array([[0.0, 0.0, 0.0],
                           [3.0, 1.0, 1.0]]) #u1
    
    bc3_coords = np.array([[0.0, 1.0, 0.0],
                           [3.0, 1.0, 1.0]]) #both
    
    bc4_coords = np.array([[3.0, 0.0, 0.0],
                           [3.0, 1.0, 1.0]]) #u2
    
    dom_coords = np.array([[0.0, 0.0, 0.0],
                           [3.0, 1.0, 1.0]])

    # Create Initial conditions samplers

    ic1_sampler = Sampler(3, ic_coords, lambda x: f_1(x), name='Initial Condition I')
    ic2_sampler = Sampler(3, ic_coords, lambda x: f_2(x), name='Initial Condition II')
    ics_sampler = [ic1_sampler, ic2_sampler]

    # Create boundary conditions samplers
    bc1_sampler = Sampler(3, bc1_coords, lambda x: u(x), name='Boundary Condition I')
    bc2_sampler = Sampler(3, bc2_coords, lambda x: u(x), name='Boundary Condition II')
    bc3_sampler = Sampler(3, bc3_coords, lambda x: u(x), name='Boundary Condition III')
    bc4_sampler = Sampler(3, bc4_coords, lambda x: u(x), name='Boundary Condition IV')
    bcs_sampler = [bc1_sampler, bc2_sampler, bc3_sampler, bc4_sampler]

    # Create residual sampler
    res_sampler = Sampler(3, dom_coords, lambda x: u(x), name='Forcing')

    # Define model
    layers_u = [3, 100, 100, 100, 2]
    layers_s = [2, 100, 100, 100, 1]  

    model = Stefan2D_direct(layers_u, layers_s, ics_sampler, bcs_sampler, res_sampler)

      # Train the model
    model.train(nIter=40000, batch_size=128)
    
    for N in [200]:

      # Test data
      nn = N
      y = np.linspace(dom_coords[0, 1], dom_coords[1, 1], nn)[:, None]
      t = np.linspace(dom_coords[0, 2], dom_coords[1, 2], nn)[:, None]
      y, t = np.meshgrid(y, t)
      
      X_star = np.hstack((y.flatten()[:, None], t.flatten()[:, None]))
      
      s_star = s(X_star)

      # Predictions
      s_pred = model.predict_s(X_star)
      
      error_s = np.linalg.norm(s_star - s_pred, 2) / np.linalg.norm(s_star, 2)
      print('The relative errror is: {:4e}'.format(error_s))
      if not os.path.exists('/content/drive/My Drive/Diploma/2d2p_test1/'):
        os.mkdir('/content/drive/My Drive/Diploma/2d2p_test1/')

      # Plot for s
      nn = N
      y = np.linspace(dom_coords[0, 1], dom_coords[1, 1], nn)[:, None]
      t = np.linspace(dom_coords[0, 2], dom_coords[1, 2], nn)[:, None]
      y, t = np.meshgrid(y, t)

      X_star = np.hstack((y.flatten()[:, None], t.flatten()[:, None]))
      
      s_star = s(X_star)
      s_pred = model.predict_s(X_star)
      
      S_pred = griddata(X_star, s_pred.flatten(), (y, t), method='cubic')
      S_star = griddata(X_star, s_star.flatten(), (y, t), method='cubic')
          
      fig_1 = plt.figure(5, figsize=(18, 5))
      ax = fig_1.add_subplot(1, 3, 1, projection='3d')
      ax.plot_surface(y, t, S_star)
      ax.set_xlabel('y')
      ax.set_ylabel('t')
      ax.set_zlabel('s(y,t)')
      ax.set_title('Exact')
      
      ax = fig_1.add_subplot(1, 3, 2, projection='3d')
      ax.plot_surface(y, t, S_pred)
      ax.set_xlabel('y')
      ax.set_ylabel('t')
      ax.set_zlabel('s(y,t)')
      ax.set_title('Predicted')
      
      ax = fig_1.add_subplot(1, 3, 3, projection='3d')
      ax.plot_surface(y, t, np.abs(S_star - S_pred))
      ax.set_xlabel('y')
      ax.set_ylabel('t')
      ax.set_zlabel('s(y,t)')
      ax.set_title('Absolute Error')
      
      plt.tight_layout()
      with open('/content/drive/My Drive/Diploma/2d2p_test1/Plot_for_S.pdf', 'w') as f:
            pass
      plt.savefig('/content/drive/My Drive/Diploma/2d2p_test1/Plot_for_S.pdf')
      # plt.clf()

      # Plot for u
      T_list = [0.2, 0.4, 0.6, 0.8]
      nn = N
      x = np.linspace(0, 3.0, nn)[:, None]
      y = np.linspace(dom_coords[0, 1], dom_coords[1, 1], nn)[:, None]
      t = np.linspace(dom_coords[0, 2], dom_coords[1, 2], nn)[:, None]
      
      for T in T_list:
          X, Y = np.meshgrid(x, y)
          T_star = T * np.ones_like(X)
          X_star = np.hstack((X.flatten()[:, None], Y.flatten()[:, None], T_star.flatten()[:, None]))
          
          u_star = u(X_star)
          u_pred = model.predict_u(X_star)
          
          X_star = np.hstack((X.flatten()[:, None], Y.flatten()[:, None]))
          
          U_star = griddata(X_star, u_star.flatten(), (X, Y), method='cubic')
          U_pred = griddata(X_star, u_pred.flatten(), (X, Y), method='cubic')
      
          np.savetxt('pred_{}'.format(str(T)), U_pred, delimiter=',')
          np.savetxt('exact_{}'.format(str(T)), U_star, delimiter=',')
          
      
      for T in T_list:
          U_pred = np.loadtxt('pred_{}'.format(str(T)), delimiter=',')
          U_star = np.loadtxt('exact_{}'.format(str(T)), delimiter=',')

          y = np.linspace(dom_coords[0, 1], dom_coords[1, 1], nn)[:, None]
          t = T * np.ones_like(y)
          y, t = np.meshgrid(y, t)

          X_star = np.hstack((y.flatten()[:, None], t.flatten()[:, None]))
          
          s_star = s(X_star)
          s_pred = model.predict_s(X_star)
          
          fig = plt.figure(figsize=(18, 5))
          plt.subplot(1, 3, 1)
          plt.pcolor(X, Y, U_star, cmap='jet')
          plt.plot(s_star, y.flatten(), color='black', linewidth=2)
          plt.colorbar()
          plt.xlabel(r'$x$')
          plt.ylabel(r'$y$')
          plt.title('Exact $u(x, y, {})$'.format(T))
          
          plt.subplot(1, 3, 2)
          plt.pcolor(X, Y, U_pred, cmap='jet')
          plt.plot(s_star, y.flatten(), color='black', linewidth=2)
          plt.colorbar()
          plt.xlabel(r'$x$')
          plt.ylabel(r'$y$')
          plt.title('Predicted  $u(x, y, {})$'.format(T))
      
          plt.subplot(1, 3, 3)
          plt.pcolor(X, Y, np.abs(U_star - U_pred), cmap='jet')
          plt.colorbar(format='%.0e')
          plt.xlabel(r'$x$')
          plt.ylabel(r'$y$')
          plt.title('Absolute Error')
          
          plt.tight_layout()
          with open('/content/drive/My Drive/Diploma/2d2p_test1/Plot_for_U[T={}].pdf'.format(T), 'w') as f:
            pass
          plt.savefig('/content/drive/My Drive/Diploma/2d2p_test1/Plot_for_U[T={}].pdf'.format(T))
# Out:
# Mounted at /content/drive
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
#
# It: 0, Loss: 1.023e+01, Loss_bcs: 6.947e+00, Loss_ics: 1.894e+00, Loss_res: 1.374e-01, Time: 4.19
# It: 10, Loss: 4.623e+00, Loss_bcs: 2.331e+00, Loss_ics: 5.371e-01, Loss_res: 4.338e-01, Time: 0.25
# It: 20, Loss: 4.750e+00, Loss_bcs: 3.392e+00, Loss_ics: 6.491e-01, Loss_res: 2.267e-01, Time: 0.24
# It: 30, Loss: 3.632e+00, Loss_bcs: 2.277e+00, Loss_ics: 6.305e-01, Loss_res: 3.476e-01, Time: 0.24
# It: 40, Loss: 3.190e+00, Loss_bcs: 1.852e+00, Loss_ics: 5.603e-01, Loss_res: 2.623e-01, Time: 0.24
# It: 50, Loss: 2.797e+00, Loss_bcs: 1.700e+00, Loss_ics: 5.388e-01, Loss_res: 2.519e-01, Time: 0.24
# It: 60, Loss: 2.372e+00, Loss_bcs: 1.297e+00, Loss_ics: 5.879e-01, Loss_res: 1.755e-01, Time: 0.26
# It: 70, Loss: 3.008e+00, Loss_bcs: 1.913e+00, Loss_ics: 6.030e-01, Loss_res: 2.167e-01, Time: 0.26
# It: 80, Loss: 2.566e+00, Loss_bcs: 1.565e+00, Loss_ics: 5.322e-01, Loss_res: 2.380e-01, Time: 0.24
# It: 90, Loss: 2.457e+00, Loss_bcs: 1.336e+00, Loss_ics: 6.119e-01, Loss_res: 2.621e-01, Time: 0.24
# It: 100, Loss: 2.790e+00, Loss_bcs: 1.492e+00, Loss_ics: 7.758e-01, Loss_res: 3.041e-01, Time: 0.24
# It: 110, Loss: 1.578e+00, Loss_bcs: 6.653e-01, Loss_ics: 4.205e-01, Loss_res: 2.636e-01, Time: 0.26
# It: 120, Loss: 2.562e+00, Loss_bcs: 1.559e+00, Loss_ics: 5.218e-01, Loss_res: 3.017e-01, Time: 0.24
# It: 130, Loss: 2.472e+00, Loss_bcs: 1.520e+00, Loss_ics: 5.236e-01, Loss_res: 2.809e-01, Time: 0.24
# It: 140, Loss: 1.829e+00, Loss_bcs: 6.988e-01, Loss_ics: 6.292e-01, Loss_res: 3.432e-01, Time: 0.24
# It: 150, Loss: 1.467e+00, Loss_bcs: 7.057e-01, Loss_ics: 3.100e-01, Loss_res: 3.055e-01, Time: 0.25
# It: 160, Loss: 1.550e+00, Loss_bcs: 6.425e-01, Loss_ics: 5.074e-01, Loss_res: 2.946e-01, Time: 0.25
# It: 170, Loss: 1.697e+00, Loss_bcs: 1.125e+00, Loss_ics: 1.942e-01, Loss_res: 2.566e-01, Time: 0.24
# It: 180, Loss: 1.207e+00, Loss_bcs: 5.856e-01, Loss_ics: 2.453e-01, Loss_res: 2.579e-01, Time: 0.24
# It: 190, Loss: 1.288e+00, Loss_bcs: 5.301e-01, Loss_ics: 4.126e-01, Loss_res: 2.169e-01, Time: 0.33
# It: 200, Loss: 8.234e-01, Loss_bcs: 3.696e-01, Loss_ics: 1.602e-01, Loss_res: 1.947e-01, Time: 0.55
# It: 210, Loss: 7.518e-01, Loss_bcs: 3.232e-01, Loss_ics: 1.387e-01, Loss_res: 1.935e-01, Time: 0.28
# It: 220, Loss: 8.732e-01, Loss_bcs: 3.364e-01, Loss_ics: 3.066e-01, Loss_res: 1.349e-01, Time: 0.24
# It: 230, Loss: 7.986e-01, Loss_bcs: 3.083e-01, Loss_ics: 2.489e-01, Loss_res: 1.373e-01, Time: 0.45
# It: 240, Loss: 6.279e-01, Loss_bcs: 2.563e-01, Loss_ics: 1.564e-01, Loss_res: 1.300e-01, Time: 0.43
# It: 250, Loss: 5.322e-01, Loss_bcs: 1.352e-01, Loss_ics: 2.143e-01, Loss_res: 1.076e-01, Time: 0.24
# It: 260, Loss: 4.890e-01, Loss_bcs: 2.229e-01, Loss_ics: 6.283e-02, Loss_res: 1.143e-01, Time: 0.37
# It: 270, Loss: 4.440e-01, Loss_bcs: 1.813e-01, Loss_ics: 1.293e-01, Loss_res: 5.922e-02, Time: 0.49
# It: 280, Loss: 3.856e-01, Loss_bcs: 1.343e-01, Loss_ics: 1.047e-01, Loss_res: 6.414e-02, Time: 0.27
# It: 290, Loss: 4.567e-01, Loss_bcs: 1.533e-01, Loss_ics: 1.241e-01, Loss_res: 1.019e-01, Time: 0.25
# It: 300, Loss: 2.776e-01, Loss_bcs: 9.901e-02, Loss_ics: 6.651e-02, Loss_res: 5.455e-02, Time: 0.25
# It: 310, Loss: 3.222e-01, Loss_bcs: 1.079e-01, Loss_ics: 6.754e-02, Loss_res: 5.901e-02, Time: 0.25
# It: 320, Loss: 3.288e-01, Loss_bcs: 1.405e-01, Loss_ics: 8.851e-02, Loss_res: 3.087e-02, Time: 0.24
# It: 330, Loss: 2.429e-01, Loss_bcs: 1.007e-01, Loss_ics: 5.840e-02, Loss_res: 3.109e-02, Time: 0.24
# It: 340, Loss: 2.036e-01, Loss_bcs: 5.735e-02, Loss_ics: 4.556e-02, Loss_res: 4.400e-02, Time: 0.25
# It: 350, Loss: 2.121e-01, Loss_bcs: 7.118e-02, Loss_ics: 5.014e-02, Loss_res: 3.755e-02, Time: 0.24
# It: 360, Loss: 1.947e-01, Loss_bcs: 6.128e-02, Loss_ics: 4.722e-02, Loss_res: 3.868e-02, Time: 0.25
# It: 370, Loss: 1.891e-01, Loss_bcs: 4.844e-02, Loss_ics: 4.593e-02, Loss_res: 4.922e-02, Time: 0.25
# It: 380, Loss: 1.914e-01, Loss_bcs: 5.887e-02, Loss_ics: 4.466e-02, Loss_res: 2.740e-02, Time: 0.25
# It: 390, Loss: 1.878e-01, Loss_bcs: 3.984e-02, Loss_ics: 3.441e-02, Loss_res: 6.431e-02, Time: 0.24
# It: 400, Loss: 1.767e-01, Loss_bcs: 4.713e-02, Loss_ics: 3.295e-02, Loss_res: 6.041e-02, Time: 0.25
# It: 410, Loss: 1.420e-01, Loss_bcs: 5.642e-02, Loss_ics: 1.766e-02, Loss_res: 2.775e-02, Time: 0.25
# It: 420, Loss: 2.027e-01, Loss_bcs: 7.385e-02, Loss_ics: 7.523e-02, Loss_res: 1.519e-02, Time: 0.24
# It: 430, Loss: 1.619e-01, Loss_bcs: 4.101e-02, Loss_ics: 1.999e-02, Loss_res: 6.380e-02, Time: 0.23
# It: 440, Loss: 1.667e-01, Loss_bcs: 5.244e-02, Loss_ics: 4.586e-02, Loss_res: 3.136e-02, Time: 0.25
# It: 450, Loss: 1.976e-01, Loss_bcs: 8.354e-02, Loss_ics: 4.271e-02, Loss_res: 3.093e-02, Time: 0.24
# It: 460, Loss: 1.229e-01, Loss_bcs: 4.551e-02, Loss_ics: 2.800e-02, Loss_res: 2.134e-02, Time: 0.25
# It: 470, Loss: 1.422e-01, Loss_bcs: 4.454e-02, Loss_ics: 4.660e-02, Loss_res: 1.695e-02, Time: 0.26
# It: 480, Loss: 1.157e-01, Loss_bcs: 5.101e-02, Loss_ics: 1.035e-02, Loss_res: 2.472e-02, Time: 0.23
# It: 490, Loss: 1.446e-01, Loss_bcs: 4.400e-02, Loss_ics: 4.154e-02, Loss_res: 2.867e-02, Time: 0.24
# It: 500, Loss: 1.158e-01, Loss_bcs: 2.899e-02, Loss_ics: 2.580e-02, Loss_res: 3.198e-02, Time: 0.24
# It: 510, Loss: 8.859e-02, Loss_bcs: 3.545e-02, Loss_ics: 7.568e-03, Loss_res: 1.976e-02, Time: 0.24
# It: 520, Loss: 1.004e-01, Loss_bcs: 3.754e-02, Loss_ics: 2.013e-02, Loss_res: 1.589e-02, Time: 0.25
# It: 530, Loss: 8.360e-02, Loss_bcs: 2.387e-02, Loss_ics: 2.248e-02, Loss_res: 1.497e-02, Time: 0.24
# It: 540, Loss: 8.463e-02, Loss_bcs: 2.922e-02, Loss_ics: 1.309e-02, Loss_res: 1.464e-02, Time: 0.24
# It: 550, Loss: 8.171e-02, Loss_bcs: 2.655e-02, Loss_ics: 2.034e-02, Loss_res: 1.345e-02, Time: 0.24
# It: 560, Loss: 1.071e-01, Loss_bcs: 3.606e-02, Loss_ics: 4.015e-02, Loss_res: 9.814e-03, Time: 0.23
# It: 570, Loss: 8.500e-02, Loss_bcs: 4.008e-02, Loss_ics: 1.171e-02, Loss_res: 1.178e-02, Time: 0.24
# It: 580, Loss: 9.494e-02, Loss_bcs: 3.797e-02, Loss_ics: 1.883e-02, Loss_res: 1.803e-02, Time: 0.25
# It: 590, Loss: 8.471e-02, Loss_bcs: 3.164e-02, Loss_ics: 1.834e-02, Loss_res: 9.605e-03, Time: 0.23
# It: 600, Loss: 9.328e-02, Loss_bcs: 2.933e-02, Loss_ics: 2.126e-02, Loss_res: 2.401e-02, Time: 0.24
# It: 610, Loss: 9.471e-02, Loss_bcs: 2.870e-02, Loss_ics: 1.085e-02, Loss_res: 2.987e-02, Time: 0.25
# It: 620, Loss: 6.926e-02, Loss_bcs: 2.362e-02, Loss_ics: 9.402e-03, Loss_res: 1.166e-02, Time: 0.23
# It: 630, Loss: 8.787e-02, Loss_bcs: 2.972e-02, Loss_ics: 2.035e-02, Loss_res: 1.826e-02, Time: 0.24
# It: 640, Loss: 7.590e-02, Loss_bcs: 2.647e-02, Loss_ics: 1.054e-02, Loss_res: 1.702e-02, Time: 0.23
# It: 650, Loss: 7.836e-02, Loss_bcs: 2.172e-02, Loss_ics: 6.729e-03, Loss_res: 2.027e-02, Time: 0.25
# It: 660, Loss: 5.754e-02, Loss_bcs: 2.298e-02, Loss_ics: 7.818e-03, Loss_res: 1.132e-02, Time: 0.25
# It: 670, Loss: 5.698e-02, Loss_bcs: 2.569e-02, Loss_ics: 8.635e-03, Loss_res: 7.150e-03, Time: 0.25
# It: 680, Loss: 6.049e-02, Loss_bcs: 2.409e-02, Loss_ics: 1.150e-02, Loss_res: 1.070e-02, Time: 0.23
# It: 690, Loss: 7.396e-02, Loss_bcs: 2.921e-02, Loss_ics: 1.596e-02, Loss_res: 1.033e-02, Time: 0.25
# It: 700, Loss: 5.819e-02, Loss_bcs: 1.930e-02, Loss_ics: 6.104e-03, Loss_res: 1.445e-02, Time: 0.24
# It: 710, Loss: 5.689e-02, Loss_bcs: 2.256e-02, Loss_ics: 6.843e-03, Loss_res: 1.206e-02, Time: 0.24
# It: 720, Loss: 5.500e-02, Loss_bcs: 2.008e-02, Loss_ics: 7.332e-03, Loss_res: 1.205e-02, Time: 0.23
# It: 730, Loss: 7.657e-02, Loss_bcs: 3.010e-02, Loss_ics: 1.030e-02, Loss_res: 1.461e-02, Time: 0.25
# It: 740, Loss: 7.680e-02, Loss_bcs: 3.331e-02, Loss_ics: 5.479e-03, Loss_res: 1.772e-02, Time: 0.24
# It: 750, Loss: 5.534e-02, Loss_bcs: 2.566e-02, Loss_ics: 2.957e-03, Loss_res: 1.457e-02, Time: 0.26
# It: 760, Loss: 5.692e-02, Loss_bcs: 2.388e-02, Loss_ics: 6.158e-03, Loss_res: 1.186e-02, Time: 0.23
# It: 770, Loss: 6.640e-02, Loss_bcs: 3.070e-02, Loss_ics: 3.587e-03, Loss_res: 1.140e-02, Time: 0.25
# It: 780, Loss: 4.645e-02, Loss_bcs: 1.919e-02, Loss_ics: 5.584e-03, Loss_res: 9.486e-03, Time: 0.24
# It: 790, Loss: 6.091e-02, Loss_bcs: 2.419e-02, Loss_ics: 7.136e-03, Loss_res: 7.771e-03, Time: 0.24
# It: 800, Loss: 5.521e-02, Loss_bcs: 2.185e-02, Loss_ics: 6.694e-03, Loss_res: 5.674e-03, Time: 0.24
# It: 810, Loss: 4.865e-02, Loss_bcs: 2.078e-02, Loss_ics: 4.880e-03, Loss_res: 9.674e-03, Time: 0.26
# It: 820, Loss: 6.900e-02, Loss_bcs: 2.207e-02, Loss_ics: 1.135e-02, Loss_res: 2.194e-02, Time: 0.24
# It: 830, Loss: 5.519e-02, Loss_bcs: 2.718e-02, Loss_ics: 5.219e-03, Loss_res: 1.127e-02, Time: 0.24
# It: 840, Loss: 6.090e-02, Loss_bcs: 3.042e-02, Loss_ics: 5.898e-03, Loss_res: 9.724e-03, Time: 0.24
# It: 850, Loss: 7.331e-02, Loss_bcs: 3.791e-02, Loss_ics: 1.266e-02, Loss_res: 1.005e-02, Time: 0.25
# It: 860, Loss: 7.305e-02, Loss_bcs: 2.534e-02, Loss_ics: 1.023e-02, Loss_res: 1.828e-02, Time: 0.26
# It: 870, Loss: 5.697e-02, Loss_bcs: 2.235e-02, Loss_ics: 5.518e-03, Loss_res: 1.402e-02, Time: 0.23
# It: 880, Loss: 5.203e-02, Loss_bcs: 1.982e-02, Loss_ics: 7.474e-03, Loss_res: 7.134e-03, Time: 0.24
# It: 890, Loss: 4.836e-02, Loss_bcs: 1.981e-02, Loss_ics: 5.040e-03, Loss_res: 6.895e-03, Time: 0.25
# It: 900, Loss: 5.304e-02, Loss_bcs: 1.872e-02, Loss_ics: 8.047e-03, Loss_res: 8.610e-03, Time: 0.24
# It: 910, Loss: 4.076e-02, Loss_bcs: 1.925e-02, Loss_ics: 4.028e-03, Loss_res: 7.164e-03, Time: 0.25
# It: 920, Loss: 4.570e-02, Loss_bcs: 1.856e-02, Loss_ics: 5.306e-03, Loss_res: 1.285e-02, Time: 0.24
# It: 930, Loss: 4.938e-02, Loss_bcs: 1.699e-02, Loss_ics: 4.381e-03, Loss_res: 1.164e-02, Time: 0.25
# It: 940, Loss: 4.700e-02, Loss_bcs: 1.481e-02, Loss_ics: 7.053e-03, Loss_res: 1.050e-02, Time: 0.24
# It: 950, Loss: 5.106e-02, Loss_bcs: 2.263e-02, Loss_ics: 4.916e-03, Loss_res: 9.774e-03, Time: 0.25
# It: 960, Loss: 5.168e-02, Loss_bcs: 2.114e-02, Loss_ics: 6.313e-03, Loss_res: 7.710e-03, Time: 0.25
# It: 970, Loss: 4.360e-02, Loss_bcs: 2.148e-02, Loss_ics: 4.184e-03, Loss_res: 6.873e-03, Time: 0.25
# It: 980, Loss: 4.084e-02, Loss_bcs: 1.821e-02, Loss_ics: 2.771e-03, Loss_res: 9.104e-03, Time: 0.25
# It: 990, Loss: 4.469e-02, Loss_bcs: 1.836e-02, Loss_ics: 4.402e-03, Loss_res: 8.785e-03, Time: 0.25
# It: 1000, Loss: 5.378e-02, Loss_bcs: 2.577e-02, Loss_ics: 6.935e-03, Loss_res: 1.218e-02, Time: 0.26
# It: 1010, Loss: 7.667e-02, Loss_bcs: 3.118e-02, Loss_ics: 7.976e-03, Loss_res: 1.557e-02, Time: 0.26
# It: 1020, Loss: 5.113e-02, Loss_bcs: 1.780e-02, Loss_ics: 6.111e-03, Loss_res: 8.886e-03, Time: 0.24
# It: 1030, Loss: 6.065e-02, Loss_bcs: 2.350e-02, Loss_ics: 5.091e-03, Loss_res: 1.387e-02, Time: 0.26
# It: 1040, Loss: 3.638e-02, Loss_bcs: 1.502e-02, Loss_ics: 3.012e-03, Loss_res: 6.958e-03, Time: 0.26
# It: 1050, Loss: 4.332e-02, Loss_bcs: 2.175e-02, Loss_ics: 3.128e-03, Loss_res: 6.932e-03, Time: 0.25
# It: 1060, Loss: 4.384e-02, Loss_bcs: 2.000e-02, Loss_ics: 4.276e-03, Loss_res: 8.546e-03, Time: 0.24
# It: 1070, Loss: 4.036e-02, Loss_bcs: 1.646e-02, Loss_ics: 5.078e-03, Loss_res: 7.366e-03, Time: 0.24
# It: 1080, Loss: 3.972e-02, Loss_bcs: 1.949e-02, Loss_ics: 3.787e-03, Loss_res: 6.019e-03, Time: 0.25
# It: 1090, Loss: 3.851e-02, Loss_bcs: 1.922e-02, Loss_ics: 2.692e-03, Loss_res: 6.742e-03, Time: 0.25
# It: 1100, Loss: 3.823e-02, Loss_bcs: 1.818e-02, Loss_ics: 2.507e-03, Loss_res: 6.659e-03, Time: 0.26
# It: 1110, Loss: 3.939e-02, Loss_bcs: 1.663e-02, Loss_ics: 2.830e-03, Loss_res: 8.318e-03, Time: 0.26
# It: 1120, Loss: 3.736e-02, Loss_bcs: 1.694e-02, Loss_ics: 4.231e-03, Loss_res: 7.550e-03, Time: 0.24
# It: 1130, Loss: 3.964e-02, Loss_bcs: 1.973e-02, Loss_ics: 3.373e-03, Loss_res: 4.878e-03, Time: 0.24
# It: 1140, Loss: 3.925e-02, Loss_bcs: 1.638e-02, Loss_ics: 5.521e-03, Loss_res: 5.812e-03, Time: 0.23
# It: 1150, Loss: 4.069e-02, Loss_bcs: 1.934e-02, Loss_ics: 2.945e-03, Loss_res: 5.881e-03, Time: 0.24
# It: 1160, Loss: 5.284e-02, Loss_bcs: 1.909e-02, Loss_ics: 4.126e-03, Loss_res: 2.149e-02, Time: 0.24
# It: 1170, Loss: 4.657e-02, Loss_bcs: 1.688e-02, Loss_ics: 8.743e-03, Loss_res: 9.737e-03, Time: 0.24
# It: 1180, Loss: 4.204e-02, Loss_bcs: 2.296e-02, Loss_ics: 3.305e-03, Loss_res: 6.293e-03, Time: 0.24
# It: 1190, Loss: 4.457e-02, Loss_bcs: 1.812e-02, Loss_ics: 3.581e-03, Loss_res: 1.197e-02, Time: 0.24
# It: 1200, Loss: 4.392e-02, Loss_bcs: 1.610e-02, Loss_ics: 4.718e-03, Loss_res: 1.320e-02, Time: 0.24
# It: 1210, Loss: 4.306e-02, Loss_bcs: 2.115e-02, Loss_ics: 3.067e-03, Loss_res: 6.853e-03, Time: 0.26
# It: 1220, Loss: 4.196e-02, Loss_bcs: 1.756e-02, Loss_ics: 3.599e-03, Loss_res: 6.735e-03, Time: 0.25
# It: 1230, Loss: 3.754e-02, Loss_bcs: 1.666e-02, Loss_ics: 3.371e-03, Loss_res: 5.716e-03, Time: 0.24
# It: 1240, Loss: 3.770e-02, Loss_bcs: 1.665e-02, Loss_ics: 3.317e-03, Loss_res: 4.730e-03, Time: 0.25
# It: 1250, Loss: 3.449e-02, Loss_bcs: 1.671e-02, Loss_ics: 2.912e-03, Loss_res: 5.032e-03, Time: 0.25
# It: 1260, Loss: 3.115e-02, Loss_bcs: 1.556e-02, Loss_ics: 2.356e-03, Loss_res: 4.694e-03, Time: 0.25
# It: 1270, Loss: 3.886e-02, Loss_bcs: 1.832e-02, Loss_ics: 3.373e-03, Loss_res: 8.045e-03, Time: 0.23
# It: 1280, Loss: 3.261e-02, Loss_bcs: 1.572e-02, Loss_ics: 3.237e-03, Loss_res: 6.851e-03, Time: 0.25
# It: 1290, Loss: 3.487e-02, Loss_bcs: 1.871e-02, Loss_ics: 2.765e-03, Loss_res: 4.513e-03, Time: 0.25
# It: 1300, Loss: 3.752e-02, Loss_bcs: 1.818e-02, Loss_ics: 2.548e-03, Loss_res: 8.861e-03, Time: 0.25
# It: 1310, Loss: 3.844e-02, Loss_bcs: 1.879e-02, Loss_ics: 3.077e-03, Loss_res: 5.782e-03, Time: 0.24
# It: 1320, Loss: 4.412e-02, Loss_bcs: 1.868e-02, Loss_ics: 3.284e-03, Loss_res: 7.492e-03, Time: 0.25
# It: 1330, Loss: 4.065e-02, Loss_bcs: 1.736e-02, Loss_ics: 6.276e-03, Loss_res: 6.047e-03, Time: 0.23
# It: 1340, Loss: 3.677e-02, Loss_bcs: 1.502e-02, Loss_ics: 7.057e-03, Loss_res: 4.344e-03, Time: 0.25
# It: 1350, Loss: 4.019e-02, Loss_bcs: 1.793e-02, Loss_ics: 5.115e-03, Loss_res: 5.672e-03, Time: 0.24
# It: 1360, Loss: 3.715e-02, Loss_bcs: 1.890e-02, Loss_ics: 1.869e-03, Loss_res: 5.354e-03, Time: 0.24
# It: 1370, Loss: 3.466e-02, Loss_bcs: 1.483e-02, Loss_ics: 3.330e-03, Loss_res: 6.823e-03, Time: 0.25
# It: 1380, Loss: 3.008e-02, Loss_bcs: 1.407e-02, Loss_ics: 2.262e-03, Loss_res: 6.208e-03, Time: 0.24
# It: 1390, Loss: 3.743e-02, Loss_bcs: 1.429e-02, Loss_ics: 3.208e-03, Loss_res: 1.108e-02, Time: 0.24
# It: 1400, Loss: 3.251e-02, Loss_bcs: 1.729e-02, Loss_ics: 2.762e-03, Loss_res: 5.376e-03, Time: 0.24
# It: 1410, Loss: 3.063e-02, Loss_bcs: 1.604e-02, Loss_ics: 3.557e-03, Loss_res: 4.679e-03, Time: 0.25
# It: 1420, Loss: 2.793e-02, Loss_bcs: 1.488e-02, Loss_ics: 2.387e-03, Loss_res: 4.600e-03, Time: 0.25
# It: 1430, Loss: 3.238e-02, Loss_bcs: 1.381e-02, Loss_ics: 2.943e-03, Loss_res: 7.261e-03, Time: 0.24
# It: 1440, Loss: 3.134e-02, Loss_bcs: 1.331e-02, Loss_ics: 2.922e-03, Loss_res: 6.171e-03, Time: 0.24
# It: 1450, Loss: 3.467e-02, Loss_bcs: 1.569e-02, Loss_ics: 2.636e-03, Loss_res: 9.008e-03, Time: 0.24
# It: 1460, Loss: 3.143e-02, Loss_bcs: 1.548e-02, Loss_ics: 2.787e-03, Loss_res: 4.078e-03, Time: 0.26
# It: 1470, Loss: 3.132e-02, Loss_bcs: 1.533e-02, Loss_ics: 2.443e-03, Loss_res: 5.200e-03, Time: 0.24
# It: 1480, Loss: 3.583e-02, Loss_bcs: 1.501e-02, Loss_ics: 3.212e-03, Loss_res: 5.170e-03, Time: 0.25
# It: 1490, Loss: 3.034e-02, Loss_bcs: 1.422e-02, Loss_ics: 3.314e-03, Loss_res: 4.380e-03, Time: 0.25
# It: 1500, Loss: 3.935e-02, Loss_bcs: 1.783e-02, Loss_ics: 2.538e-03, Loss_res: 7.734e-03, Time: 0.25
# It: 1510, Loss: 6.115e-02, Loss_bcs: 1.680e-02, Loss_ics: 1.278e-02, Loss_res: 1.714e-02, Time: 0.23
# It: 1520, Loss: 4.200e-02, Loss_bcs: 1.405e-02, Loss_ics: 4.907e-03, Loss_res: 8.335e-03, Time: 0.24
# It: 1530, Loss: 3.470e-02, Loss_bcs: 1.514e-02, Loss_ics: 2.593e-03, Loss_res: 5.453e-03, Time: 0.24
# It: 1540, Loss: 3.552e-02, Loss_bcs: 1.647e-02, Loss_ics: 2.785e-03, Loss_res: 8.205e-03, Time: 0.24
# It: 1550, Loss: 3.029e-02, Loss_bcs: 1.513e-02, Loss_ics: 3.068e-03, Loss_res: 4.787e-03, Time: 0.24
# It: 1560, Loss: 3.179e-02, Loss_bcs: 1.347e-02, Loss_ics: 2.321e-03, Loss_res: 4.096e-03, Time: 0.25
# It: 1570, Loss: 2.771e-02, Loss_bcs: 1.315e-02, Loss_ics: 1.687e-03, Loss_res: 3.608e-03, Time: 0.23
# It: 1580, Loss: 3.387e-02, Loss_bcs: 1.706e-02, Loss_ics: 2.360e-03, Loss_res: 4.533e-03, Time: 0.24
# It: 1590, Loss: 3.826e-02, Loss_bcs: 1.296e-02, Loss_ics: 2.043e-03, Loss_res: 1.650e-02, Time: 0.24
# It: 1600, Loss: 2.800e-02, Loss_bcs: 1.153e-02, Loss_ics: 3.363e-03, Loss_res: 5.210e-03, Time: 0.25
# It: 1610, Loss: 3.249e-02, Loss_bcs: 1.556e-02, Loss_ics: 2.975e-03, Loss_res: 5.214e-03, Time: 0.26
# It: 1620, Loss: 2.977e-02, Loss_bcs: 1.413e-02, Loss_ics: 4.295e-03, Loss_res: 3.314e-03, Time: 0.25
# It: 1630, Loss: 2.964e-02, Loss_bcs: 1.184e-02, Loss_ics: 3.331e-03, Loss_res: 5.087e-03, Time: 0.25
# It: 1640, Loss: 2.609e-02, Loss_bcs: 1.399e-02, Loss_ics: 2.111e-03, Loss_res: 3.904e-03, Time: 0.24
# It: 1650, Loss: 2.986e-02, Loss_bcs: 1.558e-02, Loss_ics: 2.391e-03, Loss_res: 3.727e-03, Time: 0.24
# It: 1660, Loss: 2.968e-02, Loss_bcs: 1.441e-02, Loss_ics: 3.092e-03, Loss_res: 4.063e-03, Time: 0.23
# It: 1670, Loss: 3.005e-02, Loss_bcs: 1.591e-02, Loss_ics: 2.462e-03, Loss_res: 5.292e-03, Time: 0.26
# It: 1680, Loss: 2.528e-02, Loss_bcs: 1.115e-02, Loss_ics: 3.905e-03, Loss_res: 3.201e-03, Time: 0.25
# It: 1690, Loss: 3.141e-02, Loss_bcs: 1.393e-02, Loss_ics: 3.650e-03, Loss_res: 4.272e-03, Time: 0.24
# It: 1700, Loss: 2.908e-02, Loss_bcs: 1.205e-02, Loss_ics: 2.868e-03, Loss_res: 3.697e-03, Time: 0.24
# It: 1710, Loss: 3.692e-02, Loss_bcs: 1.339e-02, Loss_ics: 2.619e-03, Loss_res: 3.661e-03, Time: 0.26
# It: 1720, Loss: 2.862e-02, Loss_bcs: 1.316e-02, Loss_ics: 1.580e-03, Loss_res: 5.060e-03, Time: 0.24
# It: 1730, Loss: 2.752e-02, Loss_bcs: 1.503e-02, Loss_ics: 2.129e-03, Loss_res: 4.306e-03, Time: 0.25
# It: 1740, Loss: 3.674e-02, Loss_bcs: 1.532e-02, Loss_ics: 1.729e-03, Loss_res: 1.400e-02, Time: 0.24
# It: 1750, Loss: 3.134e-02, Loss_bcs: 1.267e-02, Loss_ics: 2.350e-03, Loss_res: 6.561e-03, Time: 0.25
# It: 1760, Loss: 3.069e-02, Loss_bcs: 1.271e-02, Loss_ics: 2.252e-03, Loss_res: 4.939e-03, Time: 0.24
# It: 1770, Loss: 2.593e-02, Loss_bcs: 1.251e-02, Loss_ics: 2.496e-03, Loss_res: 4.875e-03, Time: 0.24
# It: 1780, Loss: 3.010e-02, Loss_bcs: 1.268e-02, Loss_ics: 3.230e-03, Loss_res: 4.199e-03, Time: 0.24
# It: 1790, Loss: 2.956e-02, Loss_bcs: 1.426e-02, Loss_ics: 3.925e-03, Loss_res: 4.343e-03, Time: 0.25
# It: 1800, Loss: 3.059e-02, Loss_bcs: 1.198e-02, Loss_ics: 4.214e-03, Loss_res: 6.168e-03, Time: 0.24
# It: 1810, Loss: 2.705e-02, Loss_bcs: 1.270e-02, Loss_ics: 3.153e-03, Loss_res: 5.133e-03, Time: 0.24
# It: 1820, Loss: 2.860e-02, Loss_bcs: 1.359e-02, Loss_ics: 1.898e-03, Loss_res: 3.992e-03, Time: 0.24
# It: 1830, Loss: 2.559e-02, Loss_bcs: 1.351e-02, Loss_ics: 1.740e-03, Loss_res: 3.517e-03, Time: 0.27
# It: 1840, Loss: 2.744e-02, Loss_bcs: 1.590e-02, Loss_ics: 1.845e-03, Loss_res: 3.373e-03, Time: 0.24
# It: 1850, Loss: 2.684e-02, Loss_bcs: 1.147e-02, Loss_ics: 2.111e-03, Loss_res: 4.179e-03, Time: 0.24
# It: 1860, Loss: 4.407e-02, Loss_bcs: 2.897e-02, Loss_ics: 3.820e-03, Loss_res: 5.795e-03, Time: 0.24
# It: 1870, Loss: 3.293e-02, Loss_bcs: 1.405e-02, Loss_ics: 2.325e-03, Loss_res: 1.049e-02, Time: 0.24
# It: 1880, Loss: 3.476e-02, Loss_bcs: 1.808e-02, Loss_ics: 1.882e-03, Loss_res: 6.586e-03, Time: 0.24
# It: 1890, Loss: 3.079e-02, Loss_bcs: 1.662e-02, Loss_ics: 2.306e-03, Loss_res: 5.286e-03, Time: 0.24
# It: 1900, Loss: 2.767e-02, Loss_bcs: 1.365e-02, Loss_ics: 2.426e-03, Loss_res: 4.836e-03, Time: 0.25
# It: 1910, Loss: 2.606e-02, Loss_bcs: 1.537e-02, Loss_ics: 1.828e-03, Loss_res: 3.558e-03, Time: 0.25
# It: 1920, Loss: 2.682e-02, Loss_bcs: 1.455e-02, Loss_ics: 2.269e-03, Loss_res: 2.297e-03, Time: 0.24
# It: 1930, Loss: 2.738e-02, Loss_bcs: 1.300e-02, Loss_ics: 1.879e-03, Loss_res: 3.479e-03, Time: 0.24
# It: 1940, Loss: 2.232e-02, Loss_bcs: 1.156e-02, Loss_ics: 2.283e-03, Loss_res: 3.213e-03, Time: 0.24
# It: 1950, Loss: 2.588e-02, Loss_bcs: 1.168e-02, Loss_ics: 2.469e-03, Loss_res: 6.118e-03, Time: 0.24
# It: 1960, Loss: 2.669e-02, Loss_bcs: 1.214e-02, Loss_ics: 1.681e-03, Loss_res: 4.161e-03, Time: 0.24
# It: 1970, Loss: 2.719e-02, Loss_bcs: 1.269e-02, Loss_ics: 2.429e-03, Loss_res: 5.531e-03, Time: 0.24
# It: 1980, Loss: 2.903e-02, Loss_bcs: 1.315e-02, Loss_ics: 2.328e-03, Loss_res: 2.563e-03, Time: 0.24
# It: 1990, Loss: 2.470e-02, Loss_bcs: 1.295e-02, Loss_ics: 2.157e-03, Loss_res: 3.569e-03, Time: 0.25
# It: 2000, Loss: 2.520e-02, Loss_bcs: 1.115e-02, Loss_ics: 1.689e-03, Loss_res: 4.310e-03, Time: 0.25
# It: 2010, Loss: 2.594e-02, Loss_bcs: 1.346e-02, Loss_ics: 2.761e-03, Loss_res: 3.871e-03, Time: 0.26
# It: 2020, Loss: 2.474e-02, Loss_bcs: 1.237e-02, Loss_ics: 1.164e-03, Loss_res: 3.238e-03, Time: 0.23
# It: 2030, Loss: 2.869e-02, Loss_bcs: 1.463e-02, Loss_ics: 1.964e-03, Loss_res: 4.929e-03, Time: 0.25
# It: 2040, Loss: 2.561e-02, Loss_bcs: 1.219e-02, Loss_ics: 1.776e-03, Loss_res: 3.854e-03, Time: 0.25
# It: 2050, Loss: 2.738e-02, Loss_bcs: 1.144e-02, Loss_ics: 3.170e-03, Loss_res: 5.214e-03, Time: 0.25
# It: 2060, Loss: 3.313e-02, Loss_bcs: 1.432e-02, Loss_ics: 2.763e-03, Loss_res: 5.899e-03, Time: 0.24
# It: 2070, Loss: 3.510e-02, Loss_bcs: 1.052e-02, Loss_ics: 2.261e-03, Loss_res: 3.400e-03, Time: 0.24
# It: 2080, Loss: 2.594e-02, Loss_bcs: 1.298e-02, Loss_ics: 2.776e-03, Loss_res: 4.121e-03, Time: 0.24
# It: 2090, Loss: 2.829e-02, Loss_bcs: 1.448e-02, Loss_ics: 3.006e-03, Loss_res: 4.801e-03, Time: 0.23
# It: 2100, Loss: 2.231e-02, Loss_bcs: 1.134e-02, Loss_ics: 1.445e-03, Loss_res: 3.703e-03, Time: 0.23
# It: 2110, Loss: 2.563e-02, Loss_bcs: 1.046e-02, Loss_ics: 1.289e-03, Loss_res: 3.742e-03, Time: 0.24
# It: 2120, Loss: 2.517e-02, Loss_bcs: 1.459e-02, Loss_ics: 2.112e-03, Loss_res: 3.140e-03, Time: 0.24
# It: 2130, Loss: 2.365e-02, Loss_bcs: 1.178e-02, Loss_ics: 1.365e-03, Loss_res: 3.862e-03, Time: 0.26
# It: 2140, Loss: 2.483e-02, Loss_bcs: 1.188e-02, Loss_ics: 2.049e-03, Loss_res: 4.735e-03, Time: 0.25
# It: 2150, Loss: 5.779e-02, Loss_bcs: 3.816e-02, Loss_ics: 3.293e-03, Loss_res: 1.172e-02, Time: 0.26
# It: 2160, Loss: 4.712e-02, Loss_bcs: 1.433e-02, Loss_ics: 3.388e-03, Loss_res: 1.737e-02, Time: 0.24
# It: 2170, Loss: 4.142e-02, Loss_bcs: 1.819e-02, Loss_ics: 9.681e-04, Loss_res: 1.104e-02, Time: 0.24
# It: 2180, Loss: 3.696e-02, Loss_bcs: 1.340e-02, Loss_ics: 2.380e-03, Loss_res: 1.029e-02, Time: 0.25
# It: 2190, Loss: 3.132e-02, Loss_bcs: 1.563e-02, Loss_ics: 3.961e-03, Loss_res: 5.044e-03, Time: 0.24
# It: 2200, Loss: 2.262e-02, Loss_bcs: 9.836e-03, Loss_ics: 2.442e-03, Loss_res: 2.790e-03, Time: 0.24
# It: 2210, Loss: 2.483e-02, Loss_bcs: 1.253e-02, Loss_ics: 1.979e-03, Loss_res: 2.957e-03, Time: 0.24
# It: 2220, Loss: 2.232e-02, Loss_bcs: 1.106e-02, Loss_ics: 2.248e-03, Loss_res: 3.416e-03, Time: 0.25
# It: 2230, Loss: 2.378e-02, Loss_bcs: 1.254e-02, Loss_ics: 1.418e-03, Loss_res: 3.212e-03, Time: 0.26
# It: 2240, Loss: 2.570e-02, Loss_bcs: 1.312e-02, Loss_ics: 1.083e-03, Loss_res: 4.619e-03, Time: 0.25
# It: 2250, Loss: 2.700e-02, Loss_bcs: 1.528e-02, Loss_ics: 1.355e-03, Loss_res: 4.279e-03, Time: 0.24
# It: 2260, Loss: 3.597e-02, Loss_bcs: 1.309e-02, Loss_ics: 1.876e-03, Loss_res: 4.602e-03, Time: 0.25
# It: 2270, Loss: 2.385e-02, Loss_bcs: 1.292e-02, Loss_ics: 1.185e-03, Loss_res: 3.172e-03, Time: 0.25
# It: 2280, Loss: 3.271e-02, Loss_bcs: 1.578e-02, Loss_ics: 1.345e-03, Loss_res: 5.318e-03, Time: 0.25
# It: 2290, Loss: 3.005e-02, Loss_bcs: 1.134e-02, Loss_ics: 8.725e-04, Loss_res: 9.124e-03, Time: 0.24
# It: 2300, Loss: 2.418e-02, Loss_bcs: 1.013e-02, Loss_ics: 1.327e-03, Loss_res: 5.126e-03, Time: 0.26
# It: 2310, Loss: 2.157e-02, Loss_bcs: 1.154e-02, Loss_ics: 9.287e-04, Loss_res: 2.783e-03, Time: 0.24
# It: 2320, Loss: 2.680e-02, Loss_bcs: 1.040e-02, Loss_ics: 2.713e-03, Loss_res: 3.865e-03, Time: 0.25
# It: 2330, Loss: 2.529e-02, Loss_bcs: 1.180e-02, Loss_ics: 1.900e-03, Loss_res: 6.173e-03, Time: 0.24
# It: 2340, Loss: 2.453e-02, Loss_bcs: 1.431e-02, Loss_ics: 1.465e-03, Loss_res: 3.165e-03, Time: 0.25
# It: 2350, Loss: 2.202e-02, Loss_bcs: 1.016e-02, Loss_ics: 2.053e-03, Loss_res: 3.630e-03, Time: 0.24
# It: 2360, Loss: 1.893e-02, Loss_bcs: 1.061e-02, Loss_ics: 1.202e-03, Loss_res: 3.053e-03, Time: 0.24
# It: 2370, Loss: 2.302e-02, Loss_bcs: 1.288e-02, Loss_ics: 2.143e-03, Loss_res: 2.946e-03, Time: 0.24
# It: 2380, Loss: 2.284e-02, Loss_bcs: 1.270e-02, Loss_ics: 9.800e-04, Loss_res: 3.766e-03, Time: 0.26
# It: 2390, Loss: 1.841e-02, Loss_bcs: 9.844e-03, Loss_ics: 1.115e-03, Loss_res: 2.616e-03, Time: 0.23
# It: 2400, Loss: 2.499e-02, Loss_bcs: 1.445e-02, Loss_ics: 1.922e-03, Loss_res: 3.698e-03, Time: 0.24
# It: 2410, Loss: 2.225e-02, Loss_bcs: 1.117e-02, Loss_ics: 1.945e-03, Loss_res: 2.413e-03, Time: 0.25
# It: 2420, Loss: 2.109e-02, Loss_bcs: 1.052e-02, Loss_ics: 8.895e-04, Loss_res: 2.681e-03, Time: 0.25
# It: 2430, Loss: 2.333e-02, Loss_bcs: 1.191e-02, Loss_ics: 2.073e-03, Loss_res: 4.312e-03, Time: 0.25
# It: 2440, Loss: 2.619e-02, Loss_bcs: 1.395e-02, Loss_ics: 2.659e-03, Loss_res: 3.267e-03, Time: 0.25
# It: 2450, Loss: 2.325e-02, Loss_bcs: 1.271e-02, Loss_ics: 1.531e-03, Loss_res: 4.370e-03, Time: 0.25
# It: 2460, Loss: 2.482e-02, Loss_bcs: 1.287e-02, Loss_ics: 1.612e-03, Loss_res: 5.165e-03, Time: 0.28
# It: 2470, Loss: 2.686e-02, Loss_bcs: 1.186e-02, Loss_ics: 1.569e-03, Loss_res: 4.059e-03, Time: 0.26
# It: 2480, Loss: 2.872e-02, Loss_bcs: 1.414e-02, Loss_ics: 2.238e-03, Loss_res: 3.187e-03, Time: 0.25
# It: 2490, Loss: 2.806e-02, Loss_bcs: 1.143e-02, Loss_ics: 2.339e-03, Loss_res: 7.227e-03, Time: 0.25
# It: 2500, Loss: 2.941e-02, Loss_bcs: 1.381e-02, Loss_ics: 3.842e-03, Loss_res: 6.552e-03, Time: 0.25
# It: 2510, Loss: 2.245e-02, Loss_bcs: 1.193e-02, Loss_ics: 1.714e-03, Loss_res: 3.293e-03, Time: 0.23
# It: 2520, Loss: 2.676e-02, Loss_bcs: 1.376e-02, Loss_ics: 1.472e-03, Loss_res: 5.768e-03, Time: 0.23
# It: 2530, Loss: 2.192e-02, Loss_bcs: 1.047e-02, Loss_ics: 2.102e-03, Loss_res: 2.401e-03, Time: 0.25
# It: 2540, Loss: 2.345e-02, Loss_bcs: 1.120e-02, Loss_ics: 1.863e-03, Loss_res: 4.158e-03, Time: 0.24
# It: 2550, Loss: 2.384e-02, Loss_bcs: 1.130e-02, Loss_ics: 1.914e-03, Loss_res: 3.864e-03, Time: 0.24
# It: 2560, Loss: 2.520e-02, Loss_bcs: 1.174e-02, Loss_ics: 2.668e-03, Loss_res: 3.026e-03, Time: 0.24
# It: 2570, Loss: 2.139e-02, Loss_bcs: 1.175e-02, Loss_ics: 1.466e-03, Loss_res: 3.657e-03, Time: 0.25
# It: 2580, Loss: 2.086e-02, Loss_bcs: 1.018e-02, Loss_ics: 1.524e-03, Loss_res: 2.336e-03, Time: 0.24
# It: 2590, Loss: 2.122e-02, Loss_bcs: 1.129e-02, Loss_ics: 1.457e-03, Loss_res: 3.589e-03, Time: 0.24
# It: 2600, Loss: 2.143e-02, Loss_bcs: 1.035e-02, Loss_ics: 1.282e-03, Loss_res: 2.879e-03, Time: 0.25
# It: 2610, Loss: 2.458e-02, Loss_bcs: 1.184e-02, Loss_ics: 1.483e-03, Loss_res: 4.820e-03, Time: 0.26
# It: 2620, Loss: 2.197e-02, Loss_bcs: 9.599e-03, Loss_ics: 2.411e-03, Loss_res: 4.011e-03, Time: 0.25
# It: 2630, Loss: 2.430e-02, Loss_bcs: 1.248e-02, Loss_ics: 1.672e-03, Loss_res: 4.321e-03, Time: 0.25
# It: 2640, Loss: 2.056e-02, Loss_bcs: 1.171e-02, Loss_ics: 1.388e-03, Loss_res: 3.282e-03, Time: 0.24
# It: 2650, Loss: 2.115e-02, Loss_bcs: 1.194e-02, Loss_ics: 1.847e-03, Loss_res: 3.210e-03, Time: 0.25
# It: 2660, Loss: 1.954e-02, Loss_bcs: 1.055e-02, Loss_ics: 2.189e-03, Loss_res: 2.607e-03, Time: 0.25
# It: 2670, Loss: 1.859e-02, Loss_bcs: 1.011e-02, Loss_ics: 1.122e-03, Loss_res: 2.719e-03, Time: 0.24
# It: 2680, Loss: 2.338e-02, Loss_bcs: 1.031e-02, Loss_ics: 1.233e-03, Loss_res: 5.910e-03, Time: 0.24
# It: 2690, Loss: 2.069e-02, Loss_bcs: 1.132e-02, Loss_ics: 1.849e-03, Loss_res: 4.065e-03, Time: 0.25
# It: 2700, Loss: 2.095e-02, Loss_bcs: 1.021e-02, Loss_ics: 2.509e-03, Loss_res: 3.883e-03, Time: 0.24
# It: 2710, Loss: 2.108e-02, Loss_bcs: 1.092e-02, Loss_ics: 1.783e-03, Loss_res: 2.688e-03, Time: 0.25
# It: 2720, Loss: 2.184e-02, Loss_bcs: 1.069e-02, Loss_ics: 1.500e-03, Loss_res: 3.155e-03, Time: 0.25
# It: 2730, Loss: 2.124e-02, Loss_bcs: 1.044e-02, Loss_ics: 2.008e-03, Loss_res: 2.632e-03, Time: 0.26
# It: 2740, Loss: 2.285e-02, Loss_bcs: 1.115e-02, Loss_ics: 1.557e-03, Loss_res: 2.422e-03, Time: 0.24
# It: 2750, Loss: 2.052e-02, Loss_bcs: 9.124e-03, Loss_ics: 1.787e-03, Loss_res: 3.790e-03, Time: 0.24
# It: 2760, Loss: 2.364e-02, Loss_bcs: 1.023e-02, Loss_ics: 2.804e-03, Loss_res: 3.228e-03, Time: 0.24
# It: 2770, Loss: 2.383e-02, Loss_bcs: 9.284e-03, Loss_ics: 4.492e-03, Loss_res: 3.839e-03, Time: 0.26
# It: 2780, Loss: 2.201e-02, Loss_bcs: 1.090e-02, Loss_ics: 1.922e-03, Loss_res: 4.863e-03, Time: 0.24
# It: 2790, Loss: 2.098e-02, Loss_bcs: 1.134e-02, Loss_ics: 1.568e-03, Loss_res: 3.760e-03, Time: 0.24
# It: 2800, Loss: 1.918e-02, Loss_bcs: 1.007e-02, Loss_ics: 1.800e-03, Loss_res: 2.394e-03, Time: 0.25
# It: 2810, Loss: 1.939e-02, Loss_bcs: 9.960e-03, Loss_ics: 1.315e-03, Loss_res: 3.458e-03, Time: 0.25
# It: 2820, Loss: 2.006e-02, Loss_bcs: 1.051e-02, Loss_ics: 2.597e-03, Loss_res: 2.719e-03, Time: 0.24
# It: 2830, Loss: 2.166e-02, Loss_bcs: 9.557e-03, Loss_ics: 1.414e-03, Loss_res: 5.664e-03, Time: 0.24
# It: 2840, Loss: 2.233e-02, Loss_bcs: 8.737e-03, Loss_ics: 1.018e-03, Loss_res: 4.742e-03, Time: 0.24
# It: 2850, Loss: 1.876e-02, Loss_bcs: 9.083e-03, Loss_ics: 1.147e-03, Loss_res: 3.493e-03, Time: 0.26
# It: 2860, Loss: 2.126e-02, Loss_bcs: 1.039e-02, Loss_ics: 2.451e-03, Loss_res: 3.704e-03, Time: 0.24
# It: 2870, Loss: 2.693e-02, Loss_bcs: 1.369e-02, Loss_ics: 2.561e-03, Loss_res: 6.620e-03, Time: 0.25
# It: 2880, Loss: 2.177e-02, Loss_bcs: 9.249e-03, Loss_ics: 1.453e-03, Loss_res: 3.969e-03, Time: 0.25
# It: 2890, Loss: 2.452e-02, Loss_bcs: 1.265e-02, Loss_ics: 1.540e-03, Loss_res: 4.710e-03, Time: 0.25
# It: 2900, Loss: 2.278e-02, Loss_bcs: 1.048e-02, Loss_ics: 2.158e-03, Loss_res: 3.065e-03, Time: 0.24
# It: 2910, Loss: 2.451e-02, Loss_bcs: 1.218e-02, Loss_ics: 2.838e-03, Loss_res: 2.572e-03, Time: 0.25
# It: 2920, Loss: 2.180e-02, Loss_bcs: 1.222e-02, Loss_ics: 1.461e-03, Loss_res: 4.127e-03, Time: 0.25
# It: 2930, Loss: 2.106e-02, Loss_bcs: 1.173e-02, Loss_ics: 1.647e-03, Loss_res: 3.835e-03, Time: 0.25
# It: 2940, Loss: 1.936e-02, Loss_bcs: 9.657e-03, Loss_ics: 1.469e-03, Loss_res: 2.541e-03, Time: 0.23
# It: 2950, Loss: 2.217e-02, Loss_bcs: 1.081e-02, Loss_ics: 2.475e-03, Loss_res: 3.914e-03, Time: 0.25
# It: 2960, Loss: 1.979e-02, Loss_bcs: 9.214e-03, Loss_ics: 1.401e-03, Loss_res: 4.994e-03, Time: 0.25
# It: 2970, Loss: 1.852e-02, Loss_bcs: 1.117e-02, Loss_ics: 1.552e-03, Loss_res: 2.215e-03, Time: 0.24
# It: 2980, Loss: 2.150e-02, Loss_bcs: 1.109e-02, Loss_ics: 1.798e-03, Loss_res: 2.411e-03, Time: 0.24
# It: 2990, Loss: 2.229e-02, Loss_bcs: 9.005e-03, Loss_ics: 1.969e-03, Loss_res: 3.030e-03, Time: 0.26
# It: 3000, Loss: 2.100e-02, Loss_bcs: 1.052e-02, Loss_ics: 9.079e-04, Loss_res: 5.743e-03, Time: 0.26
# It: 3010, Loss: 1.827e-02, Loss_bcs: 9.147e-03, Loss_ics: 8.216e-04, Loss_res: 3.894e-03, Time: 0.24
# It: 3020, Loss: 2.044e-02, Loss_bcs: 9.375e-03, Loss_ics: 1.912e-03, Loss_res: 4.729e-03, Time: 0.25
# It: 3030, Loss: 2.030e-02, Loss_bcs: 9.487e-03, Loss_ics: 1.570e-03, Loss_res: 3.809e-03, Time: 0.24
# It: 3040, Loss: 2.315e-02, Loss_bcs: 1.239e-02, Loss_ics: 2.835e-03, Loss_res: 3.271e-03, Time: 0.26
# It: 3050, Loss: 1.812e-02, Loss_bcs: 8.974e-03, Loss_ics: 1.231e-03, Loss_res: 2.494e-03, Time: 0.24
# It: 3060, Loss: 2.157e-02, Loss_bcs: 1.267e-02, Loss_ics: 2.007e-03, Loss_res: 2.229e-03, Time: 0.25
# It: 3070, Loss: 2.111e-02, Loss_bcs: 1.182e-02, Loss_ics: 1.402e-03, Loss_res: 2.746e-03, Time: 0.24
# It: 3080, Loss: 2.118e-02, Loss_bcs: 1.049e-02, Loss_ics: 1.287e-03, Loss_res: 4.435e-03, Time: 0.26
# It: 3090, Loss: 1.644e-02, Loss_bcs: 8.171e-03, Loss_ics: 1.243e-03, Loss_res: 3.248e-03, Time: 0.24
# It: 3100, Loss: 1.997e-02, Loss_bcs: 9.761e-03, Loss_ics: 9.069e-04, Loss_res: 4.060e-03, Time: 0.24
# It: 3110, Loss: 1.863e-02, Loss_bcs: 1.009e-02, Loss_ics: 1.284e-03, Loss_res: 4.104e-03, Time: 0.24
# It: 3120, Loss: 1.793e-02, Loss_bcs: 1.007e-02, Loss_ics: 1.022e-03, Loss_res: 2.327e-03, Time: 0.25
# It: 3130, Loss: 1.793e-02, Loss_bcs: 8.990e-03, Loss_ics: 1.618e-03, Loss_res: 2.398e-03, Time: 0.24
# It: 3140, Loss: 1.634e-02, Loss_bcs: 8.776e-03, Loss_ics: 9.810e-04, Loss_res: 2.446e-03, Time: 0.25
# It: 3150, Loss: 2.176e-02, Loss_bcs: 1.150e-02, Loss_ics: 1.780e-03, Loss_res: 3.953e-03, Time: 0.24
# It: 3160, Loss: 2.327e-02, Loss_bcs: 8.353e-03, Loss_ics: 1.002e-03, Loss_res: 3.175e-03, Time: 0.24
# It: 3170, Loss: 2.344e-02, Loss_bcs: 9.733e-03, Loss_ics: 8.174e-04, Loss_res: 5.228e-03, Time: 0.24
# It: 3180, Loss: 2.533e-02, Loss_bcs: 9.834e-03, Loss_ics: 1.737e-03, Loss_res: 4.822e-03, Time: 0.25
# It: 3190, Loss: 2.143e-02, Loss_bcs: 1.180e-02, Loss_ics: 1.335e-03, Loss_res: 2.850e-03, Time: 0.24
# It: 3200, Loss: 1.930e-02, Loss_bcs: 9.143e-03, Loss_ics: 1.209e-03, Loss_res: 4.506e-03, Time: 0.24
# It: 3210, Loss: 2.031e-02, Loss_bcs: 8.340e-03, Loss_ics: 1.765e-03, Loss_res: 4.499e-03, Time: 0.25
# It: 3220, Loss: 2.391e-02, Loss_bcs: 1.020e-02, Loss_ics: 1.365e-03, Loss_res: 4.209e-03, Time: 0.24
# It: 3230, Loss: 2.121e-02, Loss_bcs: 9.945e-03, Loss_ics: 1.467e-03, Loss_res: 4.149e-03, Time: 0.25
# It: 3240, Loss: 1.916e-02, Loss_bcs: 9.797e-03, Loss_ics: 1.542e-03, Loss_res: 3.530e-03, Time: 0.26
# It: 3250, Loss: 2.014e-02, Loss_bcs: 1.060e-02, Loss_ics: 1.324e-03, Loss_res: 4.034e-03, Time: 0.24
# It: 3260, Loss: 2.053e-02, Loss_bcs: 9.498e-03, Loss_ics: 1.851e-03, Loss_res: 4.943e-03, Time: 0.23
# It: 3270, Loss: 1.768e-02, Loss_bcs: 9.776e-03, Loss_ics: 1.368e-03, Loss_res: 2.359e-03, Time: 0.24
# It: 3280, Loss: 2.285e-02, Loss_bcs: 1.216e-02, Loss_ics: 3.060e-03, Loss_res: 2.157e-03, Time: 0.25
# It: 3290, Loss: 1.835e-02, Loss_bcs: 1.086e-02, Loss_ics: 1.205e-03, Loss_res: 1.892e-03, Time: 0.25
# It: 3300, Loss: 1.817e-02, Loss_bcs: 9.017e-03, Loss_ics: 1.584e-03, Loss_res: 2.665e-03, Time: 0.24
# It: 3310, Loss: 1.633e-02, Loss_bcs: 8.555e-03, Loss_ics: 1.663e-03, Loss_res: 1.909e-03, Time: 0.25
# It: 3320, Loss: 1.758e-02, Loss_bcs: 8.323e-03, Loss_ics: 1.480e-03, Loss_res: 3.356e-03, Time: 0.26
# It: 3330, Loss: 1.719e-02, Loss_bcs: 8.843e-03, Loss_ics: 1.554e-03, Loss_res: 3.013e-03, Time: 0.26
# It: 3340, Loss: 1.867e-02, Loss_bcs: 8.068e-03, Loss_ics: 2.362e-03, Loss_res: 2.624e-03, Time: 0.26
# It: 3350, Loss: 2.070e-02, Loss_bcs: 9.456e-03, Loss_ics: 2.598e-03, Loss_res: 3.169e-03, Time: 0.28
# It: 3360, Loss: 2.074e-02, Loss_bcs: 1.026e-02, Loss_ics: 1.579e-03, Loss_res: 4.349e-03, Time: 0.25
# It: 3370, Loss: 2.137e-02, Loss_bcs: 9.240e-03, Loss_ics: 1.577e-03, Loss_res: 6.296e-03, Time: 0.25
# It: 3380, Loss: 1.819e-02, Loss_bcs: 7.312e-03, Loss_ics: 1.721e-03, Loss_res: 3.878e-03, Time: 0.24
# It: 3390, Loss: 2.403e-02, Loss_bcs: 1.180e-02, Loss_ics: 1.722e-03, Loss_res: 6.167e-03, Time: 0.26
# It: 3400, Loss: 3.694e-02, Loss_bcs: 1.320e-02, Loss_ics: 1.693e-03, Loss_res: 1.637e-02, Time: 0.26
# It: 3410, Loss: 3.120e-02, Loss_bcs: 1.292e-02, Loss_ics: 1.730e-03, Loss_res: 1.074e-02, Time: 0.26
# It: 3420, Loss: 2.323e-02, Loss_bcs: 1.137e-02, Loss_ics: 1.139e-03, Loss_res: 3.856e-03, Time: 0.24
# It: 3430, Loss: 2.451e-02, Loss_bcs: 1.300e-02, Loss_ics: 1.393e-03, Loss_res: 2.563e-03, Time: 0.26
# It: 3440, Loss: 2.236e-02, Loss_bcs: 8.360e-03, Loss_ics: 1.918e-03, Loss_res: 3.708e-03, Time: 0.23
# It: 3450, Loss: 1.933e-02, Loss_bcs: 8.981e-03, Loss_ics: 1.709e-03, Loss_res: 2.834e-03, Time: 0.24
# It: 3460, Loss: 2.154e-02, Loss_bcs: 1.121e-02, Loss_ics: 1.197e-03, Loss_res: 2.978e-03, Time: 0.24
# It: 3470, Loss: 1.805e-02, Loss_bcs: 7.593e-03, Loss_ics: 1.643e-03, Loss_res: 4.087e-03, Time: 0.26
# It: 3480, Loss: 2.500e-02, Loss_bcs: 1.113e-02, Loss_ics: 1.647e-03, Loss_res: 6.368e-03, Time: 0.25
# It: 3490, Loss: 2.195e-02, Loss_bcs: 9.148e-03, Loss_ics: 2.065e-03, Loss_res: 3.496e-03, Time: 0.24
# It: 3500, Loss: 1.919e-02, Loss_bcs: 1.157e-02, Loss_ics: 1.278e-03, Loss_res: 2.524e-03, Time: 0.26
# It: 3510, Loss: 2.043e-02, Loss_bcs: 9.071e-03, Loss_ics: 1.915e-03, Loss_res: 5.042e-03, Time: 0.24
# It: 3520, Loss: 2.109e-02, Loss_bcs: 1.002e-02, Loss_ics: 1.349e-03, Loss_res: 3.376e-03, Time: 0.25
# It: 3530, Loss: 2.512e-02, Loss_bcs: 8.808e-03, Loss_ics: 1.911e-03, Loss_res: 2.977e-03, Time: 0.24
# It: 3540, Loss: 1.953e-02, Loss_bcs: 1.042e-02, Loss_ics: 1.302e-03, Loss_res: 2.335e-03, Time: 0.26
# It: 3550, Loss: 1.768e-02, Loss_bcs: 8.298e-03, Loss_ics: 6.528e-04, Loss_res: 2.504e-03, Time: 0.24
# It: 3560, Loss: 1.959e-02, Loss_bcs: 1.073e-02, Loss_ics: 2.223e-03, Loss_res: 2.712e-03, Time: 0.24
# It: 3570, Loss: 1.859e-02, Loss_bcs: 1.071e-02, Loss_ics: 1.573e-03, Loss_res: 1.464e-03, Time: 0.24
# It: 3580, Loss: 1.848e-02, Loss_bcs: 1.127e-02, Loss_ics: 1.795e-03, Loss_res: 2.263e-03, Time: 0.25
# It: 3590, Loss: 1.663e-02, Loss_bcs: 8.695e-03, Loss_ics: 1.532e-03, Loss_res: 1.918e-03, Time: 0.28
# It: 3600, Loss: 1.584e-02, Loss_bcs: 8.214e-03, Loss_ics: 1.732e-03, Loss_res: 2.234e-03, Time: 0.24
# It: 3610, Loss: 1.727e-02, Loss_bcs: 9.983e-03, Loss_ics: 1.040e-03, Loss_res: 1.626e-03, Time: 0.24
# It: 3620, Loss: 1.900e-02, Loss_bcs: 9.364e-03, Loss_ics: 1.306e-03, Loss_res: 4.536e-03, Time: 0.25
# It: 3630, Loss: 1.749e-02, Loss_bcs: 8.995e-03, Loss_ics: 1.061e-03, Loss_res: 4.802e-03, Time: 0.25
# It: 3640, Loss: 2.034e-02, Loss_bcs: 8.614e-03, Loss_ics: 1.461e-03, Loss_res: 5.024e-03, Time: 0.25
# It: 3650, Loss: 1.867e-02, Loss_bcs: 9.560e-03, Loss_ics: 1.381e-03, Loss_res: 3.671e-03, Time: 0.25
# It: 3660, Loss: 2.040e-02, Loss_bcs: 9.218e-03, Loss_ics: 1.309e-03, Loss_res: 3.749e-03, Time: 0.26
# It: 3670, Loss: 1.724e-02, Loss_bcs: 9.736e-03, Loss_ics: 5.912e-04, Loss_res: 3.161e-03, Time: 0.24
# It: 3680, Loss: 1.650e-02, Loss_bcs: 8.826e-03, Loss_ics: 1.993e-03, Loss_res: 1.804e-03, Time: 0.24
# It: 3690, Loss: 1.790e-02, Loss_bcs: 9.012e-03, Loss_ics: 1.268e-03, Loss_res: 2.643e-03, Time: 0.24
# It: 3700, Loss: 1.573e-02, Loss_bcs: 8.065e-03, Loss_ics: 1.955e-03, Loss_res: 2.254e-03, Time: 0.25
# It: 3710, Loss: 1.773e-02, Loss_bcs: 1.028e-02, Loss_ics: 1.303e-03, Loss_res: 2.354e-03, Time: 0.24
# It: 3720, Loss: 1.792e-02, Loss_bcs: 1.088e-02, Loss_ics: 1.275e-03, Loss_res: 2.886e-03, Time: 0.25
# It: 3730, Loss: 1.978e-02, Loss_bcs: 1.087e-02, Loss_ics: 1.236e-03, Loss_res: 4.447e-03, Time: 0.24
# It: 3740, Loss: 1.985e-02, Loss_bcs: 1.113e-02, Loss_ics: 1.322e-03, Loss_res: 3.105e-03, Time: 0.25
# It: 3750, Loss: 1.823e-02, Loss_bcs: 9.416e-03, Loss_ics: 1.528e-03, Loss_res: 2.695e-03, Time: 0.25
# It: 3760, Loss: 1.992e-02, Loss_bcs: 9.437e-03, Loss_ics: 1.722e-03, Loss_res: 4.967e-03, Time: 0.25
# It: 3770, Loss: 1.884e-02, Loss_bcs: 9.469e-03, Loss_ics: 1.053e-03, Loss_res: 3.831e-03, Time: 0.25
# It: 3780, Loss: 1.505e-02, Loss_bcs: 9.382e-03, Loss_ics: 9.857e-04, Loss_res: 2.305e-03, Time: 0.26
# It: 3790, Loss: 1.727e-02, Loss_bcs: 9.005e-03, Loss_ics: 1.402e-03, Loss_res: 2.258e-03, Time: 0.24
# It: 3800, Loss: 1.981e-02, Loss_bcs: 9.371e-03, Loss_ics: 2.801e-03, Loss_res: 2.442e-03, Time: 0.24
# It: 3810, Loss: 2.201e-02, Loss_bcs: 8.551e-03, Loss_ics: 1.219e-03, Loss_res: 9.151e-03, Time: 0.25
# It: 3820, Loss: 1.822e-02, Loss_bcs: 8.903e-03, Loss_ics: 1.133e-03, Loss_res: 4.599e-03, Time: 0.26
# It: 3830, Loss: 1.653e-02, Loss_bcs: 7.547e-03, Loss_ics: 1.911e-03, Loss_res: 2.848e-03, Time: 0.24
# It: 3840, Loss: 1.743e-02, Loss_bcs: 1.047e-02, Loss_ics: 1.403e-03, Loss_res: 2.088e-03, Time: 0.24
# It: 3850, Loss: 1.594e-02, Loss_bcs: 8.620e-03, Loss_ics: 1.592e-03, Loss_res: 2.622e-03, Time: 0.25
# It: 3860, Loss: 1.841e-02, Loss_bcs: 1.176e-02, Loss_ics: 1.431e-03, Loss_res: 2.380e-03, Time: 0.25
# It: 3870, Loss: 3.003e-02, Loss_bcs: 1.076e-02, Loss_ics: 1.524e-03, Loss_res: 1.444e-02, Time: 0.24
# It: 3880, Loss: 2.232e-02, Loss_bcs: 9.813e-03, Loss_ics: 2.310e-03, Loss_res: 5.199e-03, Time: 0.24
# It: 3890, Loss: 1.946e-02, Loss_bcs: 8.791e-03, Loss_ics: 1.652e-03, Loss_res: 3.394e-03, Time: 0.26
# It: 3900, Loss: 1.830e-02, Loss_bcs: 1.060e-02, Loss_ics: 1.645e-03, Loss_res: 3.156e-03, Time: 0.25
# It: 3910, Loss: 2.361e-02, Loss_bcs: 9.894e-03, Loss_ics: 1.819e-03, Loss_res: 5.880e-03, Time: 0.26
# It: 3920, Loss: 2.180e-02, Loss_bcs: 8.526e-03, Loss_ics: 1.784e-03, Loss_res: 3.638e-03, Time: 0.25
# It: 3930, Loss: 1.948e-02, Loss_bcs: 1.021e-02, Loss_ics: 1.526e-03, Loss_res: 3.387e-03, Time: 0.25
# It: 3940, Loss: 1.588e-02, Loss_bcs: 8.616e-03, Loss_ics: 8.989e-04, Loss_res: 2.495e-03, Time: 0.25
# It: 3950, Loss: 1.861e-02, Loss_bcs: 1.096e-02, Loss_ics: 1.578e-03, Loss_res: 2.888e-03, Time: 0.25
# It: 3960, Loss: 1.607e-02, Loss_bcs: 7.510e-03, Loss_ics: 1.697e-03, Loss_res: 2.795e-03, Time: 0.25
# It: 3970, Loss: 1.503e-02, Loss_bcs: 8.535e-03, Loss_ics: 1.244e-03, Loss_res: 2.248e-03, Time: 0.26
# It: 3980, Loss: 1.642e-02, Loss_bcs: 8.914e-03, Loss_ics: 1.664e-03, Loss_res: 2.214e-03, Time: 0.27
# It: 3990, Loss: 1.938e-02, Loss_bcs: 1.039e-02, Loss_ics: 1.491e-03, Loss_res: 2.067e-03, Time: 0.26
# It: 4000, Loss: 1.714e-02, Loss_bcs: 8.787e-03, Loss_ics: 2.294e-03, Loss_res: 2.064e-03, Time: 0.25
# It: 4010, Loss: 1.583e-02, Loss_bcs: 8.118e-03, Loss_ics: 1.204e-03, Loss_res: 3.619e-03, Time: 0.25
# It: 4020, Loss: 1.550e-02, Loss_bcs: 8.690e-03, Loss_ics: 9.693e-04, Loss_res: 2.450e-03, Time: 0.24
# It: 4030, Loss: 1.495e-02, Loss_bcs: 7.444e-03, Loss_ics: 1.526e-03, Loss_res: 2.120e-03, Time: 0.25
# It: 4040, Loss: 1.662e-02, Loss_bcs: 8.678e-03, Loss_ics: 1.270e-03, Loss_res: 2.916e-03, Time: 0.25
# It: 4050, Loss: 1.734e-02, Loss_bcs: 8.928e-03, Loss_ics: 1.766e-03, Loss_res: 2.719e-03, Time: 0.25
# It: 4060, Loss: 1.942e-02, Loss_bcs: 1.036e-02, Loss_ics: 9.830e-04, Loss_res: 4.316e-03, Time: 0.25
# It: 4070, Loss: 1.952e-02, Loss_bcs: 9.368e-03, Loss_ics: 1.825e-03, Loss_res: 3.392e-03, Time: 0.24
# It: 4080, Loss: 1.656e-02, Loss_bcs: 8.702e-03, Loss_ics: 1.009e-03, Loss_res: 2.097e-03, Time: 0.26
# It: 4090, Loss: 1.549e-02, Loss_bcs: 7.992e-03, Loss_ics: 9.594e-04, Loss_res: 3.178e-03, Time: 0.23
# It: 4100, Loss: 1.614e-02, Loss_bcs: 9.278e-03, Loss_ics: 1.099e-03, Loss_res: 2.705e-03, Time: 0.25
# It: 4110, Loss: 1.682e-02, Loss_bcs: 7.776e-03, Loss_ics: 6.800e-04, Loss_res: 2.379e-03, Time: 0.25
# It: 4120, Loss: 1.628e-02, Loss_bcs: 7.995e-03, Loss_ics: 1.256e-03, Loss_res: 3.246e-03, Time: 0.27
# It: 4130, Loss: 1.798e-02, Loss_bcs: 9.211e-03, Loss_ics: 1.545e-03, Loss_res: 3.361e-03, Time: 0.25
# It: 4140, Loss: 2.313e-02, Loss_bcs: 9.200e-03, Loss_ics: 1.422e-03, Loss_res: 7.953e-03, Time: 0.25
# It: 4150, Loss: 1.509e-02, Loss_bcs: 7.197e-03, Loss_ics: 1.762e-03, Loss_res: 2.673e-03, Time: 0.24
# It: 4160, Loss: 1.639e-02, Loss_bcs: 9.335e-03, Loss_ics: 1.125e-03, Loss_res: 2.027e-03, Time: 0.26
# It: 4170, Loss: 2.249e-02, Loss_bcs: 8.520e-03, Loss_ics: 1.705e-03, Loss_res: 6.237e-03, Time: 0.23
# It: 4180, Loss: 1.528e-02, Loss_bcs: 9.207e-03, Loss_ics: 6.481e-04, Loss_res: 1.872e-03, Time: 0.24
# It: 4190, Loss: 1.768e-02, Loss_bcs: 9.749e-03, Loss_ics: 2.241e-03, Loss_res: 2.158e-03, Time: 0.24
# It: 4200, Loss: 1.865e-02, Loss_bcs: 8.257e-03, Loss_ics: 1.829e-03, Loss_res: 3.703e-03, Time: 0.26
# It: 4210, Loss: 1.555e-02, Loss_bcs: 9.663e-03, Loss_ics: 8.817e-04, Loss_res: 1.842e-03, Time: 0.25
# It: 4220, Loss: 1.633e-02, Loss_bcs: 9.355e-03, Loss_ics: 1.206e-03, Loss_res: 2.707e-03, Time: 0.24
# It: 4230, Loss: 1.722e-02, Loss_bcs: 9.112e-03, Loss_ics: 1.508e-03, Loss_res: 3.661e-03, Time: 0.24
# It: 4240, Loss: 2.293e-02, Loss_bcs: 9.554e-03, Loss_ics: 1.612e-03, Loss_res: 7.777e-03, Time: 0.24
# It: 4250, Loss: 2.268e-02, Loss_bcs: 9.705e-03, Loss_ics: 9.289e-04, Loss_res: 9.472e-03, Time: 0.25
# It: 4260, Loss: 2.264e-02, Loss_bcs: 8.796e-03, Loss_ics: 1.254e-03, Loss_res: 7.111e-03, Time: 0.24
# It: 4270, Loss: 2.093e-02, Loss_bcs: 1.014e-02, Loss_ics: 9.742e-04, Loss_res: 5.346e-03, Time: 0.25
# It: 4280, Loss: 1.866e-02, Loss_bcs: 1.166e-02, Loss_ics: 8.944e-04, Loss_res: 3.400e-03, Time: 0.26
# It: 4290, Loss: 1.726e-02, Loss_bcs: 1.041e-02, Loss_ics: 7.334e-04, Loss_res: 2.512e-03, Time: 0.25
# It: 4300, Loss: 1.786e-02, Loss_bcs: 1.067e-02, Loss_ics: 1.158e-03, Loss_res: 2.624e-03, Time: 0.25
# It: 4310, Loss: 1.865e-02, Loss_bcs: 1.056e-02, Loss_ics: 1.418e-03, Loss_res: 1.880e-03, Time: 0.25
# It: 4320, Loss: 1.663e-02, Loss_bcs: 8.886e-03, Loss_ics: 1.250e-03, Loss_res: 2.548e-03, Time: 0.26
# It: 4330, Loss: 1.674e-02, Loss_bcs: 8.818e-03, Loss_ics: 8.784e-04, Loss_res: 3.541e-03, Time: 0.25
# It: 4340, Loss: 1.566e-02, Loss_bcs: 7.983e-03, Loss_ics: 9.297e-04, Loss_res: 2.127e-03, Time: 0.24
# It: 4350, Loss: 1.833e-02, Loss_bcs: 8.699e-03, Loss_ics: 1.354e-03, Loss_res: 3.616e-03, Time: 0.25
# It: 4360, Loss: 1.469e-02, Loss_bcs: 7.763e-03, Loss_ics: 1.384e-03, Loss_res: 1.446e-03, Time: 0.25
# It: 4370, Loss: 1.609e-02, Loss_bcs: 9.369e-03, Loss_ics: 1.446e-03, Loss_res: 1.857e-03, Time: 0.25
# It: 4380, Loss: 1.733e-02, Loss_bcs: 1.041e-02, Loss_ics: 1.289e-03, Loss_res: 1.663e-03, Time: 0.25
# It: 4390, Loss: 1.943e-02, Loss_bcs: 9.556e-03, Loss_ics: 9.995e-04, Loss_res: 3.255e-03, Time: 0.24
# It: 4400, Loss: 1.547e-02, Loss_bcs: 7.126e-03, Loss_ics: 1.377e-03, Loss_res: 2.404e-03, Time: 0.24
# It: 4410, Loss: 1.636e-02, Loss_bcs: 8.385e-03, Loss_ics: 1.602e-03, Loss_res: 2.332e-03, Time: 0.24
# It: 4420, Loss: 1.564e-02, Loss_bcs: 9.316e-03, Loss_ics: 8.417e-04, Loss_res: 2.399e-03, Time: 0.24
# It: 4430, Loss: 1.500e-02, Loss_bcs: 8.543e-03, Loss_ics: 1.265e-03, Loss_res: 1.745e-03, Time: 0.23
# It: 4440, Loss: 1.707e-02, Loss_bcs: 9.708e-03, Loss_ics: 1.364e-03, Loss_res: 2.217e-03, Time: 0.25
# It: 4450, Loss: 1.900e-02, Loss_bcs: 1.049e-02, Loss_ics: 1.199e-03, Loss_res: 2.940e-03, Time: 0.25
# It: 4460, Loss: 1.570e-02, Loss_bcs: 8.723e-03, Loss_ics: 2.000e-03, Loss_res: 1.923e-03, Time: 0.24
# It: 4470, Loss: 1.940e-02, Loss_bcs: 9.808e-03, Loss_ics: 1.105e-03, Loss_res: 2.123e-03, Time: 0.27
# It: 4480, Loss: 1.815e-02, Loss_bcs: 7.585e-03, Loss_ics: 2.115e-03, Loss_res: 3.533e-03, Time: 0.23
# It: 4490, Loss: 1.693e-02, Loss_bcs: 9.385e-03, Loss_ics: 1.293e-03, Loss_res: 2.890e-03, Time: 0.24
# It: 4500, Loss: 1.527e-02, Loss_bcs: 8.687e-03, Loss_ics: 9.881e-04, Loss_res: 2.115e-03, Time: 0.26
# It: 4510, Loss: 1.817e-02, Loss_bcs: 9.891e-03, Loss_ics: 1.320e-03, Loss_res: 3.120e-03, Time: 0.26
# It: 4520, Loss: 2.160e-02, Loss_bcs: 9.460e-03, Loss_ics: 8.744e-04, Loss_res: 2.054e-03, Time: 0.24
# It: 4530, Loss: 1.768e-02, Loss_bcs: 7.618e-03, Loss_ics: 1.045e-03, Loss_res: 3.671e-03, Time: 0.24
# It: 4540, Loss: 1.697e-02, Loss_bcs: 8.689e-03, Loss_ics: 2.030e-03, Loss_res: 2.772e-03, Time: 0.25
# It: 4550, Loss: 2.085e-02, Loss_bcs: 9.082e-03, Loss_ics: 9.721e-04, Loss_res: 4.587e-03, Time: 0.26
# It: 4560, Loss: 1.781e-02, Loss_bcs: 1.030e-02, Loss_ics: 1.010e-03, Loss_res: 3.921e-03, Time: 0.23
# It: 4570, Loss: 1.574e-02, Loss_bcs: 8.222e-03, Loss_ics: 2.120e-03, Loss_res: 1.911e-03, Time: 0.24
# It: 4580, Loss: 1.789e-02, Loss_bcs: 8.367e-03, Loss_ics: 1.048e-03, Loss_res: 2.204e-03, Time: 0.24
# It: 4590, Loss: 1.366e-02, Loss_bcs: 6.473e-03, Loss_ics: 9.170e-04, Loss_res: 1.764e-03, Time: 0.25
# It: 4600, Loss: 1.420e-02, Loss_bcs: 8.766e-03, Loss_ics: 1.743e-03, Loss_res: 1.600e-03, Time: 0.25
# It: 4610, Loss: 1.985e-02, Loss_bcs: 1.172e-02, Loss_ics: 1.661e-03, Loss_res: 2.548e-03, Time: 0.25
# It: 4620, Loss: 1.609e-02, Loss_bcs: 9.212e-03, Loss_ics: 9.271e-04, Loss_res: 2.127e-03, Time: 0.24
# It: 4630, Loss: 1.460e-02, Loss_bcs: 8.062e-03, Loss_ics: 7.589e-04, Loss_res: 2.727e-03, Time: 0.25
# It: 4640, Loss: 1.499e-02, Loss_bcs: 8.241e-03, Loss_ics: 9.848e-04, Loss_res: 1.981e-03, Time: 0.24
# It: 4650, Loss: 1.572e-02, Loss_bcs: 8.592e-03, Loss_ics: 1.206e-03, Loss_res: 2.899e-03, Time: 0.24
# It: 4660, Loss: 1.667e-02, Loss_bcs: 7.924e-03, Loss_ics: 1.351e-03, Loss_res: 3.473e-03, Time: 0.24
# It: 4670, Loss: 1.391e-02, Loss_bcs: 7.804e-03, Loss_ics: 9.564e-04, Loss_res: 2.284e-03, Time: 0.26
# It: 4680, Loss: 1.740e-02, Loss_bcs: 1.025e-02, Loss_ics: 1.080e-03, Loss_res: 2.108e-03, Time: 0.24
# It: 4690, Loss: 1.630e-02, Loss_bcs: 9.526e-03, Loss_ics: 1.510e-03, Loss_res: 2.221e-03, Time: 0.24
# It: 4700, Loss: 1.423e-02, Loss_bcs: 8.250e-03, Loss_ics: 1.381e-03, Loss_res: 1.703e-03, Time: 0.24
# ...
# It: 38440, Loss: 7.744e-03, Loss_bcs: 5.034e-03, Loss_ics: 5.940e-04, Loss_res: 4.368e-04, Time: 0.24
# It: 38450, Loss: 1.001e-02, Loss_bcs: 7.179e-03, Loss_ics: 5.873e-04, Loss_res: 3.627e-04, Time: 0.24
# It: 38460, Loss: 1.047e-02, Loss_bcs: 7.202e-03, Loss_ics: 1.140e-03, Loss_res: 3.042e-04, Time: 0.24
# It: 38470, Loss: 9.083e-03, Loss_bcs: 6.436e-03, Loss_ics: 7.163e-04, Loss_res: 3.643e-04, Time: 0.24
# It: 38480, Loss: 9.113e-03, Loss_bcs: 5.971e-03, Loss_ics: 9.802e-04, Loss_res: 4.463e-04, Time: 0.25
# It: 38490, Loss: 8.593e-03, Loss_bcs: 5.791e-03, Loss_ics: 7.470e-04, Loss_res: 4.070e-04, Time: 0.24
# It: 38500, Loss: 9.181e-03, Loss_bcs: 6.127e-03, Loss_ics: 7.607e-04, Loss_res: 4.616e-04, Time: 0.25
# It: 38510, Loss: 8.853e-03, Loss_bcs: 6.366e-03, Loss_ics: 6.553e-04, Loss_res: 3.299e-04, Time: 0.26
# It: 38520, Loss: 9.918e-03, Loss_bcs: 6.952e-03, Loss_ics: 7.789e-04, Loss_res: 4.451e-04, Time: 0.25
# It: 38530, Loss: 8.542e-03, Loss_bcs: 5.965e-03, Loss_ics: 5.849e-04, Loss_res: 4.248e-04, Time: 0.24
# It: 38540, Loss: 9.055e-03, Loss_bcs: 6.485e-03, Loss_ics: 6.622e-04, Loss_res: 4.007e-04, Time: 0.24
# It: 38550, Loss: 9.970e-03, Loss_bcs: 7.386e-03, Loss_ics: 6.645e-04, Loss_res: 3.136e-04, Time: 0.24
# It: 38560, Loss: 9.767e-03, Loss_bcs: 6.930e-03, Loss_ics: 8.866e-04, Loss_res: 4.316e-04, Time: 0.24
# It: 38570, Loss: 9.052e-03, Loss_bcs: 5.947e-03, Loss_ics: 8.318e-04, Loss_res: 4.197e-04, Time: 0.24
# It: 38580, Loss: 8.350e-03, Loss_bcs: 5.412e-03, Loss_ics: 8.343e-04, Loss_res: 3.189e-04, Time: 0.24
# It: 38590, Loss: 9.887e-03, Loss_bcs: 6.929e-03, Loss_ics: 9.207e-04, Loss_res: 2.871e-04, Time: 0.24
# It: 38600, Loss: 8.014e-03, Loss_bcs: 5.230e-03, Loss_ics: 6.698e-04, Loss_res: 4.137e-04, Time: 0.28
# It: 38610, Loss: 9.391e-03, Loss_bcs: 6.524e-03, Loss_ics: 8.544e-04, Loss_res: 3.906e-04, Time: 0.24
# It: 38620, Loss: 1.044e-02, Loss_bcs: 7.603e-03, Loss_ics: 7.277e-04, Loss_res: 5.072e-04, Time: 0.25
# It: 38630, Loss: 9.510e-03, Loss_bcs: 6.676e-03, Loss_ics: 8.430e-04, Loss_res: 4.194e-04, Time: 0.26
# It: 38640, Loss: 8.195e-03, Loss_bcs: 5.313e-03, Loss_ics: 7.840e-04, Loss_res: 3.674e-04, Time: 0.24
# It: 38650, Loss: 8.054e-03, Loss_bcs: 5.433e-03, Loss_ics: 5.131e-04, Loss_res: 6.362e-04, Time: 0.26
# It: 38660, Loss: 7.770e-03, Loss_bcs: 4.804e-03, Loss_ics: 8.367e-04, Loss_res: 3.622e-04, Time: 0.25
# It: 38670, Loss: 8.776e-03, Loss_bcs: 5.718e-03, Loss_ics: 8.033e-04, Loss_res: 3.637e-04, Time: 0.24
# It: 38680, Loss: 9.375e-03, Loss_bcs: 6.372e-03, Loss_ics: 8.517e-04, Loss_res: 4.045e-04, Time: 0.25
# It: 38690, Loss: 8.781e-03, Loss_bcs: 5.891e-03, Loss_ics: 8.165e-04, Loss_res: 4.075e-04, Time: 0.25
# It: 38700, Loss: 1.032e-02, Loss_bcs: 7.659e-03, Loss_ics: 5.893e-04, Loss_res: 3.701e-04, Time: 0.25
# It: 38710, Loss: 8.494e-03, Loss_bcs: 5.467e-03, Loss_ics: 8.860e-04, Loss_res: 3.795e-04, Time: 0.24
# It: 38720, Loss: 8.871e-03, Loss_bcs: 5.919e-03, Loss_ics: 8.459e-04, Loss_res: 4.011e-04, Time: 0.25
# It: 38730, Loss: 8.698e-03, Loss_bcs: 5.990e-03, Loss_ics: 6.888e-04, Loss_res: 4.163e-04, Time: 0.24
# It: 38740, Loss: 8.769e-03, Loss_bcs: 5.823e-03, Loss_ics: 8.396e-04, Loss_res: 5.340e-04, Time: 0.24
# It: 38750, Loss: 8.506e-03, Loss_bcs: 5.474e-03, Loss_ics: 7.355e-04, Loss_res: 5.182e-04, Time: 0.24
# It: 38760, Loss: 9.255e-03, Loss_bcs: 6.369e-03, Loss_ics: 6.928e-04, Loss_res: 4.227e-04, Time: 0.24
# It: 38770, Loss: 1.000e-02, Loss_bcs: 7.237e-03, Loss_ics: 6.664e-04, Loss_res: 3.890e-04, Time: 0.26
# It: 38780, Loss: 8.855e-03, Loss_bcs: 6.278e-03, Loss_ics: 8.471e-04, Loss_res: 3.693e-04, Time: 0.24
# It: 38790, Loss: 9.998e-03, Loss_bcs: 6.987e-03, Loss_ics: 8.447e-04, Loss_res: 4.384e-04, Time: 0.24
# It: 38800, Loss: 1.056e-02, Loss_bcs: 7.687e-03, Loss_ics: 8.120e-04, Loss_res: 3.873e-04, Time: 0.25
# It: 38810, Loss: 9.005e-03, Loss_bcs: 6.191e-03, Loss_ics: 7.428e-04, Loss_res: 3.063e-04, Time: 0.25
# It: 38820, Loss: 9.141e-03, Loss_bcs: 6.168e-03, Loss_ics: 7.583e-04, Loss_res: 3.965e-04, Time: 0.24
# It: 38830, Loss: 7.370e-03, Loss_bcs: 4.666e-03, Loss_ics: 6.753e-04, Loss_res: 3.479e-04, Time: 0.26
# It: 38840, Loss: 9.660e-03, Loss_bcs: 6.982e-03, Loss_ics: 5.911e-04, Loss_res: 3.242e-04, Time: 0.25
# It: 38850, Loss: 8.845e-03, Loss_bcs: 5.797e-03, Loss_ics: 8.811e-04, Loss_res: 4.624e-04, Time: 0.25
# It: 38860, Loss: 8.564e-03, Loss_bcs: 5.691e-03, Loss_ics: 8.080e-04, Loss_res: 3.566e-04, Time: 0.25
# It: 38870, Loss: 8.420e-03, Loss_bcs: 5.730e-03, Loss_ics: 5.206e-04, Loss_res: 4.408e-04, Time: 0.24
# It: 38880, Loss: 9.827e-03, Loss_bcs: 6.677e-03, Loss_ics: 7.497e-04, Loss_res: 4.361e-04, Time: 0.24
# It: 38890, Loss: 1.172e-02, Loss_bcs: 8.697e-03, Loss_ics: 1.044e-03, Loss_res: 3.737e-04, Time: 0.24
# It: 38900, Loss: 9.123e-03, Loss_bcs: 6.041e-03, Loss_ics: 8.380e-04, Loss_res: 4.316e-04, Time: 0.25
# It: 38910, Loss: 7.182e-03, Loss_bcs: 4.648e-03, Loss_ics: 5.228e-04, Loss_res: 3.787e-04, Time: 0.24
# It: 38920, Loss: 8.553e-03, Loss_bcs: 5.629e-03, Loss_ics: 6.589e-04, Loss_res: 4.109e-04, Time: 0.24
# It: 38930, Loss: 8.034e-03, Loss_bcs: 5.310e-03, Loss_ics: 6.727e-04, Loss_res: 4.107e-04, Time: 0.24
# It: 38940, Loss: 8.665e-03, Loss_bcs: 6.169e-03, Loss_ics: 6.702e-04, Loss_res: 4.165e-04, Time: 0.27
# It: 38950, Loss: 1.005e-02, Loss_bcs: 6.987e-03, Loss_ics: 7.902e-04, Loss_res: 6.099e-04, Time: 0.24
# It: 38960, Loss: 9.023e-03, Loss_bcs: 6.048e-03, Loss_ics: 7.906e-04, Loss_res: 6.638e-04, Time: 0.25
# It: 38970, Loss: 7.644e-03, Loss_bcs: 5.098e-03, Loss_ics: 8.646e-04, Loss_res: 3.329e-04, Time: 0.25
# It: 38980, Loss: 8.310e-03, Loss_bcs: 5.490e-03, Loss_ics: 6.920e-04, Loss_res: 4.163e-04, Time: 0.25
# It: 38990, Loss: 1.041e-02, Loss_bcs: 7.711e-03, Loss_ics: 6.532e-04, Loss_res: 5.038e-04, Time: 0.27
# It: 39000, Loss: 7.650e-03, Loss_bcs: 4.604e-03, Loss_ics: 8.167e-04, Loss_res: 5.456e-04, Time: 0.24
# It: 39010, Loss: 8.338e-03, Loss_bcs: 5.450e-03, Loss_ics: 6.047e-04, Loss_res: 4.293e-04, Time: 0.24
# It: 39020, Loss: 8.293e-03, Loss_bcs: 5.407e-03, Loss_ics: 7.511e-04, Loss_res: 4.516e-04, Time: 0.24
# It: 39030, Loss: 1.005e-02, Loss_bcs: 7.326e-03, Loss_ics: 6.687e-04, Loss_res: 4.749e-04, Time: 0.24
# It: 39040, Loss: 9.231e-03, Loss_bcs: 6.569e-03, Loss_ics: 6.910e-04, Loss_res: 3.818e-04, Time: 0.24
# It: 39050, Loss: 8.868e-03, Loss_bcs: 5.802e-03, Loss_ics: 8.016e-04, Loss_res: 3.103e-04, Time: 0.25
# It: 39060, Loss: 1.012e-02, Loss_bcs: 7.141e-03, Loss_ics: 8.065e-04, Loss_res: 3.119e-04, Time: 0.25
# It: 39070, Loss: 8.996e-03, Loss_bcs: 5.943e-03, Loss_ics: 7.649e-04, Loss_res: 4.880e-04, Time: 0.24
# It: 39080, Loss: 9.067e-03, Loss_bcs: 6.422e-03, Loss_ics: 7.778e-04, Loss_res: 3.582e-04, Time: 0.25
# It: 39090, Loss: 1.084e-02, Loss_bcs: 8.133e-03, Loss_ics: 6.569e-04, Loss_res: 3.426e-04, Time: 0.24
# It: 39100, Loss: 8.102e-03, Loss_bcs: 5.541e-03, Loss_ics: 5.741e-04, Loss_res: 3.990e-04, Time: 0.24
# It: 39110, Loss: 8.087e-03, Loss_bcs: 5.274e-03, Loss_ics: 9.237e-04, Loss_res: 4.067e-04, Time: 0.24
# It: 39120, Loss: 8.057e-03, Loss_bcs: 5.081e-03, Loss_ics: 8.205e-04, Loss_res: 4.497e-04, Time: 0.24
# It: 39130, Loss: 9.797e-03, Loss_bcs: 7.119e-03, Loss_ics: 6.555e-04, Loss_res: 4.036e-04, Time: 0.25
# It: 39140, Loss: 9.719e-03, Loss_bcs: 6.926e-03, Loss_ics: 9.247e-04, Loss_res: 3.157e-04, Time: 0.24
# It: 39150, Loss: 8.119e-03, Loss_bcs: 4.859e-03, Loss_ics: 8.836e-04, Loss_res: 5.874e-04, Time: 0.26
# It: 39160, Loss: 9.971e-03, Loss_bcs: 7.014e-03, Loss_ics: 9.129e-04, Loss_res: 3.653e-04, Time: 0.26
# It: 39170, Loss: 9.541e-03, Loss_bcs: 6.742e-03, Loss_ics: 8.560e-04, Loss_res: 3.070e-04, Time: 0.25
# It: 39180, Loss: 7.988e-03, Loss_bcs: 5.321e-03, Loss_ics: 6.925e-04, Loss_res: 3.390e-04, Time: 0.23
# It: 39190, Loss: 9.192e-03, Loss_bcs: 6.114e-03, Loss_ics: 9.117e-04, Loss_res: 4.257e-04, Time: 0.25
# It: 39200, Loss: 7.186e-03, Loss_bcs: 4.425e-03, Loss_ics: 7.009e-04, Loss_res: 4.746e-04, Time: 0.24
# It: 39210, Loss: 1.014e-02, Loss_bcs: 7.009e-03, Loss_ics: 7.457e-04, Loss_res: 6.202e-04, Time: 0.26
# It: 39220, Loss: 8.322e-03, Loss_bcs: 5.351e-03, Loss_ics: 7.855e-04, Loss_res: 4.442e-04, Time: 0.24
# It: 39230, Loss: 9.090e-03, Loss_bcs: 5.951e-03, Loss_ics: 8.979e-04, Loss_res: 4.543e-04, Time: 0.24
# It: 39240, Loss: 7.993e-03, Loss_bcs: 5.375e-03, Loss_ics: 7.096e-04, Loss_res: 3.868e-04, Time: 0.24
# It: 39250, Loss: 8.497e-03, Loss_bcs: 5.969e-03, Loss_ics: 6.017e-04, Loss_res: 2.901e-04, Time: 0.25
# It: 39260, Loss: 7.727e-03, Loss_bcs: 5.023e-03, Loss_ics: 5.408e-04, Loss_res: 4.634e-04, Time: 0.25
# It: 39270, Loss: 8.513e-03, Loss_bcs: 5.813e-03, Loss_ics: 5.662e-04, Loss_res: 3.955e-04, Time: 0.25
# It: 39280, Loss: 8.004e-03, Loss_bcs: 5.221e-03, Loss_ics: 9.988e-04, Loss_res: 4.087e-04, Time: 0.24
# It: 39290, Loss: 8.886e-03, Loss_bcs: 5.897e-03, Loss_ics: 6.676e-04, Loss_res: 6.311e-04, Time: 0.24
# It: 39300, Loss: 8.747e-03, Loss_bcs: 5.576e-03, Loss_ics: 8.530e-04, Loss_res: 4.392e-04, Time: 0.24
# It: 39310, Loss: 9.486e-03, Loss_bcs: 6.693e-03, Loss_ics: 6.521e-04, Loss_res: 5.880e-04, Time: 0.24
# It: 39320, Loss: 8.721e-03, Loss_bcs: 6.032e-03, Loss_ics: 7.323e-04, Loss_res: 4.121e-04, Time: 0.24
# It: 39330, Loss: 1.038e-02, Loss_bcs: 7.221e-03, Loss_ics: 7.340e-04, Loss_res: 4.759e-04, Time: 0.26
# It: 39340, Loss: 8.759e-03, Loss_bcs: 6.095e-03, Loss_ics: 7.985e-04, Loss_res: 4.745e-04, Time: 0.24
# It: 39350, Loss: 8.550e-03, Loss_bcs: 5.472e-03, Loss_ics: 9.253e-04, Loss_res: 4.930e-04, Time: 0.24
# It: 39360, Loss: 8.547e-03, Loss_bcs: 5.904e-03, Loss_ics: 6.830e-04, Loss_res: 4.530e-04, Time: 0.25
# It: 39370, Loss: 8.382e-03, Loss_bcs: 5.781e-03, Loss_ics: 7.303e-04, Loss_res: 3.460e-04, Time: 0.25
# It: 39380, Loss: 9.386e-03, Loss_bcs: 6.517e-03, Loss_ics: 8.887e-04, Loss_res: 3.474e-04, Time: 0.24
# It: 39390, Loss: 7.916e-03, Loss_bcs: 4.953e-03, Loss_ics: 7.490e-04, Loss_res: 4.394e-04, Time: 0.25
# It: 39400, Loss: 8.133e-03, Loss_bcs: 5.241e-03, Loss_ics: 8.931e-04, Loss_res: 2.765e-04, Time: 0.25
# It: 39410, Loss: 9.332e-03, Loss_bcs: 6.472e-03, Loss_ics: 6.884e-04, Loss_res: 3.760e-04, Time: 0.25
# It: 39420, Loss: 7.560e-03, Loss_bcs: 5.213e-03, Loss_ics: 5.506e-04, Loss_res: 3.371e-04, Time: 0.24
# It: 39430, Loss: 8.973e-03, Loss_bcs: 5.972e-03, Loss_ics: 9.650e-04, Loss_res: 3.844e-04, Time: 0.23
# It: 39440, Loss: 1.290e-02, Loss_bcs: 7.067e-03, Loss_ics: 5.322e-04, Loss_res: 3.724e-03, Time: 0.24
# It: 39450, Loss: 9.297e-03, Loss_bcs: 6.318e-03, Loss_ics: 6.310e-04, Loss_res: 6.929e-04, Time: 0.24
# It: 39460, Loss: 8.595e-03, Loss_bcs: 5.783e-03, Loss_ics: 5.608e-04, Loss_res: 5.627e-04, Time: 0.24
# It: 39470, Loss: 8.169e-03, Loss_bcs: 5.436e-03, Loss_ics: 6.311e-04, Loss_res: 3.614e-04, Time: 0.25
# It: 39480, Loss: 1.075e-02, Loss_bcs: 7.398e-03, Loss_ics: 8.684e-04, Loss_res: 5.350e-04, Time: 0.26
# It: 39490, Loss: 9.591e-03, Loss_bcs: 6.788e-03, Loss_ics: 8.090e-04, Loss_res: 3.407e-04, Time: 0.26
# It: 39500, Loss: 8.796e-03, Loss_bcs: 5.915e-03, Loss_ics: 8.638e-04, Loss_res: 5.057e-04, Time: 0.27
# It: 39510, Loss: 1.025e-02, Loss_bcs: 7.200e-03, Loss_ics: 9.334e-04, Loss_res: 3.286e-04, Time: 0.25
# It: 39520, Loss: 8.050e-03, Loss_bcs: 5.136e-03, Loss_ics: 8.180e-04, Loss_res: 3.519e-04, Time: 0.24
# It: 39530, Loss: 9.069e-03, Loss_bcs: 6.182e-03, Loss_ics: 9.202e-04, Loss_res: 4.341e-04, Time: 0.24
# It: 39540, Loss: 8.783e-03, Loss_bcs: 5.993e-03, Loss_ics: 6.893e-04, Loss_res: 3.471e-04, Time: 0.25
# It: 39550, Loss: 1.011e-02, Loss_bcs: 7.459e-03, Loss_ics: 7.139e-04, Loss_res: 3.631e-04, Time: 0.23
# It: 39560, Loss: 8.877e-03, Loss_bcs: 5.861e-03, Loss_ics: 1.037e-03, Loss_res: 3.447e-04, Time: 0.24
# It: 39570, Loss: 9.002e-03, Loss_bcs: 6.009e-03, Loss_ics: 8.221e-04, Loss_res: 3.589e-04, Time: 0.24
# It: 39580, Loss: 8.624e-03, Loss_bcs: 5.884e-03, Loss_ics: 5.905e-04, Loss_res: 5.073e-04, Time: 0.23
# It: 39590, Loss: 8.654e-03, Loss_bcs: 5.998e-03, Loss_ics: 7.073e-04, Loss_res: 4.014e-04, Time: 0.24
# It: 39600, Loss: 9.396e-03, Loss_bcs: 6.594e-03, Loss_ics: 6.078e-04, Loss_res: 4.244e-04, Time: 0.25
# It: 39610, Loss: 9.064e-03, Loss_bcs: 6.200e-03, Loss_ics: 5.918e-04, Loss_res: 5.333e-04, Time: 0.24
# It: 39620, Loss: 8.242e-03, Loss_bcs: 5.447e-03, Loss_ics: 7.785e-04, Loss_res: 4.093e-04, Time: 0.24
# It: 39630, Loss: 8.724e-03, Loss_bcs: 6.329e-03, Loss_ics: 5.046e-04, Loss_res: 3.222e-04, Time: 0.24
# It: 39640, Loss: 7.750e-03, Loss_bcs: 4.973e-03, Loss_ics: 7.415e-04, Loss_res: 3.238e-04, Time: 0.25
# It: 39650, Loss: 1.005e-02, Loss_bcs: 7.071e-03, Loss_ics: 7.524e-04, Loss_res: 4.624e-04, Time: 0.25
# It: 39660, Loss: 9.762e-03, Loss_bcs: 7.037e-03, Loss_ics: 8.324e-04, Loss_res: 4.187e-04, Time: 0.23
# It: 39670, Loss: 9.624e-03, Loss_bcs: 7.058e-03, Loss_ics: 6.410e-04, Loss_res: 3.606e-04, Time: 0.24
# It: 39680, Loss: 8.506e-03, Loss_bcs: 5.545e-03, Loss_ics: 9.982e-04, Loss_res: 3.505e-04, Time: 0.26
# It: 39690, Loss: 9.063e-03, Loss_bcs: 6.141e-03, Loss_ics: 8.300e-04, Loss_res: 4.137e-04, Time: 0.25
# It: 39700, Loss: 8.279e-03, Loss_bcs: 5.693e-03, Loss_ics: 5.374e-04, Loss_res: 3.955e-04, Time: 0.24
# It: 39710, Loss: 8.303e-03, Loss_bcs: 5.722e-03, Loss_ics: 7.067e-04, Loss_res: 3.800e-04, Time: 0.24
# It: 39720, Loss: 7.386e-03, Loss_bcs: 4.633e-03, Loss_ics: 7.936e-04, Loss_res: 3.993e-04, Time: 0.25
# It: 39730, Loss: 7.168e-03, Loss_bcs: 4.366e-03, Loss_ics: 7.181e-04, Loss_res: 3.618e-04, Time: 0.25
# It: 39740, Loss: 9.501e-03, Loss_bcs: 6.686e-03, Loss_ics: 6.581e-04, Loss_res: 3.986e-04, Time: 0.24
# It: 39750, Loss: 8.704e-03, Loss_bcs: 5.856e-03, Loss_ics: 9.437e-04, Loss_res: 3.102e-04, Time: 0.25
# It: 39760, Loss: 8.945e-03, Loss_bcs: 6.176e-03, Loss_ics: 7.544e-04, Loss_res: 3.666e-04, Time: 0.25
# It: 39770, Loss: 9.668e-03, Loss_bcs: 6.794e-03, Loss_ics: 8.467e-04, Loss_res: 3.313e-04, Time: 0.24
# It: 39780, Loss: 8.173e-03, Loss_bcs: 5.384e-03, Loss_ics: 6.559e-04, Loss_res: 4.620e-04, Time: 0.24
# It: 39790, Loss: 9.109e-03, Loss_bcs: 6.050e-03, Loss_ics: 8.439e-04, Loss_res: 4.938e-04, Time: 0.26
# It: 39800, Loss: 9.447e-03, Loss_bcs: 6.421e-03, Loss_ics: 9.223e-04, Loss_res: 3.757e-04, Time: 0.26
# It: 39810, Loss: 8.874e-03, Loss_bcs: 5.978e-03, Loss_ics: 8.885e-04, Loss_res: 3.590e-04, Time: 0.24
# It: 39820, Loss: 7.475e-03, Loss_bcs: 4.825e-03, Loss_ics: 5.473e-04, Loss_res: 4.374e-04, Time: 0.25
# It: 39830, Loss: 9.740e-03, Loss_bcs: 6.880e-03, Loss_ics: 8.824e-04, Loss_res: 3.129e-04, Time: 0.24
# It: 39840, Loss: 9.882e-03, Loss_bcs: 7.246e-03, Loss_ics: 5.319e-04, Loss_res: 3.447e-04, Time: 0.25
# It: 39850, Loss: 9.165e-03, Loss_bcs: 6.105e-03, Loss_ics: 9.021e-04, Loss_res: 4.005e-04, Time: 0.24
# It: 39860, Loss: 9.787e-03, Loss_bcs: 7.149e-03, Loss_ics: 7.481e-04, Loss_res: 4.332e-04, Time: 0.24
# It: 39870, Loss: 8.323e-03, Loss_bcs: 5.804e-03, Loss_ics: 6.572e-04, Loss_res: 3.521e-04, Time: 0.24
# It: 39880, Loss: 9.054e-03, Loss_bcs: 6.256e-03, Loss_ics: 7.002e-04, Loss_res: 3.771e-04, Time: 0.24
# It: 39890, Loss: 9.198e-03, Loss_bcs: 6.432e-03, Loss_ics: 6.090e-04, Loss_res: 4.009e-04, Time: 0.25
# It: 39900, Loss: 9.153e-03, Loss_bcs: 6.151e-03, Loss_ics: 8.873e-04, Loss_res: 4.273e-04, Time: 0.25
# It: 39910, Loss: 8.130e-03, Loss_bcs: 5.369e-03, Loss_ics: 9.033e-04, Loss_res: 3.163e-04, Time: 0.26
# It: 39920, Loss: 9.392e-03, Loss_bcs: 6.840e-03, Loss_ics: 4.975e-04, Loss_res: 5.176e-04, Time: 0.24
# It: 39930, Loss: 9.541e-03, Loss_bcs: 6.447e-03, Loss_ics: 8.575e-04, Loss_res: 4.619e-04, Time: 0.26
# It: 39940, Loss: 9.304e-03, Loss_bcs: 6.393e-03, Loss_ics: 7.346e-04, Loss_res: 5.845e-04, Time: 0.25
# It: 39950, Loss: 8.516e-03, Loss_bcs: 5.652e-03, Loss_ics: 8.325e-04, Loss_res: 4.020e-04, Time: 0.27
# It: 39960, Loss: 8.874e-03, Loss_bcs: 5.812e-03, Loss_ics: 8.887e-04, Loss_res: 3.740e-04, Time: 0.26
# It: 39970, Loss: 1.045e-02, Loss_bcs: 7.574e-03, Loss_ics: 7.059e-04, Loss_res: 4.355e-04, Time: 0.25
# It: 39980, Loss: 8.513e-03, Loss_bcs: 5.751e-03, Loss_ics: 7.955e-04, Loss_res: 4.419e-04, Time: 0.26
# It: 39990, Loss: 7.987e-03, Loss_bcs: 5.151e-03, Loss_ics: 8.005e-04, Loss_res: 3.461e-04, Time: 0.26
# The relative errror is: 1.308814e-02

# %%
from matplotlib.animation import FuncAnimation
from IPython.display import HTML
font = {'size' : 10}

matplotlib.rc('font', **font)

fig = plt.figure(figsize=(18, 5))

from mpl_toolkits.axes_grid1 import make_axes_locatable

ax1 = plt.subplot(1,3,1)   
ax2 = plt.subplot(1, 3, 2)
ax3 = plt.subplot(1, 3, 3)



txt_title_1 = ax1.set_title('')
ax1.set_xlabel(r'$x$')
ax1.set_ylabel(r'$y$')

txt_title_2 = ax2.set_title('')
ax2.set_xlabel(r'$x$')
ax2.set_ylabel(r'$y$')

txt_title_3 = ax3.set_title('')
ax3.set_xlabel(r'$x$')
ax3.set_ylabel(r'$y$')

x = np.linspace(0, 3, 200)[:, None]
y = np.linspace(dom_coords[0, 1], dom_coords[1, 1], 200)[:, None]
t = np.linspace(dom_coords[0, 2], dom_coords[1, 2], 100)[:, None]

X, Y = np.meshgrid(x, y)
T_star = 0 * np.ones_like(X)
X_star = np.hstack((X.flatten()[:, None], Y.flatten()[:, None], T_star.flatten()[:, None]))

u_star = u(X_star)
u_pred = model.predict_u(X_star)

X_star = np.hstack((X.flatten()[:, None], Y.flatten()[:, None]))

U_star = griddata(X_star, u_star.flatten(), (X, Y), method='cubic')
U_pred = griddata(X_star, u_pred.flatten(), (X, Y), method='cubic')

            
pcol_plot1 = ax1.pcolormesh(X, Y, U_star, cmap='jet', vmin=-2, vmax=7)
divider = make_axes_locatable(ax1)
cax1 = divider.append_axes('right', size='5%', pad=0.1)
plt.colorbar(pcol_plot1, cax=cax1)

pcol_plot2 = ax2.pcolormesh(X, Y, U_pred, cmap='jet', vmin=-2, vmax=7)
divider = make_axes_locatable(ax2)
cax2 = divider.append_axes('right', size='5%', pad=0.1)
plt.colorbar(pcol_plot2, cax=cax2)

pcol_plot3 = ax3.pcolormesh(X, Y, np.abs(U_star - U_pred), cmap='jet', vmin=0.005, vmax=0.07)
divider = make_axes_locatable(ax3)
cax3 = divider.append_axes('right', size='5%', pad=0.1)
plt.colorbar(pcol_plot3, cax=cax3, format='%.0e')

def animate(T):

  T = T[0]


  X, Y = np.meshgrid(x, y)
  T_star = T * np.ones_like(X)
  X_star = np.hstack((X.flatten()[:, None], Y.flatten()[:, None], T_star.flatten()[:, None]))
  
  u_star = u(X_star)
  u_pred = model.predict_u(X_star)
  
  X_star = np.hstack((X.flatten()[:, None], Y.flatten()[:, None]))
  
  U_star = griddata(X_star, u_star.flatten(), (X, Y), method='cubic')
  U_pred = griddata(X_star, u_pred.flatten(), (X, Y), method='cubic')


  ax1.clear()
  ax2.clear()
  ax3.clear()

  ytemp = np.linspace(dom_coords[0, 1], dom_coords[1, 1], nn)[:, None]
  t = T * np.ones_like(ytemp)
  ytemp, t = np.meshgrid(ytemp, t)

  
  X_star = np.hstack((ytemp.flatten()[:, None], t.flatten()[:, None]))
  
  s_star = s(X_star)

  pcol_plot1 = ax1.pcolormesh(X, Y, U_star, cmap='jet', vmin=-2, vmax=7)
  ax1.plot(s_star, ytemp.flatten(), color='black', linewidth=2)

  pcol_plot2 = ax2.pcolormesh(X, Y, U_pred, cmap='jet', vmin=-2, vmax=7)
  ax2.plot(s_star, ytemp.flatten(), color='black', linewidth=2)

  pcol_plot3 = ax3.pcolormesh(X, Y, np.abs(U_star - U_pred), cmap='jet', vmin=0.005, vmax=0.07)

  ax1.set_title('Exact $u(x, y, {})$'.format(np.round(T, 2)))
  ax2.set_title('Predicted  $u(x, y, {})$'.format(np.round(T, 2)))
  ax3.set_title('Absolute Error')


anim = FuncAnimation(fig, animate, frames=t, repeat=False, interval=20)
HTML(anim.to_html5_video())
# Out:
# <video width="1296" height="360" controls autoplay>
#   <source type="video/mp4" src="...
