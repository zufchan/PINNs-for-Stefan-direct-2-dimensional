# %% [markdown]
# <a href="https://colab.research.google.com/github/zufchan/PINNs-for-Stefan/blob/main/2d2p_Test_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
import timeit
from scipy.special import erf, erfc

g = 0.479611
t_0 = 0.695571


class Sampler:
    # Initialize the class
    def __init__(self, dim, coords, func, name=None):
        self.dim = dim
        self.coords = coords
        self.func = func
        self.name = name

    def sample(self, N):
        x = self.coords[0:1, :] + (self.coords[1:2, :] - self.coords[0:1, :]) * np.random.uniform(0, 1,
                                                                                                  size=(N, self.dim))
        y = self.func(x)
        return x, y


class DataSampler:
    # Initialize the class
    def __init__(self, X, Y, name=None):
        self.X = X
        self.Y = Y
        self.N = self.X.shape[0]

    def sample(self, batch_size):
        idx = np.random.choice(self.N, batch_size, replace=True)
        X_batch = self.X[idx, :]
        Y_batch = self.Y[idx, :]
        return X_batch, Y_batch


class Stefan2D_direct:
    def __init__(self, layers_u, layers_s, ics_sampler, bcs_sampler, res_sampler):
        # Normalization constants
        X, _ = res_sampler.sample(np.int32(1e5))
        self.mu_X, self.sigma_X = X.mean(0), X.std(0)
        self.mu_x, self.sigma_x = self.mu_X[0], self.sigma_X[0]
        self.mu_y, self.sigma_y = self.mu_X[1], self.sigma_X[1]
        self.mu_t, self.sigma_t = self.mu_X[2], self.sigma_X[2]
        
        self.error_s_list = [] 
        self.error_u_list = []
        
        # Samplers
        self.ics_sampler = ics_sampler
        self.bcs_sampler = bcs_sampler
        self.res_sampler = res_sampler

        # Initialize network weights and biases
        with tf.variable_scope('layers'):
          self.layers_u = layers_u

          self.weights_u, self.biases_u = self.initialize_NN(layers_u)
          
          # Initialize encoder weights and biases
          self.layers_s = layers_s
          self.weights_s, self.biases_s = self.initialize_NN(layers_s)

        # Define Tensorflow session
        self.sess = tf.Session(config=tf.ConfigProto(log_device_placement=True))

        with tf.variable_scope('input'):
        # Define placeholders and computational graph
          self.x_u_tf = tf.placeholder(tf.float32, shape=(None, 1))  
          self.y_u_tf = tf.placeholder(tf.float32, shape=(None, 1))  
          self.t_u_tf = tf.placeholder(tf.float32, shape=(None, 1)) 
          self.u_tf = tf.placeholder(tf.float32, shape=(None, 1)) 
          self.s_tf = tf.placeholder(tf.float32, shape=(None, 1))

        #with tf.variable_scope('boundary_conditions_1'):
          self.x_bc1_tf = tf.placeholder(tf.float32, shape=(None, 1))
          self.y_bc1_tf = tf.placeholder(tf.float32, shape=(None, 1))
          self.t_bc1_tf = tf.placeholder(tf.float32, shape=(None, 1))
          self.u_bc1_tf = tf.placeholder(tf.float32, shape=(None, 1))

        #with tf.variable_scope('boundary_conditions_2'):
          self.x_bc2_tf = tf.placeholder(tf.float32, shape=(None, 1))
          self.y_bc2_tf = tf.placeholder(tf.float32, shape=(None, 1))
          self.t_bc2_tf = tf.placeholder(tf.float32, shape=(None, 1))
          self.u_bc2_tf = tf.placeholder(tf.float32, shape=(None, 1))
        
        #with tf.variable_scope('boundary_conditions_3'):
          self.x_bc3_tf = tf.placeholder(tf.float32, shape=(None, 1))
          self.y_bc3_tf = tf.placeholder(tf.float32, shape=(None, 1))
          self.t_bc3_tf = tf.placeholder(tf.float32, shape=(None, 1))
          self.u_bc3_tf = tf.placeholder(tf.float32, shape=(None, 1))

        #with tf.variable_scope('boundary_conditions_4'):
          self.x_bc4_tf = tf.placeholder(tf.float32, shape=(None, 1))
          self.y_bc4_tf = tf.placeholder(tf.float32, shape=(None, 1))
          self.t_bc4_tf = tf.placeholder(tf.float32, shape=(None, 1))
          self.u_bc4_tf = tf.placeholder(tf.float32, shape=(None, 1))

        #with tf.variable_scope('initial_conditions'):
          self.x_ic1_tf = tf.placeholder(tf.float32, shape=(None, 1))
          self.y_ic1_tf = tf.placeholder(tf.float32, shape=(None, 1))
          self.t_ic1_tf = tf.placeholder(tf.float32, shape=(None, 1))
          self.u_ic1_tf = tf.placeholder(tf.float32, shape=(None, 1))  
          self.s_ic1_tf = tf.placeholder(tf.float32, shape=(None, 1))  

        #with tf.variable_scope('initial_conditions'):
          self.x_ic2_tf = tf.placeholder(tf.float32, shape=(None, 1))
          self.y_ic2_tf = tf.placeholder(tf.float32, shape=(None, 1))
          self.t_ic2_tf = tf.placeholder(tf.float32, shape=(None, 1))
          self.u_ic2_tf = tf.placeholder(tf.float32, shape=(None, 1))  
          self.s_ic2_tf = tf.placeholder(tf.float32, shape=(None, 1))  

        #with tf.variable_scope('Normalization_constants'):
          self.y_Nc_tf = tf.placeholder(tf.float32, shape=(None, 1))
          self.t_Nc_tf = tf.placeholder(tf.float32, shape=(None, 1))
          self.u_Nc_tf = tf.placeholder(tf.float32, shape=(None, 1))

        #with tf.variable_scope('residual_conditions'):
          self.x_r_tf = tf.placeholder(tf.float32, shape=(None, 1))
          self.y_r_tf = tf.placeholder(tf.float32, shape=(None, 1))
          self.t_r_tf = tf.placeholder(tf.float32, shape=(None, 1))


        # Evaluate predictions
        self.s_pred = self.net_s(self.y_u_tf, self.t_u_tf)
        self.s_0_pred = self.net_s(self.y_ic1_tf, self.t_ic1_tf)

        # self.u_pred = self.net_u(self.x_u_tf, self.y_u_tf, self.t_u_tf)
        self.u1_pred, self.u2_pred = self.net_u1u2(self.x_u_tf, self.y_u_tf, self.t_u_tf)
        self.u_pred = self.net_u(self.x_u_tf, self.y_u_tf, self.t_u_tf)

        # self.u_0_pred = self.net_u(self.x_0_tf, self.y_0_tf, self.t_0_tf)
        self.u1_0_pred,_ = self.net_u1u2(self.x_ic1_tf, self.y_ic1_tf, self.t_ic1_tf)
        _, self.u2_0_pred = self.net_u1u2(self.x_ic2_tf, self.y_ic2_tf, self.t_ic2_tf)

        #2131231231

        self.u_bc1_pred = self.net_u(self.x_bc1_tf, self.y_bc1_tf, self.t_bc1_tf)
        self.u_bc2_pred,_ = self.net_u1u2(self.x_bc2_tf, self.y_bc2_tf, self.t_bc2_tf)
        self.u_bc3_pred = self.net_u(self.x_bc3_tf, self.y_bc3_tf, self.t_bc3_tf)
        _,self.u_bc4_pred = self.net_u1u2(self.x_bc4_tf, self.y_bc4_tf, self.t_bc4_tf)
        
        self.S_bc1_pred, self.S_bc2_pred = self.net_u1u2((self.s_pred - self.mu_x) / self.sigma_x,
                                    self.y_u_tf,
                                    self.t_u_tf)
        self.r_Nc_pred = self.net_r_Nc(self.y_Nc_tf, self.t_Nc_tf)
        self.r_u1_pred, self.r_u2_pred = self.net_r_u1u2(self.x_r_tf, self.y_r_tf, self.t_r_tf)

        # Stefan Boundary loss
        with tf.variable_scope('loss'):

          #      changed
          self.loss_Sbc1 = tf.reduce_mean(tf.square(self.S_bc1_pred))
          self.loss_Sbc2 = tf.reduce_mean(tf.square(self.S_bc2_pred))

          self.loss_s_0 = tf.reduce_mean(tf.square(self.s_0_pred - (g * np.sqrt(t_0) +  (self.y_ic1_tf * self.sigma_y + self.mu_y)))) # s(y, 0) = y/2   + 1/2
          self.loss_SNc = tf.reduce_mean(tf.square(self.r_Nc_pred)) 

          # Boundary and Initial loss
          self.loss_u_bc1 = tf.reduce_mean(tf.square(self.u_bc1_pred- self.u_bc1_tf))
          self.loss_u_bc2 = tf.reduce_mean(tf.square(self.u_bc2_pred- self.u_bc2_tf))
          self.loss_u_bc3 = tf.reduce_mean(tf.square(self.u_bc3_pred- self.u_bc3_tf))
          self.loss_u_bc4 = tf.reduce_mean(tf.square(self.u_bc4_pred- self.u_bc4_tf))

          self.loss_u1_ic = tf.reduce_mean(tf.square(self.u1_0_pred - self.u_ic1_tf))
          self.loss_u2_ic = tf.reduce_mean(tf.square(self.u2_0_pred - self.u_ic2_tf))
          self.loss_u_ic = self.loss_u1_ic + self.loss_u2_ic

          self.loss_u_bcs = self.loss_u_bc1 + self.loss_u_bc2 + self.loss_u_bc3 + self.loss_u_bc4
          # Stefan loss
          self.loss_Scs = self.loss_Sbc1 + self.loss_Sbc2 + self.loss_s_0 + self.loss_SNc 


          # Residual loss
          self.loss_res_u1 = tf.reduce_mean(tf.square(self.r_u1_pred))
          self.loss_res_u2 = tf.reduce_mean(tf.square(self.r_u2_pred))  # u_t - u_xx = 0
          self.loss_res = self.loss_res_u1 + self.loss_res_u2

          # Total loss
          self.loss = self.loss_u_bcs + self.loss_u_ic + self.loss_Scs + self.loss_res

        with tf.variable_scope('residual_conditions'):
          tf.summary.scalar('loss', self.loss)
          tf.summary.histogram(name="distribution", values=self.loss)
          tf.summary.scalar('loss_SNc', self.loss_SNc)
          tf.summary.scalar('loss_s_0', self.loss_s_0)
          tf.summary.scalar('loss_u_bcs', self.loss_u_bcs)
          tf.summary.scalar('loss_u_ic', self.loss_u_ic)
          tf.summary.scalar('loss_res', self.loss_res)
          self.summary = tf.summary.merge_all()
        
        # Define optimizer with learning rate schedule
        with tf.variable_scope('train'):
          self.global_step = tf.Variable(0, trainable=False)
          starter_learning_rate = 1e-3
          self.learning_rate = tf.train.exponential_decay(starter_learning_rate, self.global_step,
                                                          1000, 0.9, staircase=False)
        # Passing global_step to minimize() will increment it at each step
          self.train_op = tf.train.AdamOptimizer(self.learning_rate).minimize(self.loss, global_step=self.global_step)

        self.loss_u_bcs_log = []
        self.loss_u_ic_log = []
        self.loss_res_log = []
        self.saver = tf.train.Saver()
        
        # Initialize Tensorflow variables
        init = tf.global_variables_initializer()
        self.sess.run(init)
        self.training_writer = tf.summary.FileWriter('./logs/training', self.sess.graph)
        #self.testing_writer = tf.summary.FileWriter('./logs/testing', self.sess.graph)

     # Xavier initialization
    def xavier_init(self, size):
        in_dim = size[0]
        out_dim = size[1]
        xavier_stddev = 1. / np.sqrt((in_dim + out_dim) / 2.)
        return tf.Variable(tf.random_normal([in_dim, out_dim], dtype=tf.float32) * xavier_stddev,
                           dtype=tf.float32)

    # Initialize network weights and biases using Xavier initialization
    def initialize_NN(self, layers):
        weights = []
        biases = []
        num_layers = len(layers)
        for l in range(0, num_layers - 1):
          
            W = self.xavier_init(size=[layers[l], layers[l + 1]])
            b = tf.Variable(tf.zeros([1, layers[l + 1]], dtype=tf.float32), dtype=tf.float32)
            weights.append(W)
            biases.append(b)
        return weights, biases

    # Evaluates the forward pass
    def forward_pass_u(self, H):
        num_layers = len(self.layers_u)
        for l in range(0, num_layers - 2):
          
            W = self.weights_u[l]
            b = self.biases_u[l]
            H = tf.tanh(tf.add(tf.matmul(H, W), b))
        W = self.weights_u[-1]
        b = self.biases_u[-1]
        H = tf.add(tf.matmul(H, W), b)
        return H
    
    def forward_pass_s(self, H):
        num_layers = len(self.layers_s)
        for l in range(0, num_layers - 2):
         
            W = self.weights_s[l]
            b = self.biases_s[l]
            H = tf.tanh(tf.add(tf.matmul(H, W), b))
        W = self.weights_s[-1]
        b = self.biases_s[-1]
        H = tf.add(tf.matmul(H, W), b)
        return H

     # Forward pass for u
    def net_u1u2(self, x, y, t):
        u = self.forward_pass_u(tf.concat([x, y, t], 1))
        u1 = u[:,0:1]
        u2 = u[:,1:2]
        return u1, u2

     # Forward pass for s
    def net_s(self, y, t):
        s = self.forward_pass_s(tf.concat([y, t], 1))
        return s

    def net_u1u2_x(self, x, y, t):
        u = self.forward_pass_u(tf.concat([x, y, t], 1))

        u1 = u[:,0:1]
        u2 = u[:,1:2]

        u1_x = tf.gradients(u1, x)[0] / self.sigma_x
        u1_y = tf.gradients(u1, y)[0] / self.sigma_y
        u2_x = tf.gradients(u2, x)[0] / self.sigma_x
        u2_y = tf.gradients(u2, y)[0] / self.sigma_y
        return  u1_x, u2_x, u1_y, u2_y

    def net_u(self, x, y, t):
        u1, u2 = self.net_u1u2(x, y, t)
        s = self.net_s(y, t)  # consider normalization

        # demoralizing x coordinates
        x_hat = x * self.sigma_x + self.mu_x
        # consider s = x_hat
        u = tf.multiply(u1, 0.5 * (tf.sign(s - x_hat) + 1)) + tf.multiply(u2, 0.5 * (tf.sign(x_hat - s) + 1))
        return u

    # Forward pass for residual
    def net_r_u1u2(self, x, y, t):
        u1,u2 = self.net_u1u2(x, y, t)
        u1_t = tf.gradients(u1, t)[0] / self.sigma_t

        u1_x = tf.gradients(u1, x)[0] / self.sigma_x
        u1_y = tf.gradients(u1, y)[0] / self.sigma_y

        u1_xx = tf.gradients(u1_x, x)[0] / self.sigma_x
        u1_yy = tf.gradients(u1_y, y)[0] / self.sigma_y
        r_u1 = u1_t - 0.5 * (u1_xx + u1_yy) #1

        u2_t = tf.gradients(u2, t)[0] / self.sigma_t

        u2_x = tf.gradients(u2, x)[0] / self.sigma_x
        u2_y = tf.gradients(u2, y)[0] / self.sigma_y

        u2_xx = tf.gradients(u2_x, x)[0] / self.sigma_x
        u2_yy = tf.gradients(u2_y, y)[0] / self.sigma_y
        r_u2 = u2_t - 1 * (u2_xx + u2_yy) #2

        return r_u1, r_u2

    def net_r_Nc(self, y, t):
        s = self.net_s(y, t)
        s_y = tf.gradients(s, y)[0] / self.sigma_y
        s_t = tf.gradients(s, t)[0] / self.sigma_t

        # Normalizing s
        s = (s - self.mu_x) / self.sigma_x
        u1_x, u2_x, u1_y, u2_y = self.net_u1u2_x(s, y, t) #* self.sigma_y + self.mu_y

        residual =  s_t - 0.252612 * (u1_x - u1_y * s_y) + np.sqrt(2) * (u2_x - u2_y * s_y)

        # residual = s_t + 7/(2*np.sqrt(5)) * np.sqrt(5/4) - 3/(np.sqrt(5)) * np.sqrt(5)
        return residual

    def fetch_minibatch(self, sampler, N):
        X, Y = sampler.sample(N)
        X = (X - self.mu_X) / self.sigma_X
        return X, Y

    def train(self, nIter=10000, batch_size=128):
        start_time = timeit.default_timer()

        for it in range(nIter):

            # Fetch boundary and data mini-batches
            X_ic1_batch, u_ic1_batch = self.fetch_minibatch(self.ics_sampler[0], batch_size)
            X_ic2_batch, u_ic2_batch = self.fetch_minibatch(self.ics_sampler[1], batch_size)

            X_bc1_batch, u_bc1_batch = self.fetch_minibatch(self.bcs_sampler[0], batch_size)
            X_bc2_batch, u_bc2_batch = self.fetch_minibatch(self.bcs_sampler[1], batch_size)
            X_bc3_batch, u_bc3_batch = self.fetch_minibatch(self.bcs_sampler[2], batch_size)
            X_bc4_batch, u_bc4_batch = self.fetch_minibatch(self.bcs_sampler[3], batch_size)
            # Fetch residual mini-batch
            X_res_batch, _ = self.fetch_minibatch(self.res_sampler, batch_size)

            # Define a dictionary for associating placeholders with data
            tf_dict = {self.x_u_tf: X_res_batch[:, 0:1], self.y_u_tf: X_res_batch[:, 1:2],
                       self.t_u_tf: X_res_batch[:, 2:3],
                       self.x_ic1_tf: X_ic1_batch[:, 0:1], self.y_ic1_tf: X_ic1_batch[:, 1:2],
                       self.t_ic1_tf: X_ic1_batch[:, 2:3], self.u_ic1_tf: u_ic1_batch,
                       self.x_ic2_tf: X_ic2_batch[:, 0:1], self.y_ic2_tf: X_ic2_batch[:, 1:2],
                       self.t_ic2_tf: X_ic2_batch[:, 2:3], self.u_ic2_tf: u_ic2_batch,
                       self.x_bc1_tf: X_bc1_batch[:, 0:1], self.y_bc1_tf: X_bc1_batch[:, 1:2],
                       self.t_bc1_tf: X_bc1_batch[:, 2:3], self.u_bc1_tf: u_bc1_batch,
                       self.x_bc2_tf: X_bc2_batch[:, 0:1], self.y_bc2_tf: X_bc2_batch[:, 1:2],
                       self.t_bc2_tf: X_bc2_batch[:, 2:3], self.u_bc2_tf: u_bc2_batch,
                       self.x_bc3_tf: X_bc3_batch[:, 0:1], self.y_bc3_tf: X_bc3_batch[:, 1:2],
                       self.t_bc3_tf: X_bc3_batch[:, 2:3], self.u_bc3_tf: u_bc3_batch,
                       self.x_bc4_tf: X_bc4_batch[:, 0:1], self.y_bc4_tf: X_bc4_batch[:, 1:2],
                       self.t_bc4_tf: X_bc4_batch[:, 2:3], self.u_bc4_tf: u_bc4_batch,
                       self.y_Nc_tf: X_res_batch[:, 1:2], self.t_Nc_tf: X_res_batch[:, 2:3],
                       self.x_r_tf: X_res_batch[:, 0:1], self.y_r_tf: X_res_batch[:, 1:2],
                       self.t_r_tf: X_res_batch[:, 2:3]}

            self.sess.run(self.train_op, tf_dict)
            

            # Print
            if it % 10 == 0:
                elapsed = timeit.default_timer() - start_time
                loss_value = self.sess.run(self.loss, tf_dict)
                loss_u_bcs_value, loss_u_ic_value, loss_res_value = self.sess.run(
                    [self.loss_u_bcs, self.loss_u_ic, self.loss_res], tf_dict)
                self.loss_u_bcs_log.append(loss_u_bcs_value)
                self.loss_u_ic_log.append(loss_u_ic_value)
                self.loss_res_log.append(loss_res_value)
                print('It: %d, Loss: %.3e, Loss_bcs: %.3e, Loss_ics: %.3e, Loss_res: %.3e, Time: %.2f' %
                      (it, loss_value, loss_u_bcs_value, loss_u_ic_value, loss_res_value, elapsed))
                start_time = timeit.default_timer()

    # Predictions for u
    def predict_u(self, X_star):
        X_star = (X_star - self.mu_X) / self.sigma_X
        tf_dict = {self.x_u_tf: X_star[:, 0:1], self.y_u_tf: X_star[:, 1:2], self.t_u_tf: X_star[:, 2:3]}
        u_star = self.sess.run(self.u_pred, tf_dict)
        return u_star

    # Predictions for s
    def predict_s(self, X_star):
        X_star = (X_star - self.mu_X[1:3]) / self.sigma_X[1:3]
        tf_dict = {self.y_u_tf: X_star[:, 0:1], self.t_u_tf: X_star[:, 1:2]}
        s_star = self.sess.run(self.s_pred, tf_dict)
        return s_star

# %%
import tensorflow as tf
import numpy as np
from mpl_toolkits import mplot3d
import matplotlib.pyplot as plt
from scipy.interpolate import griddata
import seaborn as sns
import pandas as pd
import os
# from google.colab import drive
# drive.mount('/content/drive')
import tensorflow.compat.v1 as tf 
tf.disable_v2_behavior()
tf.reset_default_graph()
import gc
import matplotlib

font = {'size' : 15}

matplotlib.rc('font', **font)

if __name__ == '__main__':
    
    # Exact u
    def u1(z):
        # x = (x, y, t)
        x = z[:, 0: 1]
        y = z[:, 1: 2]
        t = z[:, 2: 3]

        u = 1 - erf(
            (x-y)/np.sqrt(8  *  0.5 * (t+t_0))
        ) / erf(
            g / np.sqrt(8 * 0.5)
        )
        return u

    def u2(z):
        # x = (x, y, t)
        x = z[:, 0: 1]
        y = z[:, 1: 2]
        t = z[:, 2: 3]

        u = -1 + erfc(
            (x-y)/np.sqrt(8  *  1 * (t+t_0))
        ) / erfc(
            g / np.sqrt(8 * 1)
        )
        return u

        # Exact u
    def u(z):
       return np.where(z[:, 0:1] <= s(z[:, 1:]), u1(z), u2(z))

    # Exact s
    def s(z):
        y = z[:, 0: 1]
        t = z[:, 1: 2]
        # s = 0.5 * y + 1.25 * t + 0.5
        s = g * np.sqrt(t + t_0) + y
        return s
    
    # Initial condition u1(x, y, 0) = exp(-x + y/2 + 1/2) -1
    def f_1(z):
        x = z[:, 0: 1]
        y = z[:, 1: 2]
        f = 1 - erf(
            (x-y)/np.sqrt(8  *  0.5 * (t_0))
        ) / erf(
            g / np.sqrt(8 * 0.5)
        )
        return f

    # Initial condition u2(x, y, 0)
    def f_2(z):
        x = z[:, 0: 1]
        y = z[:, 1: 2]
        f = -1 + erfc(
            (x-y)/np.sqrt(8  *  1 * (t_0))
        ) / erfc(
            g / np.sqrt(8 * 1)
        )
        return f

    def z(x):
        N = x.shape[0]
        return np.zeros((N, 1))

    # Domain boundaries
    ic_coords = np.array([[0.0, 0.0, 0.0],
                          [2.0, 1.0, 0.0]])
    
    bc1_coords = np.array([[0.0, 0.0, 0.0],
                           [2.0, 0.0, 1.0]]) #both
    
    bc2_coords = np.array([[0.0, 0.0, 0.0],
                           [2.0, 1.0, 1.0]]) #u1
    
    bc3_coords = np.array([[0.0, 1.0, 0.0],
                           [2.0, 1.0, 1.0]]) #both
    
    bc4_coords = np.array([[2.0, 0.0, 0.0],
                           [2.0, 1.0, 1.0]]) #u2
    
    dom_coords = np.array([[0.0, 0.0, 0.0],
                           [2.0, 1.0, 1.0]])

    # Create Initial conditions samplers

    ic1_sampler = Sampler(3, ic_coords, lambda x: f_1(x), name='Initial Condition I')
    ic2_sampler = Sampler(3, ic_coords, lambda x: f_2(x), name='Initial Condition II')
    ics_sampler = [ic1_sampler, ic2_sampler]

    # Create boundary conditions samplers
    bc1_sampler = Sampler(3, bc1_coords, lambda x: u(x), name='Boundary Condition I')
    bc2_sampler = Sampler(3, bc2_coords, lambda x: u(x), name='Boundary Condition II')
    bc3_sampler = Sampler(3, bc3_coords, lambda x: u(x), name='Boundary Condition III')
    bc4_sampler = Sampler(3, bc4_coords, lambda x: u(x), name='Boundary Condition IV')
    bcs_sampler = [bc1_sampler, bc2_sampler, bc3_sampler, bc4_sampler]

    # Create residual sampler
    res_sampler = Sampler(3, dom_coords, lambda x: u(x), name='Forcing')

    # Define model
    layers_u = [3, 100, 100, 100, 2]
    layers_s = [2, 100, 100, 100, 1]  

    model = Stefan2D_direct(layers_u, layers_s, ics_sampler, bcs_sampler, res_sampler)

      # Train the model
    model.train(nIter=40000, batch_size=128)
    
    for N in [200]:

      # Test data
      nn = N
      y = np.linspace(dom_coords[0, 1], dom_coords[1, 1], nn)[:, None]
      t = np.linspace(dom_coords[0, 2], dom_coords[1, 2], nn)[:, None]
      y, t = np.meshgrid(y, t)
      
      X_star = np.hstack((y.flatten()[:, None], t.flatten()[:, None]))
      
      s_star = s(X_star)

      # Predictions
      s_pred = model.predict_s(X_star)
      
      error_s = np.linalg.norm(s_star - s_pred, 2) / np.linalg.norm(s_star, 2)
      print('The relative errror is: {:4e}'.format(error_s))
      # if not os.path.exists('/content/drive/My Drive/Diploma/2d2p_test1/'):
      #   os.mkdir('/content/drive/My Drive/Diploma/2d2p_test1/')

      # Plot for s
      nn = N
      y = np.linspace(dom_coords[0, 1], dom_coords[1, 1], nn)[:, None]
      t = np.linspace(dom_coords[0, 2], dom_coords[1, 2], nn)[:, None]
      y, t = np.meshgrid(y, t)

      X_star = np.hstack((y.flatten()[:, None], t.flatten()[:, None]))
      
      s_star = s(X_star)
      s_pred = model.predict_s(X_star)
      
      S_pred = griddata(X_star, s_pred.flatten(), (y, t), method='cubic')
      S_star = griddata(X_star, s_star.flatten(), (y, t), method='cubic')
          
      fig_1 = plt.figure(5, figsize=(18, 5))
      ax = fig_1.add_subplot(1, 3, 1, projection='3d')
      ax.plot_surface(y, t, S_star)
      ax.set_xlabel('y')
      ax.set_ylabel('t')
      ax.set_zlabel('s(y,t)')
      ax.set_title('Exact')
      
      ax = fig_1.add_subplot(1, 3, 2, projection='3d')
      ax.plot_surface(y, t, S_pred)
      ax.set_xlabel('y')
      ax.set_ylabel('t')
      ax.set_zlabel('s(y,t)')
      ax.set_title('Predicted')
      
      ax = fig_1.add_subplot(1, 3, 3, projection='3d')
      ax.plot_surface(y, t, np.abs(S_star - S_pred))
      ax.set_xlabel('y')
      ax.set_ylabel('t')
      ax.set_zlabel('s(y,t)')
      ax.set_title('Absolute Error')
      
      plt.tight_layout()
      # with open('/content/drive/My Drive/Diploma/2d2p_test1/Plot_for_S.pdf', 'w') as f:
      #       pass
      # plt.savefig('/content/drive/My Drive/Diploma/2d2p_test1/Plot_for_S.pdf')
      # plt.clf()

      # Plot for u
      T_list = [0.2, 0.4, 0.6, 0.8]
      nn = N
      x = np.linspace(0, 2.0, nn)[:, None]
      y = np.linspace(dom_coords[0, 1], dom_coords[1, 1], nn)[:, None]
      t = np.linspace(dom_coords[0, 2], dom_coords[1, 2], nn)[:, None]
      
      for T in T_list:
          X, Y = np.meshgrid(x, y)
          T_star = T * np.ones_like(X)
          X_star = np.hstack((X.flatten()[:, None], Y.flatten()[:, None], T_star.flatten()[:, None]))
          
          u_star = u(X_star)
          u_pred = model.predict_u(X_star)
          
          X_star = np.hstack((X.flatten()[:, None], Y.flatten()[:, None]))
          
          U_star = griddata(X_star, u_star.flatten(), (X, Y), method='cubic')
          U_pred = griddata(X_star, u_pred.flatten(), (X, Y), method='cubic')
          
          # for i in range(nn):
          #     for j in range(nn):
          #         X_ij = np.array([X[i,j], Y[i,j], T]).reshape(1,3)
          #         u_ij = u(X_ij)
          #         s_ij = s(np.array([Y[i,j], T]).reshape(1,2))
          #         if X[i,j] < s_ij:
          #             U_star[i,j] = np.nan
          #             U_pred[i,j] = np.nan

      
          np.savetxt('pred_{}'.format(str(T)), U_pred, delimiter=',')
          np.savetxt('exact_{}'.format(str(T)), U_star, delimiter=',')
          
      
      for T in T_list:
          U_pred = np.loadtxt('pred_{}'.format(str(T)), delimiter=',')
          U_star = np.loadtxt('exact_{}'.format(str(T)), delimiter=',')

          y = np.linspace(dom_coords[0, 1], dom_coords[1, 1], nn)[:, None]
          t = T * np.ones_like(y)
          y, t = np.meshgrid(y, t)

          X_star = np.hstack((y.flatten()[:, None], t.flatten()[:, None]))
          
          s_star = s(X_star)
          s_pred = model.predict_s(X_star)
          
          fig = plt.figure(figsize=(18, 5))
          plt.subplot(1, 3, 1)
          plt.pcolor(X, Y, U_star, cmap='jet')
          plt.plot(s_star, y.flatten(), color='black', linewidth=2)
          plt.colorbar()
          plt.xlabel(r'$x$')
          plt.ylabel(r'$y$')
          plt.title('Exact $u(x, y, {})$'.format(T))
          
          plt.subplot(1, 3, 2)
          plt.pcolor(X, Y, U_pred, cmap='jet')
          plt.plot(s_star, y.flatten(), color='black', linewidth=2)
          plt.colorbar()
          plt.xlabel(r'$x$')
          plt.ylabel(r'$y$')
          plt.title('Predicted  $u(x, y, {})$'.format(T))
      
          plt.subplot(1, 3, 3)
          plt.pcolor(X, Y, np.abs(U_star - U_pred), cmap='jet')
          plt.colorbar(format='%.0e')
          plt.xlabel(r'$x$')
          plt.ylabel(r'$y$')
          plt.title('Absolute Error')
          
          plt.tight_layout()
          # with open('/content/drive/My Drive/Diploma/2d2p_test1/Plot_for_U[T={}].pdf'.format(T), 'w') as f:
          #   pass
          # plt.savefig('/content/drive/My Drive/Diploma/2d2p_test1/Plot_for_U[T={}].pdf'.format(T))

          # plt.clf()

      # return error_s
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
#
# It: 0, Loss: 7.036e+00, Loss_bcs: 2.686e+00, Loss_ics: 1.943e+00, Loss_res: 7.551e-01, Time: 9.87
# It: 10, Loss: 3.585e+00, Loss_bcs: 1.404e+00, Loss_ics: 8.960e-01, Loss_res: 3.866e-01, Time: 0.60
# It: 20, Loss: 2.387e+00, Loss_bcs: 8.681e-01, Loss_ics: 5.489e-01, Loss_res: 3.034e-01, Time: 0.59
# It: 30, Loss: 9.436e-01, Loss_bcs: 3.464e-01, Loss_ics: 2.084e-01, Loss_res: 3.082e-01, Time: 0.61
# It: 40, Loss: 7.251e-01, Loss_bcs: 2.043e-01, Loss_ics: 3.554e-01, Loss_res: 8.727e-02, Time: 0.53
# It: 50, Loss: 4.934e-01, Loss_bcs: 2.844e-01, Loss_ics: 1.243e-01, Loss_res: 6.290e-02, Time: 0.46
# It: 60, Loss: 5.099e-01, Loss_bcs: 2.880e-01, Loss_ics: 1.072e-01, Loss_res: 8.880e-02, Time: 0.35
# It: 70, Loss: 4.750e-01, Loss_bcs: 3.075e-01, Loss_ics: 1.144e-01, Loss_res: 3.631e-02, Time: 0.35
# It: 80, Loss: 3.738e-01, Loss_bcs: 2.072e-01, Loss_ics: 1.299e-01, Loss_res: 2.219e-02, Time: 0.32
# It: 90, Loss: 3.820e-01, Loss_bcs: 2.169e-01, Loss_ics: 1.295e-01, Loss_res: 2.439e-02, Time: 0.37
# It: 100, Loss: 4.490e-01, Loss_bcs: 2.764e-01, Loss_ics: 1.349e-01, Loss_res: 2.648e-02, Time: 0.34
# It: 110, Loss: 3.298e-01, Loss_bcs: 1.841e-01, Loss_ics: 1.080e-01, Loss_res: 2.962e-02, Time: 0.33
# It: 120, Loss: 3.793e-01, Loss_bcs: 2.549e-01, Loss_ics: 8.590e-02, Loss_res: 3.003e-02, Time: 0.35
# It: 130, Loss: 3.155e-01, Loss_bcs: 2.079e-01, Loss_ics: 6.489e-02, Loss_res: 3.519e-02, Time: 0.33
# It: 140, Loss: 3.423e-01, Loss_bcs: 2.258e-01, Loss_ics: 7.085e-02, Loss_res: 3.712e-02, Time: 0.32
# It: 150, Loss: 2.656e-01, Loss_bcs: 1.639e-01, Loss_ics: 5.933e-02, Loss_res: 3.709e-02, Time: 0.34
# It: 160, Loss: 2.568e-01, Loss_bcs: 1.613e-01, Loss_ics: 4.676e-02, Loss_res: 4.345e-02, Time: 0.35
# It: 170, Loss: 2.546e-01, Loss_bcs: 1.833e-01, Loss_ics: 4.008e-02, Loss_res: 2.717e-02, Time: 0.33
# It: 180, Loss: 2.613e-01, Loss_bcs: 1.733e-01, Loss_ics: 5.595e-02, Loss_res: 2.742e-02, Time: 0.36
# It: 190, Loss: 2.304e-01, Loss_bcs: 1.430e-01, Loss_ics: 4.625e-02, Loss_res: 3.619e-02, Time: 0.35
# It: 200, Loss: 2.187e-01, Loss_bcs: 1.358e-01, Loss_ics: 4.376e-02, Loss_res: 3.518e-02, Time: 0.32
# It: 210, Loss: 2.010e-01, Loss_bcs: 1.157e-01, Loss_ics: 5.588e-02, Loss_res: 2.515e-02, Time: 0.34
# It: 220, Loss: 2.097e-01, Loss_bcs: 1.360e-01, Loss_ics: 3.646e-02, Loss_res: 3.411e-02, Time: 0.35
# It: 230, Loss: 1.729e-01, Loss_bcs: 1.006e-01, Loss_ics: 4.473e-02, Loss_res: 2.318e-02, Time: 0.43
# It: 240, Loss: 1.578e-01, Loss_bcs: 9.761e-02, Loss_ics: 3.601e-02, Loss_res: 2.108e-02, Time: 0.51
# It: 250, Loss: 1.460e-01, Loss_bcs: 8.811e-02, Loss_ics: 3.166e-02, Loss_res: 2.224e-02, Time: 0.50
# It: 260, Loss: 1.988e-01, Loss_bcs: 1.253e-01, Loss_ics: 4.595e-02, Loss_res: 2.213e-02, Time: 0.51
# It: 270, Loss: 1.757e-01, Loss_bcs: 1.080e-01, Loss_ics: 4.242e-02, Loss_res: 2.228e-02, Time: 0.35
# It: 280, Loss: 1.632e-01, Loss_bcs: 9.426e-02, Loss_ics: 3.731e-02, Loss_res: 2.737e-02, Time: 0.33
# It: 290, Loss: 1.552e-01, Loss_bcs: 9.925e-02, Loss_ics: 3.184e-02, Loss_res: 1.986e-02, Time: 0.33
# It: 300, Loss: 1.589e-01, Loss_bcs: 8.734e-02, Loss_ics: 3.623e-02, Loss_res: 3.214e-02, Time: 0.35
# It: 310, Loss: 1.907e-01, Loss_bcs: 1.185e-01, Loss_ics: 4.037e-02, Loss_res: 2.761e-02, Time: 0.34
# It: 320, Loss: 1.577e-01, Loss_bcs: 9.272e-02, Loss_ics: 3.506e-02, Loss_res: 2.496e-02, Time: 0.35
# It: 330, Loss: 1.776e-01, Loss_bcs: 1.332e-01, Loss_ics: 2.743e-02, Loss_res: 1.518e-02, Time: 0.34
# It: 340, Loss: 1.443e-01, Loss_bcs: 8.681e-02, Loss_ics: 3.033e-02, Loss_res: 2.430e-02, Time: 0.35
# It: 350, Loss: 1.469e-01, Loss_bcs: 9.599e-02, Loss_ics: 3.040e-02, Loss_res: 1.621e-02, Time: 0.34
# It: 360, Loss: 1.124e-01, Loss_bcs: 6.712e-02, Loss_ics: 2.748e-02, Loss_res: 1.478e-02, Time: 0.34
# It: 370, Loss: 1.213e-01, Loss_bcs: 8.055e-02, Loss_ics: 2.413e-02, Loss_res: 1.487e-02, Time: 0.36
# It: 380, Loss: 1.507e-01, Loss_bcs: 1.010e-01, Loss_ics: 3.130e-02, Loss_res: 1.601e-02, Time: 0.33
# It: 390, Loss: 1.191e-01, Loss_bcs: 8.227e-02, Loss_ics: 2.357e-02, Loss_res: 1.199e-02, Time: 0.35
# It: 400, Loss: 1.258e-01, Loss_bcs: 8.368e-02, Loss_ics: 1.972e-02, Loss_res: 1.979e-02, Time: 0.35
# It: 410, Loss: 1.235e-01, Loss_bcs: 9.242e-02, Loss_ics: 1.925e-02, Loss_res: 9.651e-03, Time: 0.35
# It: 420, Loss: 1.104e-01, Loss_bcs: 6.879e-02, Loss_ics: 2.968e-02, Loss_res: 1.008e-02, Time: 0.35
# It: 430, Loss: 1.309e-01, Loss_bcs: 7.804e-02, Loss_ics: 3.501e-02, Loss_res: 1.577e-02, Time: 0.33
# It: 440, Loss: 1.005e-01, Loss_bcs: 6.668e-02, Loss_ics: 1.768e-02, Loss_res: 1.371e-02, Time: 0.34
# It: 450, Loss: 1.349e-01, Loss_bcs: 9.226e-02, Loss_ics: 3.101e-02, Loss_res: 9.202e-03, Time: 0.34
# It: 460, Loss: 1.115e-01, Loss_bcs: 7.560e-02, Loss_ics: 1.956e-02, Loss_res: 1.422e-02, Time: 0.35
# It: 470, Loss: 1.447e-01, Loss_bcs: 8.513e-02, Loss_ics: 4.196e-02, Loss_res: 1.525e-02, Time: 0.35
# It: 480, Loss: 9.652e-02, Loss_bcs: 5.163e-02, Loss_ics: 2.261e-02, Loss_res: 1.831e-02, Time: 0.34
# It: 490, Loss: 1.387e-01, Loss_bcs: 8.382e-02, Loss_ics: 3.404e-02, Loss_res: 1.775e-02, Time: 0.35
# It: 500, Loss: 1.150e-01, Loss_bcs: 8.285e-02, Loss_ics: 1.507e-02, Loss_res: 1.446e-02, Time: 0.34
# It: 510, Loss: 1.091e-01, Loss_bcs: 7.104e-02, Loss_ics: 2.724e-02, Loss_res: 8.774e-03, Time: 0.34
# It: 520, Loss: 1.125e-01, Loss_bcs: 8.090e-02, Loss_ics: 2.076e-02, Loss_res: 8.286e-03, Time: 0.34
# It: 530, Loss: 1.257e-01, Loss_bcs: 8.237e-02, Loss_ics: 2.665e-02, Loss_res: 1.388e-02, Time: 0.34
# It: 540, Loss: 9.750e-02, Loss_bcs: 6.302e-02, Loss_ics: 1.738e-02, Loss_res: 1.397e-02, Time: 0.35
# It: 550, Loss: 1.293e-01, Loss_bcs: 9.827e-02, Loss_ics: 2.176e-02, Loss_res: 7.200e-03, Time: 0.33
# It: 560, Loss: 1.208e-01, Loss_bcs: 8.721e-02, Loss_ics: 2.115e-02, Loss_res: 9.601e-03, Time: 0.34
# It: 570, Loss: 1.127e-01, Loss_bcs: 8.070e-02, Loss_ics: 2.170e-02, Loss_res: 8.876e-03, Time: 0.35
# It: 580, Loss: 1.064e-01, Loss_bcs: 7.138e-02, Loss_ics: 2.362e-02, Loss_res: 8.440e-03, Time: 0.35
# It: 590, Loss: 1.054e-01, Loss_bcs: 6.777e-02, Loss_ics: 1.985e-02, Loss_res: 1.501e-02, Time: 0.34
# It: 600, Loss: 7.989e-02, Loss_bcs: 5.622e-02, Loss_ics: 1.554e-02, Loss_res: 5.701e-03, Time: 0.34
# It: 610, Loss: 1.131e-01, Loss_bcs: 8.417e-02, Loss_ics: 1.783e-02, Loss_res: 8.769e-03, Time: 0.34
# It: 620, Loss: 9.263e-02, Loss_bcs: 5.650e-02, Loss_ics: 2.306e-02, Loss_res: 1.055e-02, Time: 0.34
# It: 630, Loss: 9.338e-02, Loss_bcs: 6.437e-02, Loss_ics: 1.675e-02, Loss_res: 1.027e-02, Time: 0.34
# It: 640, Loss: 1.398e-01, Loss_bcs: 8.583e-02, Loss_ics: 4.309e-02, Loss_res: 8.320e-03, Time: 0.35
# It: 650, Loss: 1.066e-01, Loss_bcs: 7.540e-02, Loss_ics: 1.715e-02, Loss_res: 9.818e-03, Time: 0.33
# It: 660, Loss: 1.168e-01, Loss_bcs: 6.518e-02, Loss_ics: 3.593e-02, Loss_res: 1.020e-02, Time: 0.33
# It: 670, Loss: 1.105e-01, Loss_bcs: 8.015e-02, Loss_ics: 1.983e-02, Loss_res: 7.190e-03, Time: 0.35
# It: 680, Loss: 1.022e-01, Loss_bcs: 6.336e-02, Loss_ics: 2.670e-02, Loss_res: 9.358e-03, Time: 0.34
# It: 690, Loss: 1.272e-01, Loss_bcs: 9.594e-02, Loss_ics: 1.724e-02, Loss_res: 1.180e-02, Time: 0.34
# It: 700, Loss: 1.142e-01, Loss_bcs: 6.917e-02, Loss_ics: 3.294e-02, Loss_res: 9.642e-03, Time: 0.34
# It: 710, Loss: 1.045e-01, Loss_bcs: 7.090e-02, Loss_ics: 2.190e-02, Loss_res: 7.547e-03, Time: 0.35
# It: 720, Loss: 9.932e-02, Loss_bcs: 6.473e-02, Loss_ics: 2.502e-02, Loss_res: 6.550e-03, Time: 0.34
# It: 730, Loss: 9.733e-02, Loss_bcs: 6.926e-02, Loss_ics: 1.625e-02, Loss_res: 9.650e-03, Time: 0.35
# It: 740, Loss: 1.098e-01, Loss_bcs: 7.547e-02, Loss_ics: 2.367e-02, Loss_res: 7.138e-03, Time: 0.35
# It: 750, Loss: 7.449e-02, Loss_bcs: 4.515e-02, Loss_ics: 1.921e-02, Loss_res: 7.520e-03, Time: 0.34
# It: 760, Loss: 9.439e-02, Loss_bcs: 6.620e-02, Loss_ics: 1.795e-02, Loss_res: 7.412e-03, Time: 0.35
# It: 770, Loss: 8.023e-02, Loss_bcs: 5.673e-02, Loss_ics: 1.479e-02, Loss_res: 6.202e-03, Time: 0.34
# It: 780, Loss: 1.101e-01, Loss_bcs: 7.444e-02, Loss_ics: 2.353e-02, Loss_res: 9.543e-03, Time: 0.34
# It: 790, Loss: 1.327e-01, Loss_bcs: 9.223e-02, Loss_ics: 2.833e-02, Loss_res: 7.938e-03, Time: 0.34
# It: 800, Loss: 1.065e-01, Loss_bcs: 7.143e-02, Loss_ics: 2.705e-02, Loss_res: 5.998e-03, Time: 0.35
# It: 810, Loss: 8.997e-02, Loss_bcs: 6.110e-02, Loss_ics: 2.249e-02, Loss_res: 3.804e-03, Time: 0.35
# It: 820, Loss: 1.001e-01, Loss_bcs: 6.741e-02, Loss_ics: 2.388e-02, Loss_res: 7.130e-03, Time: 0.33
# It: 830, Loss: 1.214e-01, Loss_bcs: 8.069e-02, Loss_ics: 2.942e-02, Loss_res: 7.216e-03, Time: 0.32
# It: 840, Loss: 1.146e-01, Loss_bcs: 8.284e-02, Loss_ics: 2.028e-02, Loss_res: 6.744e-03, Time: 0.34
# It: 850, Loss: 1.090e-01, Loss_bcs: 7.991e-02, Loss_ics: 1.995e-02, Loss_res: 5.779e-03, Time: 0.34
# It: 860, Loss: 9.733e-02, Loss_bcs: 6.533e-02, Loss_ics: 1.873e-02, Loss_res: 9.944e-03, Time: 0.34
# It: 870, Loss: 9.439e-02, Loss_bcs: 6.090e-02, Loss_ics: 2.525e-02, Loss_res: 5.486e-03, Time: 0.34
# It: 880, Loss: 1.215e-01, Loss_bcs: 7.692e-02, Loss_ics: 2.944e-02, Loss_res: 1.187e-02, Time: 0.34
# It: 890, Loss: 1.029e-01, Loss_bcs: 6.978e-02, Loss_ics: 2.479e-02, Loss_res: 5.916e-03, Time: 0.33
# It: 900, Loss: 1.276e-01, Loss_bcs: 8.946e-02, Loss_ics: 2.470e-02, Loss_res: 7.982e-03, Time: 0.35
# It: 910, Loss: 7.703e-02, Loss_bcs: 4.714e-02, Loss_ics: 1.972e-02, Loss_res: 5.151e-03, Time: 0.34
# It: 920, Loss: 9.349e-02, Loss_bcs: 7.032e-02, Loss_ics: 1.485e-02, Loss_res: 5.424e-03, Time: 0.34
# It: 930, Loss: 1.094e-01, Loss_bcs: 8.355e-02, Loss_ics: 1.402e-02, Loss_res: 7.904e-03, Time: 0.35
# It: 940, Loss: 7.788e-02, Loss_bcs: 5.039e-02, Loss_ics: 1.843e-02, Loss_res: 6.317e-03, Time: 0.34
# It: 950, Loss: 1.005e-01, Loss_bcs: 7.463e-02, Loss_ics: 1.338e-02, Loss_res: 8.793e-03, Time: 0.34
# It: 960, Loss: 9.154e-02, Loss_bcs: 6.994e-02, Loss_ics: 1.228e-02, Loss_res: 6.587e-03, Time: 0.36
# It: 970, Loss: 1.222e-01, Loss_bcs: 8.521e-02, Loss_ics: 2.536e-02, Loss_res: 7.380e-03, Time: 0.33
# It: 980, Loss: 9.460e-02, Loss_bcs: 6.250e-02, Loss_ics: 1.917e-02, Loss_res: 8.235e-03, Time: 0.34
# It: 990, Loss: 6.681e-02, Loss_bcs: 3.808e-02, Loss_ics: 1.962e-02, Loss_res: 6.382e-03, Time: 0.34
# It: 1000, Loss: 1.145e-01, Loss_bcs: 8.321e-02, Loss_ics: 2.230e-02, Loss_res: 4.865e-03, Time: 0.34
# It: 1010, Loss: 9.658e-02, Loss_bcs: 6.699e-02, Loss_ics: 1.968e-02, Loss_res: 7.323e-03, Time: 0.33
# It: 1020, Loss: 9.742e-02, Loss_bcs: 6.417e-02, Loss_ics: 1.730e-02, Loss_res: 1.199e-02, Time: 0.33
# It: 1030, Loss: 1.033e-01, Loss_bcs: 7.012e-02, Loss_ics: 2.021e-02, Loss_res: 8.455e-03, Time: 0.34
# It: 1040, Loss: 6.742e-02, Loss_bcs: 4.149e-02, Loss_ics: 1.156e-02, Loss_res: 1.030e-02, Time: 0.35
# It: 1050, Loss: 8.813e-02, Loss_bcs: 5.539e-02, Loss_ics: 2.168e-02, Loss_res: 8.284e-03, Time: 0.33
# It: 1060, Loss: 8.063e-02, Loss_bcs: 5.404e-02, Loss_ics: 1.649e-02, Loss_res: 6.395e-03, Time: 0.34
# It: 1070, Loss: 1.092e-01, Loss_bcs: 7.282e-02, Loss_ics: 2.433e-02, Loss_res: 5.251e-03, Time: 0.33
# It: 1080, Loss: 9.509e-02, Loss_bcs: 6.998e-02, Loss_ics: 1.394e-02, Loss_res: 8.655e-03, Time: 0.35
# It: 1090, Loss: 9.056e-02, Loss_bcs: 5.925e-02, Loss_ics: 2.208e-02, Loss_res: 4.879e-03, Time: 0.34
# It: 1100, Loss: 1.204e-01, Loss_bcs: 6.639e-02, Loss_ics: 3.046e-02, Loss_res: 1.845e-02, Time: 0.34
# It: 1110, Loss: 1.167e-01, Loss_bcs: 7.907e-02, Loss_ics: 1.350e-02, Loss_res: 1.807e-02, Time: 0.33
# It: 1120, Loss: 1.211e-01, Loss_bcs: 7.017e-02, Loss_ics: 2.930e-02, Loss_res: 1.579e-02, Time: 0.34
# It: 1130, Loss: 1.613e-01, Loss_bcs: 1.260e-01, Loss_ics: 2.607e-02, Loss_res: 6.265e-03, Time: 0.33
# It: 1140, Loss: 1.049e-01, Loss_bcs: 7.660e-02, Loss_ics: 2.090e-02, Loss_res: 3.018e-03, Time: 0.35
# It: 1150, Loss: 9.356e-02, Loss_bcs: 6.596e-02, Loss_ics: 2.011e-02, Loss_res: 4.494e-03, Time: 0.34
# It: 1160, Loss: 7.348e-02, Loss_bcs: 4.472e-02, Loss_ics: 1.968e-02, Loss_res: 6.836e-03, Time: 0.33
# It: 1170, Loss: 1.028e-01, Loss_bcs: 7.265e-02, Loss_ics: 2.217e-02, Loss_res: 3.519e-03, Time: 0.33
# It: 1180, Loss: 9.185e-02, Loss_bcs: 5.414e-02, Loss_ics: 2.511e-02, Loss_res: 6.244e-03, Time: 0.36
# It: 1190, Loss: 9.438e-02, Loss_bcs: 5.530e-02, Loss_ics: 2.699e-02, Loss_res: 7.167e-03, Time: 0.35
# It: 1200, Loss: 9.212e-02, Loss_bcs: 7.272e-02, Loss_ics: 1.078e-02, Loss_res: 6.325e-03, Time: 0.33
# It: 1210, Loss: 9.034e-02, Loss_bcs: 6.436e-02, Loss_ics: 1.357e-02, Loss_res: 8.566e-03, Time: 0.34
# It: 1220, Loss: 8.041e-02, Loss_bcs: 5.922e-02, Loss_ics: 1.225e-02, Loss_res: 6.044e-03, Time: 0.34
# It: 1230, Loss: 1.049e-01, Loss_bcs: 7.485e-02, Loss_ics: 2.162e-02, Loss_res: 5.676e-03, Time: 0.34
# It: 1240, Loss: 7.729e-02, Loss_bcs: 5.473e-02, Loss_ics: 1.037e-02, Loss_res: 9.665e-03, Time: 0.35
# It: 1250, Loss: 9.438e-02, Loss_bcs: 6.897e-02, Loss_ics: 1.610e-02, Loss_res: 6.577e-03, Time: 0.33
# It: 1260, Loss: 6.392e-02, Loss_bcs: 4.777e-02, Loss_ics: 9.811e-03, Loss_res: 4.406e-03, Time: 0.34
# It: 1270, Loss: 1.122e-01, Loss_bcs: 8.735e-02, Loss_ics: 1.888e-02, Loss_res: 3.415e-03, Time: 0.34
# It: 1280, Loss: 1.086e-01, Loss_bcs: 7.765e-02, Loss_ics: 2.334e-02, Loss_res: 4.555e-03, Time: 0.33
# It: 1290, Loss: 1.332e-01, Loss_bcs: 8.724e-02, Loss_ics: 3.282e-02, Loss_res: 5.914e-03, Time: 0.34
# It: 1300, Loss: 1.255e-01, Loss_bcs: 9.272e-02, Loss_ics: 2.232e-02, Loss_res: 7.134e-03, Time: 0.33
# It: 1310, Loss: 8.362e-02, Loss_bcs: 6.017e-02, Loss_ics: 1.453e-02, Loss_res: 5.883e-03, Time: 0.34
# It: 1320, Loss: 9.187e-02, Loss_bcs: 6.358e-02, Loss_ics: 1.856e-02, Loss_res: 6.483e-03, Time: 0.35
# It: 1330, Loss: 1.121e-01, Loss_bcs: 8.590e-02, Loss_ics: 1.646e-02, Loss_res: 6.440e-03, Time: 0.34
# It: 1340, Loss: 6.586e-02, Loss_bcs: 4.281e-02, Loss_ics: 1.513e-02, Loss_res: 4.995e-03, Time: 0.34
# It: 1350, Loss: 7.924e-02, Loss_bcs: 5.827e-02, Loss_ics: 1.250e-02, Loss_res: 5.726e-03, Time: 0.34
# It: 1360, Loss: 7.944e-02, Loss_bcs: 4.482e-02, Loss_ics: 2.293e-02, Loss_res: 9.323e-03, Time: 0.34
# It: 1370, Loss: 9.546e-02, Loss_bcs: 7.133e-02, Loss_ics: 1.694e-02, Loss_res: 4.615e-03, Time: 0.34
# It: 1380, Loss: 7.312e-02, Loss_bcs: 4.735e-02, Loss_ics: 1.537e-02, Loss_res: 6.573e-03, Time: 0.34
# It: 1390, Loss: 8.611e-02, Loss_bcs: 6.039e-02, Loss_ics: 1.716e-02, Loss_res: 4.192e-03, Time: 0.34
# It: 1400, Loss: 8.665e-02, Loss_bcs: 5.093e-02, Loss_ics: 2.575e-02, Loss_res: 6.070e-03, Time: 0.34
# It: 1410, Loss: 6.774e-02, Loss_bcs: 4.193e-02, Loss_ics: 1.532e-02, Loss_res: 5.704e-03, Time: 0.34
# It: 1420, Loss: 1.063e-01, Loss_bcs: 6.715e-02, Loss_ics: 2.722e-02, Loss_res: 6.747e-03, Time: 0.34
# It: 1430, Loss: 7.564e-02, Loss_bcs: 5.433e-02, Loss_ics: 1.524e-02, Loss_res: 4.148e-03, Time: 0.33
# It: 1440, Loss: 6.556e-02, Loss_bcs: 4.412e-02, Loss_ics: 1.167e-02, Loss_res: 6.770e-03, Time: 0.36
# It: 1450, Loss: 8.589e-02, Loss_bcs: 5.344e-02, Loss_ics: 1.859e-02, Loss_res: 1.050e-02, Time: 0.33
# It: 1460, Loss: 5.781e-02, Loss_bcs: 3.964e-02, Loss_ics: 9.840e-03, Loss_res: 5.545e-03, Time: 0.34
# It: 1470, Loss: 8.773e-02, Loss_bcs: 6.481e-02, Loss_ics: 1.388e-02, Loss_res: 5.300e-03, Time: 0.34
# It: 1480, Loss: 1.019e-01, Loss_bcs: 6.932e-02, Loss_ics: 2.046e-02, Loss_res: 7.199e-03, Time: 0.34
# It: 1490, Loss: 7.215e-02, Loss_bcs: 4.876e-02, Loss_ics: 1.402e-02, Loss_res: 5.455e-03, Time: 0.34
# It: 1500, Loss: 7.266e-02, Loss_bcs: 5.129e-02, Loss_ics: 1.175e-02, Loss_res: 6.521e-03, Time: 0.34
# It: 1510, Loss: 8.736e-02, Loss_bcs: 5.986e-02, Loss_ics: 1.938e-02, Loss_res: 4.148e-03, Time: 0.34
# It: 1520, Loss: 9.183e-02, Loss_bcs: 6.032e-02, Loss_ics: 1.973e-02, Loss_res: 7.495e-03, Time: 0.35
# It: 1530, Loss: 1.193e-01, Loss_bcs: 8.187e-02, Loss_ics: 2.008e-02, Loss_res: 1.354e-02, Time: 0.34
# It: 1540, Loss: 8.666e-02, Loss_bcs: 6.027e-02, Loss_ics: 1.615e-02, Loss_res: 6.999e-03, Time: 0.34
# It: 1550, Loss: 8.267e-02, Loss_bcs: 5.642e-02, Loss_ics: 1.615e-02, Loss_res: 6.818e-03, Time: 0.34
# It: 1560, Loss: 6.269e-02, Loss_bcs: 4.171e-02, Loss_ics: 1.457e-02, Loss_res: 3.258e-03, Time: 0.33
# It: 1570, Loss: 8.079e-02, Loss_bcs: 5.450e-02, Loss_ics: 1.730e-02, Loss_res: 4.932e-03, Time: 0.34
# It: 1580, Loss: 6.616e-02, Loss_bcs: 4.221e-02, Loss_ics: 1.507e-02, Loss_res: 4.174e-03, Time: 0.35
# It: 1590, Loss: 1.135e-01, Loss_bcs: 8.348e-02, Loss_ics: 2.036e-02, Loss_res: 3.879e-03, Time: 0.33
# It: 1600, Loss: 5.577e-02, Loss_bcs: 3.021e-02, Loss_ics: 1.908e-02, Loss_res: 3.852e-03, Time: 0.34
# It: 1610, Loss: 1.142e-01, Loss_bcs: 7.930e-02, Loss_ics: 2.685e-02, Loss_res: 5.287e-03, Time: 0.35
# It: 1620, Loss: 7.738e-02, Loss_bcs: 5.631e-02, Loss_ics: 1.308e-02, Loss_res: 4.598e-03, Time: 0.34
# It: 1630, Loss: 9.161e-02, Loss_bcs: 6.278e-02, Loss_ics: 2.289e-02, Loss_res: 3.256e-03, Time: 0.34
# It: 1640, Loss: 7.773e-02, Loss_bcs: 6.131e-02, Loss_ics: 1.041e-02, Loss_res: 3.434e-03, Time: 0.33
# It: 1650, Loss: 7.710e-02, Loss_bcs: 5.937e-02, Loss_ics: 1.034e-02, Loss_res: 5.088e-03, Time: 0.33
# It: 1660, Loss: 8.338e-02, Loss_bcs: 5.908e-02, Loss_ics: 1.427e-02, Loss_res: 6.078e-03, Time: 0.34
# It: 1670, Loss: 1.058e-01, Loss_bcs: 7.459e-02, Loss_ics: 2.348e-02, Loss_res: 4.491e-03, Time: 0.34
# It: 1680, Loss: 9.504e-02, Loss_bcs: 6.449e-02, Loss_ics: 1.436e-02, Loss_res: 1.177e-02, Time: 0.35
# It: 1690, Loss: 7.879e-02, Loss_bcs: 5.271e-02, Loss_ics: 1.771e-02, Loss_res: 4.949e-03, Time: 0.34
# It: 1700, Loss: 7.609e-02, Loss_bcs: 5.452e-02, Loss_ics: 1.238e-02, Loss_res: 5.617e-03, Time: 0.33
# It: 1710, Loss: 9.025e-02, Loss_bcs: 6.895e-02, Loss_ics: 1.202e-02, Loss_res: 5.829e-03, Time: 0.33
# It: 1720, Loss: 9.527e-02, Loss_bcs: 5.765e-02, Loss_ics: 2.723e-02, Loss_res: 6.172e-03, Time: 0.35
# It: 1730, Loss: 7.285e-02, Loss_bcs: 5.650e-02, Loss_ics: 1.061e-02, Loss_res: 3.134e-03, Time: 0.34
# It: 1740, Loss: 9.035e-02, Loss_bcs: 6.016e-02, Loss_ics: 2.306e-02, Loss_res: 4.788e-03, Time: 0.33
# It: 1750, Loss: 9.018e-02, Loss_bcs: 6.097e-02, Loss_ics: 2.044e-02, Loss_res: 3.768e-03, Time: 0.35
# It: 1760, Loss: 1.020e-01, Loss_bcs: 6.844e-02, Loss_ics: 2.296e-02, Loss_res: 7.955e-03, Time: 0.32
# It: 1770, Loss: 7.495e-02, Loss_bcs: 5.325e-02, Loss_ics: 1.212e-02, Loss_res: 5.857e-03, Time: 0.33
# It: 1780, Loss: 6.248e-02, Loss_bcs: 4.094e-02, Loss_ics: 1.168e-02, Loss_res: 6.737e-03, Time: 0.35
# It: 1790, Loss: 7.537e-02, Loss_bcs: 5.484e-02, Loss_ics: 1.343e-02, Loss_res: 4.377e-03, Time: 0.33
# It: 1800, Loss: 9.437e-02, Loss_bcs: 7.325e-02, Loss_ics: 1.491e-02, Loss_res: 2.917e-03, Time: 0.33
# It: 1810, Loss: 1.089e-01, Loss_bcs: 8.087e-02, Loss_ics: 1.685e-02, Loss_res: 8.331e-03, Time: 0.34
# It: 1820, Loss: 7.085e-02, Loss_bcs: 4.807e-02, Loss_ics: 1.384e-02, Loss_res: 5.595e-03, Time: 0.32
# It: 1830, Loss: 1.060e-01, Loss_bcs: 7.433e-02, Loss_ics: 1.774e-02, Loss_res: 8.169e-03, Time: 0.36
# It: 1840, Loss: 1.062e-01, Loss_bcs: 7.871e-02, Loss_ics: 2.015e-02, Loss_res: 4.447e-03, Time: 0.33
# It: 1850, Loss: 9.353e-02, Loss_bcs: 6.882e-02, Loss_ics: 1.868e-02, Loss_res: 3.370e-03, Time: 0.33
# It: 1860, Loss: 5.710e-02, Loss_bcs: 3.546e-02, Loss_ics: 9.991e-03, Loss_res: 5.572e-03, Time: 0.34
# It: 1870, Loss: 8.011e-02, Loss_bcs: 5.901e-02, Loss_ics: 8.931e-03, Loss_res: 7.130e-03, Time: 0.34
# It: 1880, Loss: 9.960e-02, Loss_bcs: 7.854e-02, Loss_ics: 9.643e-03, Loss_res: 6.925e-03, Time: 0.32
# It: 1890, Loss: 4.683e-02, Loss_bcs: 2.637e-02, Loss_ics: 1.324e-02, Loss_res: 3.423e-03, Time: 0.35
# It: 1900, Loss: 6.480e-02, Loss_bcs: 3.890e-02, Loss_ics: 1.092e-02, Loss_res: 1.197e-02, Time: 0.35
# It: 1910, Loss: 9.166e-02, Loss_bcs: 6.633e-02, Loss_ics: 1.637e-02, Loss_res: 5.810e-03, Time: 0.34
# It: 1920, Loss: 9.549e-02, Loss_bcs: 6.905e-02, Loss_ics: 1.628e-02, Loss_res: 7.582e-03, Time: 0.34
# It: 1930, Loss: 9.091e-02, Loss_bcs: 6.109e-02, Loss_ics: 2.032e-02, Loss_res: 6.754e-03, Time: 0.35
# It: 1940, Loss: 7.409e-02, Loss_bcs: 4.836e-02, Loss_ics: 1.584e-02, Loss_res: 6.521e-03, Time: 0.33
# It: 1950, Loss: 6.040e-02, Loss_bcs: 4.519e-02, Loss_ics: 8.992e-03, Loss_res: 4.535e-03, Time: 0.34
# It: 1960, Loss: 8.112e-02, Loss_bcs: 4.725e-02, Loss_ics: 2.595e-02, Loss_res: 5.575e-03, Time: 0.35
# It: 1970, Loss: 1.159e-01, Loss_bcs: 8.509e-02, Loss_ics: 2.254e-02, Loss_res: 5.635e-03, Time: 0.34
# It: 1980, Loss: 8.575e-02, Loss_bcs: 5.517e-02, Loss_ics: 9.410e-03, Loss_res: 1.831e-02, Time: 0.37
# It: 1990, Loss: 9.399e-02, Loss_bcs: 5.773e-02, Loss_ics: 2.423e-02, Loss_res: 8.422e-03, Time: 0.33
# It: 2000, Loss: 9.237e-02, Loss_bcs: 6.492e-02, Loss_ics: 1.429e-02, Loss_res: 9.679e-03, Time: 0.34
# It: 2010, Loss: 7.644e-02, Loss_bcs: 4.639e-02, Loss_ics: 1.382e-02, Loss_res: 1.079e-02, Time: 0.34
# It: 2020, Loss: 1.003e-01, Loss_bcs: 5.624e-02, Loss_ics: 2.355e-02, Loss_res: 1.372e-02, Time: 0.34
# It: 2030, Loss: 7.325e-02, Loss_bcs: 5.652e-02, Loss_ics: 9.226e-03, Loss_res: 4.690e-03, Time: 0.35
# It: 2040, Loss: 8.943e-02, Loss_bcs: 5.932e-02, Loss_ics: 2.425e-02, Loss_res: 3.143e-03, Time: 0.34
# It: 2050, Loss: 1.106e-01, Loss_bcs: 7.468e-02, Loss_ics: 2.420e-02, Loss_res: 8.053e-03, Time: 0.35
# It: 2060, Loss: 8.443e-02, Loss_bcs: 6.373e-02, Loss_ics: 1.212e-02, Loss_res: 5.602e-03, Time: 0.36
# It: 2070, Loss: 1.254e-01, Loss_bcs: 7.362e-02, Loss_ics: 4.158e-02, Loss_res: 5.821e-03, Time: 0.34
# It: 2080, Loss: 7.721e-02, Loss_bcs: 5.848e-02, Loss_ics: 8.214e-03, Loss_res: 7.058e-03, Time: 0.35
# It: 2090, Loss: 6.847e-02, Loss_bcs: 5.140e-02, Loss_ics: 1.064e-02, Loss_res: 3.710e-03, Time: 0.34
# It: 2100, Loss: 8.609e-02, Loss_bcs: 5.233e-02, Loss_ics: 2.622e-02, Loss_res: 3.613e-03, Time: 0.33
# It: 2110, Loss: 5.540e-02, Loss_bcs: 3.488e-02, Loss_ics: 1.086e-02, Loss_res: 6.143e-03, Time: 0.36
# It: 2120, Loss: 8.637e-02, Loss_bcs: 6.024e-02, Loss_ics: 1.761e-02, Loss_res: 5.245e-03, Time: 0.34
# It: 2130, Loss: 8.537e-02, Loss_bcs: 6.130e-02, Loss_ics: 1.693e-02, Loss_res: 3.440e-03, Time: 0.36
# It: 2140, Loss: 6.808e-02, Loss_bcs: 4.625e-02, Loss_ics: 1.676e-02, Loss_res: 2.691e-03, Time: 0.34
# It: 2150, Loss: 8.578e-02, Loss_bcs: 6.593e-02, Loss_ics: 1.439e-02, Loss_res: 3.240e-03, Time: 0.35
# It: 2160, Loss: 6.485e-02, Loss_bcs: 4.408e-02, Loss_ics: 1.568e-02, Loss_res: 2.416e-03, Time: 0.34
# It: 2170, Loss: 8.115e-02, Loss_bcs: 6.313e-02, Loss_ics: 1.190e-02, Loss_res: 3.528e-03, Time: 0.35
# It: 2180, Loss: 9.427e-02, Loss_bcs: 6.167e-02, Loss_ics: 2.310e-02, Loss_res: 5.018e-03, Time: 0.33
# It: 2190, Loss: 6.608e-02, Loss_bcs: 4.245e-02, Loss_ics: 1.646e-02, Loss_res: 2.867e-03, Time: 0.33
# It: 2200, Loss: 7.964e-02, Loss_bcs: 4.670e-02, Loss_ics: 2.518e-02, Loss_res: 2.803e-03, Time: 0.34
# It: 2210, Loss: 1.025e-01, Loss_bcs: 7.236e-02, Loss_ics: 2.228e-02, Loss_res: 5.137e-03, Time: 0.34
# It: 2220, Loss: 4.887e-02, Loss_bcs: 3.357e-02, Loss_ics: 8.139e-03, Loss_res: 4.475e-03, Time: 0.35
# It: 2230, Loss: 9.853e-02, Loss_bcs: 6.504e-02, Loss_ics: 2.020e-02, Loss_res: 1.132e-02, Time: 0.36
# It: 2240, Loss: 1.094e-01, Loss_bcs: 8.565e-02, Loss_ics: 1.213e-02, Loss_res: 8.558e-03, Time: 0.33
# It: 2250, Loss: 8.439e-02, Loss_bcs: 5.770e-02, Loss_ics: 2.119e-02, Loss_res: 3.756e-03, Time: 0.34
# It: 2260, Loss: 1.058e-01, Loss_bcs: 7.824e-02, Loss_ics: 1.733e-02, Loss_res: 7.327e-03, Time: 0.34
# It: 2270, Loss: 8.757e-02, Loss_bcs: 6.839e-02, Loss_ics: 1.397e-02, Loss_res: 2.958e-03, Time: 0.33
# It: 2280, Loss: 8.812e-02, Loss_bcs: 6.186e-02, Loss_ics: 1.785e-02, Loss_res: 5.478e-03, Time: 0.33
# It: 2290, Loss: 6.883e-02, Loss_bcs: 4.478e-02, Loss_ics: 1.481e-02, Loss_res: 7.188e-03, Time: 0.35
# It: 2300, Loss: 6.621e-02, Loss_bcs: 3.327e-02, Loss_ics: 2.026e-02, Loss_res: 1.005e-02, Time: 0.35
# It: 2310, Loss: 1.054e-01, Loss_bcs: 7.375e-02, Loss_ics: 2.135e-02, Loss_res: 7.372e-03, Time: 0.34
# It: 2320, Loss: 7.255e-02, Loss_bcs: 4.657e-02, Loss_ics: 1.732e-02, Loss_res: 6.341e-03, Time: 0.34
# It: 2330, Loss: 1.099e-01, Loss_bcs: 7.859e-02, Loss_ics: 2.336e-02, Loss_res: 4.950e-03, Time: 0.33
# It: 2340, Loss: 5.591e-02, Loss_bcs: 3.202e-02, Loss_ics: 1.534e-02, Loss_res: 3.845e-03, Time: 0.35
# It: 2350, Loss: 5.977e-02, Loss_bcs: 4.260e-02, Loss_ics: 8.343e-03, Loss_res: 7.327e-03, Time: 0.35
# It: 2360, Loss: 9.399e-02, Loss_bcs: 6.025e-02, Loss_ics: 2.067e-02, Loss_res: 9.507e-03, Time: 0.34
# It: 2370, Loss: 6.779e-02, Loss_bcs: 4.173e-02, Loss_ics: 1.914e-02, Loss_res: 4.181e-03, Time: 0.36
# It: 2380, Loss: 6.167e-02, Loss_bcs: 3.960e-02, Loss_ics: 1.279e-02, Loss_res: 5.018e-03, Time: 0.34
# It: 2390, Loss: 6.967e-02, Loss_bcs: 4.336e-02, Loss_ics: 1.143e-02, Loss_res: 1.220e-02, Time: 0.33
# It: 2400, Loss: 7.476e-02, Loss_bcs: 4.904e-02, Loss_ics: 1.674e-02, Loss_res: 7.368e-03, Time: 0.36
# It: 2410, Loss: 7.320e-02, Loss_bcs: 5.508e-02, Loss_ics: 1.286e-02, Loss_res: 3.272e-03, Time: 0.35
# It: 2420, Loss: 7.529e-02, Loss_bcs: 5.406e-02, Loss_ics: 1.209e-02, Loss_res: 6.033e-03, Time: 0.35
# It: 2430, Loss: 9.564e-02, Loss_bcs: 7.022e-02, Loss_ics: 1.695e-02, Loss_res: 5.358e-03, Time: 0.35
# It: 2440, Loss: 7.605e-02, Loss_bcs: 5.313e-02, Loss_ics: 1.781e-02, Loss_res: 2.988e-03, Time: 0.33
# It: 2450, Loss: 8.050e-02, Loss_bcs: 6.423e-02, Loss_ics: 8.043e-03, Loss_res: 5.353e-03, Time: 0.34
# It: 2460, Loss: 5.519e-02, Loss_bcs: 3.436e-02, Loss_ics: 1.545e-02, Loss_res: 3.205e-03, Time: 0.36
# It: 2470, Loss: 9.378e-02, Loss_bcs: 6.795e-02, Loss_ics: 1.923e-02, Loss_res: 4.895e-03, Time: 0.34
# It: 2480, Loss: 8.116e-02, Loss_bcs: 5.376e-02, Loss_ics: 1.998e-02, Loss_res: 4.456e-03, Time: 0.35
# It: 2490, Loss: 8.202e-02, Loss_bcs: 5.739e-02, Loss_ics: 1.805e-02, Loss_res: 3.215e-03, Time: 0.33
# It: 2500, Loss: 7.285e-02, Loss_bcs: 5.012e-02, Loss_ics: 1.697e-02, Loss_res: 3.325e-03, Time: 0.32
# It: 2510, Loss: 1.040e-01, Loss_bcs: 7.428e-02, Loss_ics: 1.810e-02, Loss_res: 7.250e-03, Time: 0.34
# It: 2520, Loss: 9.930e-02, Loss_bcs: 6.846e-02, Loss_ics: 2.169e-02, Loss_res: 5.422e-03, Time: 0.35
# It: 2530, Loss: 7.943e-02, Loss_bcs: 6.255e-02, Loss_ics: 1.034e-02, Loss_res: 3.143e-03, Time: 0.35
# It: 2540, Loss: 6.873e-02, Loss_bcs: 3.836e-02, Loss_ics: 1.990e-02, Loss_res: 5.933e-03, Time: 0.33
# It: 2550, Loss: 7.125e-02, Loss_bcs: 4.950e-02, Loss_ics: 1.290e-02, Loss_res: 6.112e-03, Time: 0.34
# It: 2560, Loss: 8.393e-02, Loss_bcs: 6.149e-02, Loss_ics: 1.773e-02, Loss_res: 2.353e-03, Time: 0.32
# It: 2570, Loss: 1.116e-01, Loss_bcs: 8.019e-02, Loss_ics: 1.970e-02, Loss_res: 9.516e-03, Time: 0.33
# It: 2580, Loss: 8.870e-02, Loss_bcs: 6.841e-02, Loss_ics: 1.421e-02, Loss_res: 3.622e-03, Time: 0.35
# It: 2590, Loss: 7.268e-02, Loss_bcs: 4.913e-02, Loss_ics: 1.679e-02, Loss_res: 4.579e-03, Time: 0.33
# It: 2600, Loss: 7.406e-02, Loss_bcs: 5.637e-02, Loss_ics: 1.165e-02, Loss_res: 2.856e-03, Time: 0.35
# It: 2610, Loss: 9.421e-02, Loss_bcs: 6.631e-02, Loss_ics: 1.586e-02, Loss_res: 7.202e-03, Time: 0.33
# It: 2620, Loss: 1.032e-01, Loss_bcs: 6.877e-02, Loss_ics: 2.356e-02, Loss_res: 5.976e-03, Time: 0.33
# It: 2630, Loss: 9.140e-02, Loss_bcs: 6.641e-02, Loss_ics: 1.649e-02, Loss_res: 4.315e-03, Time: 0.45
# It: 2640, Loss: 6.961e-02, Loss_bcs: 4.505e-02, Loss_ics: 1.510e-02, Loss_res: 5.530e-03, Time: 0.40
# It: 2650, Loss: 5.649e-02, Loss_bcs: 3.382e-02, Loss_ics: 1.282e-02, Loss_res: 7.124e-03, Time: 0.40
# It: 2660, Loss: 8.098e-02, Loss_bcs: 4.210e-02, Loss_ics: 1.093e-02, Loss_res: 2.454e-02, Time: 0.42
# It: 2670, Loss: 7.106e-02, Loss_bcs: 5.286e-02, Loss_ics: 1.348e-02, Loss_res: 2.906e-03, Time: 0.37
# It: 2680, Loss: 7.382e-02, Loss_bcs: 4.907e-02, Loss_ics: 1.924e-02, Loss_res: 2.856e-03, Time: 0.34
# It: 2690, Loss: 7.709e-02, Loss_bcs: 5.676e-02, Loss_ics: 1.337e-02, Loss_res: 4.312e-03, Time: 0.34
# It: 2700, Loss: 6.906e-02, Loss_bcs: 5.066e-02, Loss_ics: 1.056e-02, Loss_res: 5.402e-03, Time: 0.35
# It: 2710, Loss: 1.125e-01, Loss_bcs: 8.081e-02, Loss_ics: 2.344e-02, Loss_res: 6.588e-03, Time: 0.34
# It: 2720, Loss: 7.436e-02, Loss_bcs: 5.166e-02, Loss_ics: 1.584e-02, Loss_res: 3.049e-03, Time: 0.34
# It: 2730, Loss: 7.510e-02, Loss_bcs: 5.886e-02, Loss_ics: 8.222e-03, Loss_res: 5.843e-03, Time: 0.51
# It: 2740, Loss: 7.488e-02, Loss_bcs: 4.217e-02, Loss_ics: 2.160e-02, Loss_res: 8.902e-03, Time: 0.63
# It: 2750, Loss: 7.246e-02, Loss_bcs: 5.065e-02, Loss_ics: 1.212e-02, Loss_res: 8.200e-03, Time: 0.34
# It: 2760, Loss: 6.560e-02, Loss_bcs: 4.662e-02, Loss_ics: 1.379e-02, Loss_res: 2.950e-03, Time: 1.24
# It: 2770, Loss: 7.874e-02, Loss_bcs: 5.468e-02, Loss_ics: 1.676e-02, Loss_res: 4.812e-03, Time: 0.95
# It: 2780, Loss: 6.159e-02, Loss_bcs: 4.586e-02, Loss_ics: 1.021e-02, Loss_res: 2.371e-03, Time: 0.64
# It: 2790, Loss: 9.602e-02, Loss_bcs: 6.884e-02, Loss_ics: 1.859e-02, Loss_res: 5.450e-03, Time: 0.35
# It: 2800, Loss: 6.901e-02, Loss_bcs: 3.396e-02, Loss_ics: 2.094e-02, Loss_res: 8.481e-03, Time: 0.35
# It: 2810, Loss: 7.141e-02, Loss_bcs: 4.939e-02, Loss_ics: 1.438e-02, Loss_res: 3.916e-03, Time: 0.36
# It: 2820, Loss: 8.940e-02, Loss_bcs: 6.092e-02, Loss_ics: 2.120e-02, Loss_res: 3.060e-03, Time: 0.34
# It: 2830, Loss: 6.539e-02, Loss_bcs: 3.996e-02, Loss_ics: 1.727e-02, Loss_res: 4.722e-03, Time: 0.33
# It: 2840, Loss: 7.596e-02, Loss_bcs: 5.340e-02, Loss_ics: 1.647e-02, Loss_res: 3.580e-03, Time: 0.34
# It: 2850, Loss: 7.519e-02, Loss_bcs: 5.582e-02, Loss_ics: 1.485e-02, Loss_res: 2.143e-03, Time: 0.34
# It: 2860, Loss: 7.051e-02, Loss_bcs: 4.276e-02, Loss_ics: 1.883e-02, Loss_res: 6.309e-03, Time: 0.34
# It: 2870, Loss: 8.426e-02, Loss_bcs: 4.291e-02, Loss_ics: 3.271e-02, Loss_res: 4.617e-03, Time: 0.35
# It: 2880, Loss: 8.041e-02, Loss_bcs: 6.077e-02, Loss_ics: 1.303e-02, Loss_res: 3.913e-03, Time: 0.33
# It: 2890, Loss: 1.092e-01, Loss_bcs: 9.303e-02, Loss_ics: 9.352e-03, Loss_res: 3.588e-03, Time: 0.36
# It: 2900, Loss: 8.094e-02, Loss_bcs: 5.931e-02, Loss_ics: 1.574e-02, Loss_res: 3.164e-03, Time: 0.34
# It: 2910, Loss: 7.348e-02, Loss_bcs: 5.401e-02, Loss_ics: 1.156e-02, Loss_res: 5.871e-03, Time: 0.36
# It: 2920, Loss: 6.523e-02, Loss_bcs: 4.452e-02, Loss_ics: 1.300e-02, Loss_res: 6.102e-03, Time: 0.35
# It: 2930, Loss: 5.938e-02, Loss_bcs: 4.442e-02, Loss_ics: 1.018e-02, Loss_res: 2.360e-03, Time: 0.35
# It: 2940, Loss: 7.798e-02, Loss_bcs: 5.404e-02, Loss_ics: 1.578e-02, Loss_res: 6.074e-03, Time: 0.34
# It: 2950, Loss: 5.428e-02, Loss_bcs: 3.494e-02, Loss_ics: 8.795e-03, Loss_res: 8.158e-03, Time: 0.34
# It: 2960, Loss: 7.173e-02, Loss_bcs: 4.110e-02, Loss_ics: 1.962e-02, Loss_res: 6.941e-03, Time: 0.34
# It: 2970, Loss: 7.459e-02, Loss_bcs: 5.813e-02, Loss_ics: 1.045e-02, Loss_res: 3.189e-03, Time: 0.33
# It: 2980, Loss: 1.008e-01, Loss_bcs: 6.649e-02, Loss_ics: 1.938e-02, Loss_res: 1.277e-02, Time: 0.34
# It: 2990, Loss: 8.075e-02, Loss_bcs: 6.362e-02, Loss_ics: 9.816e-03, Loss_res: 5.205e-03, Time: 0.32
# It: 3000, Loss: 7.983e-02, Loss_bcs: 6.572e-02, Loss_ics: 9.120e-03, Loss_res: 2.929e-03, Time: 0.32
# It: 3010, Loss: 5.599e-02, Loss_bcs: 3.464e-02, Loss_ics: 1.182e-02, Loss_res: 6.363e-03, Time: 0.34
# It: 3020, Loss: 9.305e-02, Loss_bcs: 6.875e-02, Loss_ics: 1.040e-02, Loss_res: 1.086e-02, Time: 0.34
# It: 3030, Loss: 7.212e-02, Loss_bcs: 4.357e-02, Loss_ics: 1.470e-02, Loss_res: 1.111e-02, Time: 0.34
# It: 3040, Loss: 6.243e-02, Loss_bcs: 4.380e-02, Loss_ics: 1.073e-02, Loss_res: 5.509e-03, Time: 0.33
# It: 3050, Loss: 8.343e-02, Loss_bcs: 5.528e-02, Loss_ics: 2.035e-02, Loss_res: 3.438e-03, Time: 0.33
# It: 3060, Loss: 7.539e-02, Loss_bcs: 5.391e-02, Loss_ics: 1.189e-02, Loss_res: 7.091e-03, Time: 0.34
# It: 3070, Loss: 1.124e-01, Loss_bcs: 7.815e-02, Loss_ics: 2.704e-02, Loss_res: 3.635e-03, Time: 0.36
# It: 3080, Loss: 6.148e-02, Loss_bcs: 3.897e-02, Loss_ics: 1.403e-02, Loss_res: 6.249e-03, Time: 0.34
# It: 3090, Loss: 9.250e-02, Loss_bcs: 6.972e-02, Loss_ics: 1.719e-02, Loss_res: 3.047e-03, Time: 0.34
# It: 3100, Loss: 8.918e-02, Loss_bcs: 6.339e-02, Loss_ics: 1.652e-02, Loss_res: 6.530e-03, Time: 0.33
# It: 3110, Loss: 7.114e-02, Loss_bcs: 5.362e-02, Loss_ics: 1.216e-02, Loss_res: 3.366e-03, Time: 0.34
# It: 3120, Loss: 5.968e-02, Loss_bcs: 4.354e-02, Loss_ics: 1.023e-02, Loss_res: 3.815e-03, Time: 0.33
# It: 3130, Loss: 5.136e-02, Loss_bcs: 2.740e-02, Loss_ics: 1.492e-02, Loss_res: 6.500e-03, Time: 0.33
# It: 3140, Loss: 8.125e-02, Loss_bcs: 6.208e-02, Loss_ics: 8.146e-03, Loss_res: 8.572e-03, Time: 0.34
# It: 3150, Loss: 1.064e-01, Loss_bcs: 4.095e-02, Loss_ics: 4.296e-02, Loss_res: 1.790e-02, Time: 0.33
# It: 3160, Loss: 8.302e-02, Loss_bcs: 4.917e-02, Loss_ics: 8.664e-03, Loss_res: 2.120e-02, Time: 0.33
# It: 3170, Loss: 7.184e-02, Loss_bcs: 4.646e-02, Loss_ics: 1.289e-02, Loss_res: 8.562e-03, Time: 0.34
# It: 3180, Loss: 8.333e-02, Loss_bcs: 6.910e-02, Loss_ics: 9.588e-03, Loss_res: 3.074e-03, Time: 0.36
# It: 3190, Loss: 7.547e-02, Loss_bcs: 4.925e-02, Loss_ics: 1.558e-02, Loss_res: 7.970e-03, Time: 0.36
# It: 3200, Loss: 7.460e-02, Loss_bcs: 4.284e-02, Loss_ics: 2.162e-02, Loss_res: 4.854e-03, Time: 0.34
# It: 3210, Loss: 5.146e-02, Loss_bcs: 3.593e-02, Loss_ics: 9.188e-03, Loss_res: 3.567e-03, Time: 0.33
# It: 3220, Loss: 9.931e-02, Loss_bcs: 7.369e-02, Loss_ics: 1.916e-02, Loss_res: 4.132e-03, Time: 0.34
# It: 3230, Loss: 9.775e-02, Loss_bcs: 7.488e-02, Loss_ics: 1.616e-02, Loss_res: 4.145e-03, Time: 0.35
# It: 3240, Loss: 9.740e-02, Loss_bcs: 7.387e-02, Loss_ics: 1.565e-02, Loss_res: 5.093e-03, Time: 0.35
# It: 3250, Loss: 7.874e-02, Loss_bcs: 5.207e-02, Loss_ics: 1.605e-02, Loss_res: 7.404e-03, Time: 0.35
# It: 3260, Loss: 6.180e-02, Loss_bcs: 3.286e-02, Loss_ics: 1.275e-02, Loss_res: 1.255e-02, Time: 0.35
# It: 3270, Loss: 6.762e-02, Loss_bcs: 4.571e-02, Loss_ics: 1.022e-02, Loss_res: 9.036e-03, Time: 0.34
# It: 3280, Loss: 1.117e-01, Loss_bcs: 8.473e-02, Loss_ics: 1.931e-02, Loss_res: 4.509e-03, Time: 0.32
# It: 3290, Loss: 8.493e-02, Loss_bcs: 5.533e-02, Loss_ics: 2.139e-02, Loss_res: 5.646e-03, Time: 0.34
# It: 3300, Loss: 6.391e-02, Loss_bcs: 5.011e-02, Loss_ics: 7.680e-03, Loss_res: 4.122e-03, Time: 0.34
# It: 3310, Loss: 8.259e-02, Loss_bcs: 4.963e-02, Loss_ics: 1.857e-02, Loss_res: 1.241e-02, Time: 0.34
# It: 3320, Loss: 4.413e-02, Loss_bcs: 2.638e-02, Loss_ics: 1.097e-02, Loss_res: 4.242e-03, Time: 0.35
# It: 3330, Loss: 6.544e-02, Loss_bcs: 4.842e-02, Loss_ics: 1.011e-02, Loss_res: 5.010e-03, Time: 0.34
# It: 3340, Loss: 1.093e-01, Loss_bcs: 7.649e-02, Loss_ics: 2.412e-02, Loss_res: 5.474e-03, Time: 0.32
# It: 3350, Loss: 9.941e-02, Loss_bcs: 7.558e-02, Loss_ics: 1.160e-02, Loss_res: 8.914e-03, Time: 0.33
# It: 3360, Loss: 6.249e-02, Loss_bcs: 4.023e-02, Loss_ics: 1.495e-02, Loss_res: 3.971e-03, Time: 0.34
# It: 3370, Loss: 7.666e-02, Loss_bcs: 6.042e-02, Loss_ics: 8.019e-03, Loss_res: 5.417e-03, Time: 0.34
# It: 3380, Loss: 9.146e-02, Loss_bcs: 7.221e-02, Loss_ics: 1.040e-02, Loss_res: 6.341e-03, Time: 0.35
# It: 3390, Loss: 6.617e-02, Loss_bcs: 4.191e-02, Loss_ics: 1.358e-02, Loss_res: 8.169e-03, Time: 0.33
# It: 3400, Loss: 7.110e-02, Loss_bcs: 5.662e-02, Loss_ics: 6.676e-03, Loss_res: 4.771e-03, Time: 0.33
# It: 3410, Loss: 8.848e-02, Loss_bcs: 5.077e-02, Loss_ics: 3.022e-02, Loss_res: 3.217e-03, Time: 0.33
# It: 3420, Loss: 4.994e-02, Loss_bcs: 2.830e-02, Loss_ics: 1.645e-02, Loss_res: 2.850e-03, Time: 0.34
# It: 3430, Loss: 8.049e-02, Loss_bcs: 5.904e-02, Loss_ics: 1.136e-02, Loss_res: 7.598e-03, Time: 0.34
# It: 3440, Loss: 7.904e-02, Loss_bcs: 5.515e-02, Loss_ics: 1.645e-02, Loss_res: 4.228e-03, Time: 0.34
# It: 3450, Loss: 7.778e-02, Loss_bcs: 5.865e-02, Loss_ics: 1.205e-02, Loss_res: 4.687e-03, Time: 0.34
# It: 3460, Loss: 5.894e-02, Loss_bcs: 3.932e-02, Loss_ics: 1.443e-02, Loss_res: 2.838e-03, Time: 0.32
# It: 3470, Loss: 7.263e-02, Loss_bcs: 4.989e-02, Loss_ics: 1.300e-02, Loss_res: 4.907e-03, Time: 0.33
# It: 3480, Loss: 7.845e-02, Loss_bcs: 6.165e-02, Loss_ics: 1.092e-02, Loss_res: 3.797e-03, Time: 0.35
# It: 3490, Loss: 5.329e-02, Loss_bcs: 3.275e-02, Loss_ics: 1.405e-02, Loss_res: 3.854e-03, Time: 0.35
# It: 3500, Loss: 6.160e-02, Loss_bcs: 4.090e-02, Loss_ics: 1.237e-02, Loss_res: 5.305e-03, Time: 0.34
# It: 3510, Loss: 1.286e-01, Loss_bcs: 9.429e-02, Loss_ics: 1.986e-02, Loss_res: 1.134e-02, Time: 0.33
# It: 3520, Loss: 7.041e-02, Loss_bcs: 4.626e-02, Loss_ics: 1.304e-02, Loss_res: 7.322e-03, Time: 0.34
# It: 3530, Loss: 8.238e-02, Loss_bcs: 6.351e-02, Loss_ics: 8.542e-03, Loss_res: 7.625e-03, Time: 0.33
# It: 3540, Loss: 5.874e-02, Loss_bcs: 4.290e-02, Loss_ics: 5.692e-03, Loss_res: 7.780e-03, Time: 0.34
# It: 3550, Loss: 7.860e-02, Loss_bcs: 4.495e-02, Loss_ics: 2.097e-02, Loss_res: 1.066e-02, Time: 0.34
# It: 3560, Loss: 9.580e-02, Loss_bcs: 6.258e-02, Loss_ics: 2.315e-02, Loss_res: 4.840e-03, Time: 0.33
# It: 3570, Loss: 6.492e-02, Loss_bcs: 4.611e-02, Loss_ics: 9.728e-03, Loss_res: 6.598e-03, Time: 0.32
# It: 3580, Loss: 8.432e-02, Loss_bcs: 6.529e-02, Loss_ics: 1.429e-02, Loss_res: 2.268e-03, Time: 0.33
# It: 3590, Loss: 5.544e-02, Loss_bcs: 3.828e-02, Loss_ics: 8.816e-03, Loss_res: 5.914e-03, Time: 0.33
# It: 3600, Loss: 6.028e-02, Loss_bcs: 4.379e-02, Loss_ics: 8.314e-03, Loss_res: 5.841e-03, Time: 0.34
# It: 3610, Loss: 4.286e-02, Loss_bcs: 2.752e-02, Loss_ics: 8.648e-03, Loss_res: 4.051e-03, Time: 0.32
# It: 3620, Loss: 7.877e-02, Loss_bcs: 5.471e-02, Loss_ics: 1.594e-02, Loss_res: 5.720e-03, Time: 0.34
# It: 3630, Loss: 9.708e-02, Loss_bcs: 7.382e-02, Loss_ics: 1.670e-02, Loss_res: 3.938e-03, Time: 0.34
# It: 3640, Loss: 9.548e-02, Loss_bcs: 6.427e-02, Loss_ics: 2.263e-02, Loss_res: 5.197e-03, Time: 0.33
# It: 3650, Loss: 8.104e-02, Loss_bcs: 5.874e-02, Loss_ics: 1.542e-02, Loss_res: 3.877e-03, Time: 0.35
# It: 3660, Loss: 7.490e-02, Loss_bcs: 5.479e-02, Loss_ics: 1.350e-02, Loss_res: 4.600e-03, Time: 0.34
# It: 3670, Loss: 8.919e-02, Loss_bcs: 6.998e-02, Loss_ics: 1.200e-02, Loss_res: 4.731e-03, Time: 0.35
# It: 3680, Loss: 1.147e-01, Loss_bcs: 8.188e-02, Loss_ics: 2.334e-02, Loss_res: 5.385e-03, Time: 0.34
# It: 3690, Loss: 6.434e-02, Loss_bcs: 4.455e-02, Loss_ics: 1.311e-02, Loss_res: 3.253e-03, Time: 0.34
# It: 3700, Loss: 6.840e-02, Loss_bcs: 5.299e-02, Loss_ics: 9.260e-03, Loss_res: 3.755e-03, Time: 0.33
# It: 3710, Loss: 8.461e-02, Loss_bcs: 6.542e-02, Loss_ics: 9.231e-03, Loss_res: 7.138e-03, Time: 0.34
# It: 3720, Loss: 8.305e-02, Loss_bcs: 6.224e-02, Loss_ics: 1.509e-02, Loss_res: 3.829e-03, Time: 0.35
# It: 3730, Loss: 9.445e-02, Loss_bcs: 6.733e-02, Loss_ics: 1.942e-02, Loss_res: 4.162e-03, Time: 0.35
# It: 3740, Loss: 7.856e-02, Loss_bcs: 5.884e-02, Loss_ics: 9.321e-03, Loss_res: 7.295e-03, Time: 0.34
# It: 3750, Loss: 6.944e-02, Loss_bcs: 4.482e-02, Loss_ics: 1.507e-02, Loss_res: 3.534e-03, Time: 0.33
# It: 3760, Loss: 5.362e-02, Loss_bcs: 3.591e-02, Loss_ics: 1.274e-02, Loss_res: 2.060e-03, Time: 0.35
# It: 3770, Loss: 6.230e-02, Loss_bcs: 4.701e-02, Loss_ics: 4.878e-03, Loss_res: 8.124e-03, Time: 0.35
# It: 3780, Loss: 6.682e-02, Loss_bcs: 4.581e-02, Loss_ics: 1.410e-02, Loss_res: 4.507e-03, Time: 0.34
# It: 3790, Loss: 6.630e-02, Loss_bcs: 5.000e-02, Loss_ics: 1.011e-02, Loss_res: 4.301e-03, Time: 0.33
# It: 3800, Loss: 6.599e-02, Loss_bcs: 5.001e-02, Loss_ics: 1.007e-02, Loss_res: 3.562e-03, Time: 0.35
# It: 3810, Loss: 6.264e-02, Loss_bcs: 4.492e-02, Loss_ics: 7.847e-03, Loss_res: 7.249e-03, Time: 0.35
# It: 3820, Loss: 8.442e-02, Loss_bcs: 6.004e-02, Loss_ics: 9.342e-03, Loss_res: 9.699e-03, Time: 0.34
# It: 3830, Loss: 9.577e-02, Loss_bcs: 6.576e-02, Loss_ics: 1.945e-02, Loss_res: 7.178e-03, Time: 0.35
# It: 3840, Loss: 7.853e-02, Loss_bcs: 6.254e-02, Loss_ics: 7.282e-03, Loss_res: 5.809e-03, Time: 0.33
# It: 3850, Loss: 7.620e-02, Loss_bcs: 5.461e-02, Loss_ics: 1.535e-02, Loss_res: 3.118e-03, Time: 0.35
# It: 3860, Loss: 3.889e-02, Loss_bcs: 2.242e-02, Loss_ics: 8.496e-03, Loss_res: 5.646e-03, Time: 0.33
# It: 3870, Loss: 4.631e-02, Loss_bcs: 2.354e-02, Loss_ics: 1.415e-02, Loss_res: 4.560e-03, Time: 0.33
# It: 3880, Loss: 7.050e-02, Loss_bcs: 5.286e-02, Loss_ics: 1.174e-02, Loss_res: 3.446e-03, Time: 0.35
# It: 3890, Loss: 6.380e-02, Loss_bcs: 4.682e-02, Loss_ics: 9.903e-03, Loss_res: 4.702e-03, Time: 0.35
# It: 3900, Loss: 7.148e-02, Loss_bcs: 4.869e-02, Loss_ics: 1.669e-02, Loss_res: 3.247e-03, Time: 0.35
# It: 3910, Loss: 6.378e-02, Loss_bcs: 4.549e-02, Loss_ics: 7.468e-03, Loss_res: 8.601e-03, Time: 0.34
# It: 3920, Loss: 5.339e-02, Loss_bcs: 3.856e-02, Loss_ics: 9.885e-03, Loss_res: 3.093e-03, Time: 0.33
# It: 3930, Loss: 9.211e-02, Loss_bcs: 7.197e-02, Loss_ics: 1.022e-02, Loss_res: 7.573e-03, Time: 0.34
# It: 3940, Loss: 7.332e-02, Loss_bcs: 5.483e-02, Loss_ics: 1.291e-02, Loss_res: 2.583e-03, Time: 0.34
# It: 3950, Loss: 4.974e-02, Loss_bcs: 2.519e-02, Loss_ics: 1.406e-02, Loss_res: 8.124e-03, Time: 0.33
# It: 3960, Loss: 6.318e-02, Loss_bcs: 4.166e-02, Loss_ics: 1.425e-02, Loss_res: 5.359e-03, Time: 0.34
# It: 3970, Loss: 8.439e-02, Loss_bcs: 5.855e-02, Loss_ics: 1.610e-02, Loss_res: 6.555e-03, Time: 0.35
# It: 3980, Loss: 8.360e-02, Loss_bcs: 6.439e-02, Loss_ics: 1.054e-02, Loss_res: 6.444e-03, Time: 0.32
# It: 3990, Loss: 6.406e-02, Loss_bcs: 4.332e-02, Loss_ics: 8.753e-03, Loss_res: 9.597e-03, Time: 0.33
# It: 4000, Loss: 5.070e-02, Loss_bcs: 3.213e-02, Loss_ics: 9.573e-03, Loss_res: 6.316e-03, Time: 0.35
# It: 4010, Loss: 6.209e-02, Loss_bcs: 4.756e-02, Loss_ics: 8.540e-03, Loss_res: 3.615e-03, Time: 0.34
# It: 4020, Loss: 8.102e-02, Loss_bcs: 5.374e-02, Loss_ics: 2.150e-02, Loss_res: 2.600e-03, Time: 0.34
# It: 4030, Loss: 1.045e-01, Loss_bcs: 6.783e-02, Loss_ics: 2.498e-02, Loss_res: 8.294e-03, Time: 0.34
# It: 4040, Loss: 4.374e-02, Loss_bcs: 2.631e-02, Loss_ics: 1.235e-02, Loss_res: 3.224e-03, Time: 0.34
# It: 4050, Loss: 5.078e-02, Loss_bcs: 2.868e-02, Loss_ics: 1.223e-02, Loss_res: 6.488e-03, Time: 0.36
# It: 4060, Loss: 9.841e-02, Loss_bcs: 7.824e-02, Loss_ics: 9.779e-03, Loss_res: 7.945e-03, Time: 0.35
# It: 4070, Loss: 6.665e-02, Loss_bcs: 4.392e-02, Loss_ics: 1.198e-02, Loss_res: 7.112e-03, Time: 0.35
# It: 4080, Loss: 8.091e-02, Loss_bcs: 6.030e-02, Loss_ics: 1.255e-02, Loss_res: 5.298e-03, Time: 0.33
# It: 4090, Loss: 8.495e-02, Loss_bcs: 6.986e-02, Loss_ics: 8.361e-03, Loss_res: 4.504e-03, Time: 0.32
# It: 4100, Loss: 6.511e-02, Loss_bcs: 4.674e-02, Loss_ics: 1.179e-02, Loss_res: 4.376e-03, Time: 0.32
# It: 4110, Loss: 4.735e-02, Loss_bcs: 3.251e-02, Loss_ics: 7.937e-03, Loss_res: 5.021e-03, Time: 0.35
# It: 4120, Loss: 8.584e-02, Loss_bcs: 6.352e-02, Loss_ics: 1.380e-02, Loss_res: 6.079e-03, Time: 0.34
# It: 4130, Loss: 8.016e-02, Loss_bcs: 5.823e-02, Loss_ics: 1.560e-02, Loss_res: 4.024e-03, Time: 0.33
# It: 4140, Loss: 6.325e-02, Loss_bcs: 5.002e-02, Loss_ics: 7.794e-03, Loss_res: 3.106e-03, Time: 0.35
# It: 4150, Loss: 7.899e-02, Loss_bcs: 5.450e-02, Loss_ics: 1.768e-02, Loss_res: 3.228e-03, Time: 0.33
# It: 4160, Loss: 5.379e-02, Loss_bcs: 3.216e-02, Loss_ics: 1.289e-02, Loss_res: 4.224e-03, Time: 0.36
# It: 4170, Loss: 9.236e-02, Loss_bcs: 7.150e-02, Loss_ics: 9.643e-03, Loss_res: 8.644e-03, Time: 0.36
# It: 4180, Loss: 8.334e-02, Loss_bcs: 5.213e-02, Loss_ics: 1.990e-02, Loss_res: 8.257e-03, Time: 0.33
# It: 4190, Loss: 4.920e-02, Loss_bcs: 3.610e-02, Loss_ics: 7.831e-03, Loss_res: 2.832e-03, Time: 0.34
# It: 4200, Loss: 8.152e-02, Loss_bcs: 6.149e-02, Loss_ics: 1.558e-02, Loss_res: 2.125e-03, Time: 0.34
# It: 4210, Loss: 5.969e-02, Loss_bcs: 3.973e-02, Loss_ics: 9.672e-03, Loss_res: 7.407e-03, Time: 0.33
# It: 4220, Loss: 6.424e-02, Loss_bcs: 3.539e-02, Loss_ics: 2.244e-02, Loss_res: 3.741e-03, Time: 0.34
# It: 4230, Loss: 9.166e-02, Loss_bcs: 7.353e-02, Loss_ics: 1.071e-02, Loss_res: 4.103e-03, Time: 0.35
# It: 4240, Loss: 4.068e-02, Loss_bcs: 2.253e-02, Loss_ics: 8.087e-03, Loss_res: 7.932e-03, Time: 0.34
# It: 4250, Loss: 6.867e-02, Loss_bcs: 4.659e-02, Loss_ics: 1.553e-02, Loss_res: 4.097e-03, Time: 0.34
# It: 4260, Loss: 7.620e-02, Loss_bcs: 5.941e-02, Loss_ics: 1.025e-02, Loss_res: 3.474e-03, Time: 0.33
# It: 4270, Loss: 8.851e-02, Loss_bcs: 6.181e-02, Loss_ics: 1.924e-02, Loss_res: 4.830e-03, Time: 0.32
# It: 4280, Loss: 6.265e-02, Loss_bcs: 4.814e-02, Loss_ics: 8.559e-03, Loss_res: 2.968e-03, Time: 0.33
# It: 4290, Loss: 6.162e-02, Loss_bcs: 4.492e-02, Loss_ics: 6.991e-03, Loss_res: 5.843e-03, Time: 0.33
# It: 4300, Loss: 6.944e-02, Loss_bcs: 4.958e-02, Loss_ics: 1.437e-02, Loss_res: 2.769e-03, Time: 0.34
# It: 4310, Loss: 7.491e-02, Loss_bcs: 5.024e-02, Loss_ics: 2.006e-02, Loss_res: 1.754e-03, Time: 0.35
# It: 4320, Loss: 9.501e-02, Loss_bcs: 7.198e-02, Loss_ics: 1.617e-02, Loss_res: 4.342e-03, Time: 0.34
# It: 4330, Loss: 5.831e-02, Loss_bcs: 3.701e-02, Loss_ics: 1.285e-02, Loss_res: 5.209e-03, Time: 0.34
# It: 4340, Loss: 8.022e-02, Loss_bcs: 5.928e-02, Loss_ics: 1.366e-02, Loss_res: 4.666e-03, Time: 0.36
# It: 4350, Loss: 6.374e-02, Loss_bcs: 3.171e-02, Loss_ics: 1.844e-02, Loss_res: 9.681e-03, Time: 0.33
# It: 4360, Loss: 7.188e-02, Loss_bcs: 5.137e-02, Loss_ics: 9.434e-03, Loss_res: 8.258e-03, Time: 0.34
# It: 4370, Loss: 5.323e-02, Loss_bcs: 3.678e-02, Loss_ics: 5.428e-03, Loss_res: 9.059e-03, Time: 0.34
# It: 4380, Loss: 3.685e-02, Loss_bcs: 2.015e-02, Loss_ics: 5.154e-03, Loss_res: 7.632e-03, Time: 0.32
# It: 4390, Loss: 7.051e-02, Loss_bcs: 4.726e-02, Loss_ics: 1.544e-02, Loss_res: 4.522e-03, Time: 0.34
# It: 4400, Loss: 1.081e-01, Loss_bcs: 8.582e-02, Loss_ics: 1.543e-02, Loss_res: 4.417e-03, Time: 0.34
# It: 4410, Loss: 7.191e-02, Loss_bcs: 5.143e-02, Loss_ics: 1.510e-02, Loss_res: 2.792e-03, Time: 0.33
# It: 4420, Loss: 6.759e-02, Loss_bcs: 4.876e-02, Loss_ics: 1.402e-02, Loss_res: 2.556e-03, Time: 0.34
# It: 4430, Loss: 7.668e-02, Loss_bcs: 5.290e-02, Loss_ics: 1.599e-02, Loss_res: 5.169e-03, Time: 0.36
# It: 4440, Loss: 8.556e-02, Loss_bcs: 7.016e-02, Loss_ics: 8.851e-03, Loss_res: 4.215e-03, Time: 0.34
# It: 4450, Loss: 6.237e-02, Loss_bcs: 4.252e-02, Loss_ics: 1.275e-02, Loss_res: 3.442e-03, Time: 0.35
# It: 4460, Loss: 9.044e-02, Loss_bcs: 6.528e-02, Loss_ics: 1.824e-02, Loss_res: 3.306e-03, Time: 0.34
# It: 4470, Loss: 8.859e-02, Loss_bcs: 7.146e-02, Loss_ics: 1.034e-02, Loss_res: 4.544e-03, Time: 0.35
# It: 4480, Loss: 8.993e-02, Loss_bcs: 6.187e-02, Loss_ics: 1.913e-02, Loss_res: 4.849e-03, Time: 0.35
# It: 4490, Loss: 7.775e-02, Loss_bcs: 5.577e-02, Loss_ics: 1.069e-02, Loss_res: 7.496e-03, Time: 0.33
# It: 4500, Loss: 6.349e-02, Loss_bcs: 4.780e-02, Loss_ics: 7.818e-03, Loss_res: 5.706e-03, Time: 0.33
# It: 4510, Loss: 6.968e-02, Loss_bcs: 4.719e-02, Loss_ics: 1.432e-02, Loss_res: 5.118e-03, Time: 0.36
# It: 4520, Loss: 6.231e-02, Loss_bcs: 4.755e-02, Loss_ics: 7.786e-03, Loss_res: 4.471e-03, Time: 0.33
# It: 4530, Loss: 9.797e-02, Loss_bcs: 7.688e-02, Loss_ics: 1.283e-02, Loss_res: 5.412e-03, Time: 0.34
# It: 4540, Loss: 6.143e-02, Loss_bcs: 4.037e-02, Loss_ics: 1.314e-02, Loss_res: 5.069e-03, Time: 0.35
# It: 4550, Loss: 4.987e-02, Loss_bcs: 3.415e-02, Loss_ics: 7.618e-03, Loss_res: 5.687e-03, Time: 0.34
# It: 4560, Loss: 6.371e-02, Loss_bcs: 4.511e-02, Loss_ics: 7.725e-03, Loss_res: 8.403e-03, Time: 0.34
# It: 4570, Loss: 6.962e-02, Loss_bcs: 5.328e-02, Loss_ics: 9.647e-03, Loss_res: 4.429e-03, Time: 0.35
# It: 4580, Loss: 6.713e-02, Loss_bcs: 4.500e-02, Loss_ics: 1.552e-02, Loss_res: 2.934e-03, Time: 0.34
# It: 4590, Loss: 6.220e-02, Loss_bcs: 4.750e-02, Loss_ics: 8.221e-03, Loss_res: 4.389e-03, Time: 0.34
# It: 4600, Loss: 8.494e-02, Loss_bcs: 6.201e-02, Loss_ics: 1.162e-02, Loss_res: 9.182e-03, Time: 0.34
# It: 4610, Loss: 7.991e-02, Loss_bcs: 5.435e-02, Loss_ics: 1.779e-02, Loss_res: 5.038e-03, Time: 0.34
# It: 4620, Loss: 7.318e-02, Loss_bcs: 4.453e-02, Loss_ics: 2.041e-02, Loss_res: 5.326e-03, Time: 0.36
# It: 4630, Loss: 6.672e-02, Loss_bcs: 4.748e-02, Loss_ics: 1.006e-02, Loss_res: 6.514e-03, Time: 0.34
# It: 4640, Loss: 8.071e-02, Loss_bcs: 5.683e-02, Loss_ics: 1.429e-02, Loss_res: 5.879e-03, Time: 0.34
# It: 4650, Loss: 7.656e-02, Loss_bcs: 5.869e-02, Loss_ics: 9.088e-03, Loss_res: 4.581e-03, Time: 0.34
# It: 4660, Loss: 5.195e-02, Loss_bcs: 3.156e-02, Loss_ics: 1.300e-02, Loss_res: 5.668e-03, Time: 0.34
# It: 4670, Loss: 4.948e-02, Loss_bcs: 3.113e-02, Loss_ics: 7.229e-03, Loss_res: 7.888e-03, Time: 0.33
# It: 4680, Loss: 1.154e-01, Loss_bcs: 7.681e-02, Loss_ics: 2.354e-02, Loss_res: 1.236e-02, Time: 0.37
# It: 4690, Loss: 7.502e-02, Loss_bcs: 5.969e-02, Loss_ics: 6.099e-03, Loss_res: 6.408e-03, Time: 0.35
# It: 4700, Loss: 7.735e-02, Loss_bcs: 6.293e-02, Loss_ics: 9.567e-03, Loss_res: 2.818e-03, Time: 0.34
# ...
# It: 38440, Loss: 4.471e-02, Loss_bcs: 3.707e-02, Loss_ics: 4.439e-03, Loss_res: 1.178e-03, Time: 0.35
# It: 38450, Loss: 3.861e-02, Loss_bcs: 3.195e-02, Loss_ics: 3.393e-03, Loss_res: 8.568e-04, Time: 0.35
# It: 38460, Loss: 5.838e-02, Loss_bcs: 5.043e-02, Loss_ics: 4.433e-03, Loss_res: 1.055e-03, Time: 0.32
# It: 38470, Loss: 4.701e-02, Loss_bcs: 3.657e-02, Loss_ics: 2.194e-03, Loss_res: 6.115e-03, Time: 0.33
# It: 38480, Loss: 5.659e-02, Loss_bcs: 4.418e-02, Loss_ics: 2.730e-03, Loss_res: 7.607e-03, Time: 0.36
# It: 38490, Loss: 2.684e-02, Loss_bcs: 1.876e-02, Loss_ics: 4.074e-03, Loss_res: 1.408e-03, Time: 0.33
# It: 38500, Loss: 4.227e-02, Loss_bcs: 3.076e-02, Loss_ics: 5.048e-03, Loss_res: 4.131e-03, Time: 0.33
# It: 38510, Loss: 2.928e-02, Loss_bcs: 2.301e-02, Loss_ics: 2.526e-03, Loss_res: 1.561e-03, Time: 0.35
# It: 38520, Loss: 4.990e-02, Loss_bcs: 4.225e-02, Loss_ics: 3.187e-03, Loss_res: 2.572e-03, Time: 0.32
# It: 38530, Loss: 2.578e-02, Loss_bcs: 1.786e-02, Loss_ics: 3.120e-03, Loss_res: 2.040e-03, Time: 0.33
# It: 38540, Loss: 4.267e-02, Loss_bcs: 3.552e-02, Loss_ics: 3.907e-03, Loss_res: 1.261e-03, Time: 0.34
# It: 38550, Loss: 3.580e-02, Loss_bcs: 2.801e-02, Loss_ics: 4.325e-03, Loss_res: 1.160e-03, Time: 0.34
# It: 38560, Loss: 3.917e-02, Loss_bcs: 3.018e-02, Loss_ics: 5.047e-03, Loss_res: 1.265e-03, Time: 0.34
# It: 38570, Loss: 3.474e-02, Loss_bcs: 2.894e-02, Loss_ics: 2.738e-03, Loss_res: 7.803e-04, Time: 0.33
# It: 38580, Loss: 1.949e-02, Loss_bcs: 1.227e-02, Loss_ics: 3.772e-03, Loss_res: 9.855e-04, Time: 0.34
# It: 38590, Loss: 3.396e-02, Loss_bcs: 2.207e-02, Loss_ics: 6.503e-03, Loss_res: 2.761e-03, Time: 0.34
# It: 38600, Loss: 2.698e-02, Loss_bcs: 1.933e-02, Loss_ics: 4.066e-03, Loss_res: 1.196e-03, Time: 0.35
# It: 38610, Loss: 3.968e-02, Loss_bcs: 3.337e-02, Loss_ics: 3.429e-03, Loss_res: 7.498e-04, Time: 0.33
# It: 38620, Loss: 4.004e-02, Loss_bcs: 3.173e-02, Loss_ics: 4.860e-03, Loss_res: 1.193e-03, Time: 0.33
# It: 38630, Loss: 3.563e-02, Loss_bcs: 2.784e-02, Loss_ics: 3.689e-03, Loss_res: 1.863e-03, Time: 0.32
# It: 38640, Loss: 2.732e-02, Loss_bcs: 2.181e-02, Loss_ics: 2.287e-03, Loss_res: 9.085e-04, Time: 0.34
# It: 38650, Loss: 2.737e-02, Loss_bcs: 2.133e-02, Loss_ics: 2.241e-03, Loss_res: 1.531e-03, Time: 0.34
# It: 38660, Loss: 4.239e-02, Loss_bcs: 3.581e-02, Loss_ics: 2.199e-03, Loss_res: 2.341e-03, Time: 0.33
# It: 38670, Loss: 3.684e-02, Loss_bcs: 2.813e-02, Loss_ics: 4.337e-03, Loss_res: 2.151e-03, Time: 0.34
# It: 38680, Loss: 3.881e-02, Loss_bcs: 3.079e-02, Loss_ics: 3.116e-03, Loss_res: 2.369e-03, Time: 0.34
# It: 38690, Loss: 2.976e-02, Loss_bcs: 2.193e-02, Loss_ics: 3.699e-03, Loss_res: 1.766e-03, Time: 0.32
# It: 38700, Loss: 6.313e-02, Loss_bcs: 5.630e-02, Loss_ics: 3.357e-03, Loss_res: 1.247e-03, Time: 0.35
# It: 38710, Loss: 4.545e-02, Loss_bcs: 3.824e-02, Loss_ics: 2.864e-03, Loss_res: 1.880e-03, Time: 0.34
# It: 38720, Loss: 4.156e-02, Loss_bcs: 3.259e-02, Loss_ics: 4.621e-03, Loss_res: 1.889e-03, Time: 0.33
# It: 38730, Loss: 4.123e-02, Loss_bcs: 3.409e-02, Loss_ics: 2.422e-03, Loss_res: 2.387e-03, Time: 0.36
# It: 38740, Loss: 4.343e-02, Loss_bcs: 3.442e-02, Loss_ics: 3.605e-03, Loss_res: 3.350e-03, Time: 0.35
# It: 38750, Loss: 2.418e-02, Loss_bcs: 1.808e-02, Loss_ics: 2.592e-03, Loss_res: 1.475e-03, Time: 0.32
# It: 38760, Loss: 4.132e-02, Loss_bcs: 3.479e-02, Loss_ics: 2.870e-03, Loss_res: 1.044e-03, Time: 0.34
# It: 38770, Loss: 4.063e-02, Loss_bcs: 3.058e-02, Loss_ics: 5.621e-03, Loss_res: 2.212e-03, Time: 0.35
# It: 38780, Loss: 2.136e-02, Loss_bcs: 1.170e-02, Loss_ics: 6.046e-03, Loss_res: 1.243e-03, Time: 0.34
# It: 38790, Loss: 2.623e-02, Loss_bcs: 1.916e-02, Loss_ics: 2.649e-03, Loss_res: 1.991e-03, Time: 0.35
# It: 38800, Loss: 2.810e-02, Loss_bcs: 2.102e-02, Loss_ics: 2.812e-03, Loss_res: 1.758e-03, Time: 0.35
# It: 38810, Loss: 4.954e-02, Loss_bcs: 4.259e-02, Loss_ics: 3.509e-03, Loss_res: 1.261e-03, Time: 0.33
# It: 38820, Loss: 6.874e-02, Loss_bcs: 6.118e-02, Loss_ics: 3.449e-03, Loss_res: 1.492e-03, Time: 0.35
# It: 38830, Loss: 2.846e-02, Loss_bcs: 2.266e-02, Loss_ics: 2.363e-03, Loss_res: 1.058e-03, Time: 0.33
# It: 38840, Loss: 4.084e-02, Loss_bcs: 3.242e-02, Loss_ics: 4.983e-03, Loss_res: 9.743e-04, Time: 0.35
# It: 38850, Loss: 2.388e-02, Loss_bcs: 1.664e-02, Loss_ics: 3.754e-03, Loss_res: 1.370e-03, Time: 0.34
# It: 38860, Loss: 2.976e-02, Loss_bcs: 2.390e-02, Loss_ics: 2.774e-03, Loss_res: 8.333e-04, Time: 0.34
# It: 38870, Loss: 3.448e-02, Loss_bcs: 2.645e-02, Loss_ics: 2.034e-03, Loss_res: 3.466e-03, Time: 0.33
# It: 38880, Loss: 2.724e-02, Loss_bcs: 2.155e-02, Loss_ics: 2.292e-03, Loss_res: 1.143e-03, Time: 0.35
# It: 38890, Loss: 2.990e-02, Loss_bcs: 2.349e-02, Loss_ics: 3.111e-03, Loss_res: 9.989e-04, Time: 0.34
# It: 38900, Loss: 3.560e-02, Loss_bcs: 2.193e-02, Loss_ics: 2.723e-03, Loss_res: 8.247e-03, Time: 0.35
# It: 38910, Loss: 3.478e-02, Loss_bcs: 2.798e-02, Loss_ics: 3.182e-03, Loss_res: 1.620e-03, Time: 0.34
# It: 38920, Loss: 3.271e-02, Loss_bcs: 2.427e-02, Loss_ics: 5.004e-03, Loss_res: 1.109e-03, Time: 0.34
# It: 38930, Loss: 2.142e-02, Loss_bcs: 1.390e-02, Loss_ics: 4.315e-03, Loss_res: 1.245e-03, Time: 0.33
# It: 38940, Loss: 5.358e-02, Loss_bcs: 4.772e-02, Loss_ics: 2.237e-03, Loss_res: 1.477e-03, Time: 0.36
# It: 38950, Loss: 6.680e-02, Loss_bcs: 6.021e-02, Loss_ics: 2.524e-03, Loss_res: 1.507e-03, Time: 0.34
# It: 38960, Loss: 3.382e-02, Loss_bcs: 2.847e-02, Loss_ics: 2.428e-03, Loss_res: 7.160e-04, Time: 0.33
# It: 38970, Loss: 3.009e-02, Loss_bcs: 2.361e-02, Loss_ics: 3.386e-03, Loss_res: 8.183e-04, Time: 0.35
# It: 38980, Loss: 4.900e-02, Loss_bcs: 4.365e-02, Loss_ics: 2.076e-03, Loss_res: 1.287e-03, Time: 0.34
# It: 38990, Loss: 4.398e-02, Loss_bcs: 3.753e-02, Loss_ics: 3.241e-03, Loss_res: 7.686e-04, Time: 0.35
# It: 39000, Loss: 7.081e-02, Loss_bcs: 6.179e-02, Loss_ics: 5.572e-03, Loss_res: 1.001e-03, Time: 0.33
# It: 39010, Loss: 4.733e-02, Loss_bcs: 4.165e-02, Loss_ics: 2.184e-03, Loss_res: 1.396e-03, Time: 0.33
# It: 39020, Loss: 4.176e-02, Loss_bcs: 3.299e-02, Loss_ics: 4.700e-03, Loss_res: 1.558e-03, Time: 0.35
# It: 39030, Loss: 2.318e-02, Loss_bcs: 1.586e-02, Loss_ics: 2.481e-03, Loss_res: 2.755e-03, Time: 0.35
# It: 39040, Loss: 6.393e-02, Loss_bcs: 5.685e-02, Loss_ics: 3.949e-03, Loss_res: 7.262e-04, Time: 0.34
# It: 39050, Loss: 2.953e-02, Loss_bcs: 2.403e-02, Loss_ics: 2.142e-03, Loss_res: 1.100e-03, Time: 0.35
# It: 39060, Loss: 4.526e-02, Loss_bcs: 3.934e-02, Loss_ics: 2.401e-03, Loss_res: 9.307e-04, Time: 0.35
# It: 39070, Loss: 2.860e-02, Loss_bcs: 1.904e-02, Loss_ics: 5.656e-03, Loss_res: 1.559e-03, Time: 0.34
# It: 39080, Loss: 4.484e-02, Loss_bcs: 3.736e-02, Loss_ics: 3.210e-03, Loss_res: 1.603e-03, Time: 0.35
# It: 39090, Loss: 3.953e-02, Loss_bcs: 3.212e-02, Loss_ics: 3.360e-03, Loss_res: 1.754e-03, Time: 0.33
# It: 39100, Loss: 2.822e-02, Loss_bcs: 2.240e-02, Loss_ics: 2.515e-03, Loss_res: 7.875e-04, Time: 0.33
# It: 39110, Loss: 4.826e-02, Loss_bcs: 4.067e-02, Loss_ics: 3.684e-03, Loss_res: 1.892e-03, Time: 0.36
# It: 39120, Loss: 5.723e-02, Loss_bcs: 5.120e-02, Loss_ics: 2.394e-03, Loss_res: 1.508e-03, Time: 0.34
# It: 39130, Loss: 4.416e-02, Loss_bcs: 3.604e-02, Loss_ics: 3.887e-03, Loss_res: 1.449e-03, Time: 0.35
# It: 39140, Loss: 3.350e-02, Loss_bcs: 2.738e-02, Loss_ics: 2.408e-03, Loss_res: 1.261e-03, Time: 0.34
# It: 39150, Loss: 3.474e-02, Loss_bcs: 2.729e-02, Loss_ics: 4.535e-03, Loss_res: 6.137e-04, Time: 0.33
# It: 39160, Loss: 2.319e-02, Loss_bcs: 1.641e-02, Loss_ics: 3.537e-03, Loss_res: 8.364e-04, Time: 0.34
# It: 39170, Loss: 4.605e-02, Loss_bcs: 3.578e-02, Loss_ics: 3.738e-03, Loss_res: 4.454e-03, Time: 0.34
# It: 39180, Loss: 3.120e-02, Loss_bcs: 2.207e-02, Loss_ics: 4.797e-03, Loss_res: 2.017e-03, Time: 0.34
# It: 39190, Loss: 4.434e-02, Loss_bcs: 3.849e-02, Loss_ics: 2.612e-03, Loss_res: 6.532e-04, Time: 0.36
# It: 39200, Loss: 5.589e-02, Loss_bcs: 4.902e-02, Loss_ics: 3.127e-03, Loss_res: 1.279e-03, Time: 0.34
# It: 39210, Loss: 3.435e-02, Loss_bcs: 2.671e-02, Loss_ics: 3.696e-03, Loss_res: 1.388e-03, Time: 0.33
# It: 39220, Loss: 4.616e-02, Loss_bcs: 3.916e-02, Loss_ics: 3.619e-03, Loss_res: 9.813e-04, Time: 0.36
# It: 39230, Loss: 1.945e-02, Loss_bcs: 1.421e-02, Loss_ics: 1.835e-03, Loss_res: 1.132e-03, Time: 0.35
# It: 39240, Loss: 3.876e-02, Loss_bcs: 3.019e-02, Loss_ics: 2.937e-03, Loss_res: 3.091e-03, Time: 0.33
# It: 39250, Loss: 1.604e-02, Loss_bcs: 1.035e-02, Loss_ics: 1.648e-03, Loss_res: 1.617e-03, Time: 0.34
# It: 39260, Loss: 3.637e-02, Loss_bcs: 2.995e-02, Loss_ics: 3.022e-03, Loss_res: 1.276e-03, Time: 0.33
# It: 39270, Loss: 2.303e-02, Loss_bcs: 1.538e-02, Loss_ics: 3.771e-03, Loss_res: 1.973e-03, Time: 0.33
# It: 39280, Loss: 4.304e-02, Loss_bcs: 3.579e-02, Loss_ics: 3.568e-03, Loss_res: 1.527e-03, Time: 0.35
# It: 39290, Loss: 3.487e-02, Loss_bcs: 2.903e-02, Loss_ics: 1.999e-03, Loss_res: 1.333e-03, Time: 0.33
# It: 39300, Loss: 2.705e-02, Loss_bcs: 1.999e-02, Loss_ics: 3.229e-03, Loss_res: 1.516e-03, Time: 0.34
# It: 39310, Loss: 3.220e-02, Loss_bcs: 2.661e-02, Loss_ics: 1.884e-03, Loss_res: 1.523e-03, Time: 0.36
# It: 39320, Loss: 4.731e-02, Loss_bcs: 4.160e-02, Loss_ics: 1.969e-03, Loss_res: 1.424e-03, Time: 0.32
# It: 39330, Loss: 2.670e-02, Loss_bcs: 1.959e-02, Loss_ics: 2.396e-03, Loss_res: 2.402e-03, Time: 0.35
# It: 39340, Loss: 3.846e-02, Loss_bcs: 3.313e-02, Loss_ics: 2.159e-03, Loss_res: 1.121e-03, Time: 0.34
# It: 39350, Loss: 3.262e-02, Loss_bcs: 2.308e-02, Loss_ics: 2.811e-03, Loss_res: 4.276e-03, Time: 0.33
# It: 39360, Loss: 3.782e-02, Loss_bcs: 2.972e-02, Loss_ics: 4.107e-03, Loss_res: 1.662e-03, Time: 0.35
# It: 39370, Loss: 3.335e-02, Loss_bcs: 2.754e-02, Loss_ics: 1.939e-03, Loss_res: 1.561e-03, Time: 0.33
# It: 39380, Loss: 3.226e-02, Loss_bcs: 2.277e-02, Loss_ics: 3.440e-03, Loss_res: 3.585e-03, Time: 0.33
# It: 39390, Loss: 3.540e-02, Loss_bcs: 2.887e-02, Loss_ics: 3.239e-03, Loss_res: 9.791e-04, Time: 0.35
# It: 39400, Loss: 3.474e-02, Loss_bcs: 2.840e-02, Loss_ics: 2.081e-03, Loss_res: 2.055e-03, Time: 0.33
# It: 39410, Loss: 2.844e-02, Loss_bcs: 2.033e-02, Loss_ics: 4.002e-03, Loss_res: 2.092e-03, Time: 0.35
# It: 39420, Loss: 3.283e-02, Loss_bcs: 2.793e-02, Loss_ics: 1.434e-03, Loss_res: 1.356e-03, Time: 0.34
# It: 39430, Loss: 3.788e-02, Loss_bcs: 3.076e-02, Loss_ics: 3.659e-03, Loss_res: 1.223e-03, Time: 0.32
# It: 39440, Loss: 7.164e-02, Loss_bcs: 6.418e-02, Loss_ics: 4.278e-03, Loss_res: 1.238e-03, Time: 0.32
# It: 39450, Loss: 2.932e-02, Loss_bcs: 2.271e-02, Loss_ics: 2.731e-03, Loss_res: 1.666e-03, Time: 0.34
# It: 39460, Loss: 2.924e-02, Loss_bcs: 2.302e-02, Loss_ics: 3.034e-03, Loss_res: 7.137e-04, Time: 0.35
# It: 39470, Loss: 4.154e-02, Loss_bcs: 3.364e-02, Loss_ics: 3.744e-03, Loss_res: 1.894e-03, Time: 0.34
# It: 39480, Loss: 3.641e-02, Loss_bcs: 2.972e-02, Loss_ics: 2.784e-03, Loss_res: 1.616e-03, Time: 0.35
# It: 39490, Loss: 4.844e-02, Loss_bcs: 4.048e-02, Loss_ics: 4.734e-03, Loss_res: 8.566e-04, Time: 0.33
# It: 39500, Loss: 3.608e-02, Loss_bcs: 2.964e-02, Loss_ics: 2.740e-03, Loss_res: 1.337e-03, Time: 0.32
# It: 39510, Loss: 3.485e-02, Loss_bcs: 2.636e-02, Loss_ics: 3.689e-03, Loss_res: 2.624e-03, Time: 0.34
# It: 39520, Loss: 6.162e-02, Loss_bcs: 5.641e-02, Loss_ics: 1.736e-03, Loss_res: 1.258e-03, Time: 0.33
# It: 39530, Loss: 2.722e-02, Loss_bcs: 2.145e-02, Loss_ics: 2.022e-03, Loss_res: 1.119e-03, Time: 0.34
# It: 39540, Loss: 4.146e-02, Loss_bcs: 3.243e-02, Loss_ics: 5.211e-03, Loss_res: 1.340e-03, Time: 0.32
# It: 39550, Loss: 4.801e-02, Loss_bcs: 3.669e-02, Loss_ics: 7.140e-03, Loss_res: 1.539e-03, Time: 0.33
# It: 39560, Loss: 3.888e-02, Loss_bcs: 3.197e-02, Loss_ics: 3.819e-03, Loss_res: 9.815e-04, Time: 0.34
# It: 39570, Loss: 3.715e-02, Loss_bcs: 3.007e-02, Loss_ics: 2.667e-03, Loss_res: 1.674e-03, Time: 0.33
# It: 39580, Loss: 3.857e-02, Loss_bcs: 3.183e-02, Loss_ics: 3.549e-03, Loss_res: 9.755e-04, Time: 0.34
# It: 39590, Loss: 4.227e-02, Loss_bcs: 3.636e-02, Loss_ics: 2.683e-03, Loss_res: 1.023e-03, Time: 0.34
# It: 39600, Loss: 4.026e-02, Loss_bcs: 3.443e-02, Loss_ics: 2.027e-03, Loss_res: 1.292e-03, Time: 0.35
# It: 39610, Loss: 2.365e-02, Loss_bcs: 1.606e-02, Loss_ics: 4.439e-03, Loss_res: 8.070e-04, Time: 0.32
# It: 39620, Loss: 3.732e-02, Loss_bcs: 3.028e-02, Loss_ics: 2.245e-03, Loss_res: 2.558e-03, Time: 0.34
# It: 39630, Loss: 4.971e-02, Loss_bcs: 4.242e-02, Loss_ics: 3.894e-03, Loss_res: 8.914e-04, Time: 0.34
# It: 39640, Loss: 2.151e-02, Loss_bcs: 1.607e-02, Loss_ics: 2.499e-03, Loss_res: 8.448e-04, Time: 0.36
# It: 39650, Loss: 5.343e-02, Loss_bcs: 4.711e-02, Loss_ics: 2.878e-03, Loss_res: 1.130e-03, Time: 0.36
# It: 39660, Loss: 1.757e-02, Loss_bcs: 9.965e-03, Loss_ics: 4.293e-03, Loss_res: 1.101e-03, Time: 0.35
# It: 39670, Loss: 3.633e-02, Loss_bcs: 3.011e-02, Loss_ics: 2.410e-03, Loss_res: 1.343e-03, Time: 0.33
# It: 39680, Loss: 3.252e-02, Loss_bcs: 2.285e-02, Loss_ics: 6.602e-03, Loss_res: 7.765e-04, Time: 0.35
# It: 39690, Loss: 3.463e-02, Loss_bcs: 2.626e-02, Loss_ics: 3.879e-03, Loss_res: 2.084e-03, Time: 0.35
# It: 39700, Loss: 2.547e-02, Loss_bcs: 1.777e-02, Loss_ics: 3.212e-03, Loss_res: 2.101e-03, Time: 0.33
# It: 39710, Loss: 2.823e-02, Loss_bcs: 2.062e-02, Loss_ics: 2.240e-03, Loss_res: 2.948e-03, Time: 0.34
# It: 39720, Loss: 4.320e-02, Loss_bcs: 3.512e-02, Loss_ics: 4.389e-03, Loss_res: 1.289e-03, Time: 0.34
# It: 39730, Loss: 4.293e-02, Loss_bcs: 3.628e-02, Loss_ics: 3.106e-03, Loss_res: 1.251e-03, Time: 0.34
# It: 39740, Loss: 3.008e-02, Loss_bcs: 2.235e-02, Loss_ics: 4.087e-03, Loss_res: 1.537e-03, Time: 0.35
# It: 39750, Loss: 5.734e-02, Loss_bcs: 4.865e-02, Loss_ics: 3.265e-03, Loss_res: 2.736e-03, Time: 0.33
# It: 39760, Loss: 4.713e-02, Loss_bcs: 4.133e-02, Loss_ics: 2.449e-03, Loss_res: 1.070e-03, Time: 0.35
# It: 39770, Loss: 4.857e-02, Loss_bcs: 4.213e-02, Loss_ics: 2.600e-03, Loss_res: 1.714e-03, Time: 0.32
# It: 39780, Loss: 4.295e-02, Loss_bcs: 3.572e-02, Loss_ics: 3.679e-03, Loss_res: 1.548e-03, Time: 0.34
# It: 39790, Loss: 4.402e-02, Loss_bcs: 3.694e-02, Loss_ics: 3.112e-03, Loss_res: 1.624e-03, Time: 0.33
# It: 39800, Loss: 4.640e-02, Loss_bcs: 3.865e-02, Loss_ics: 3.955e-03, Loss_res: 1.365e-03, Time: 0.33
# It: 39810, Loss: 4.141e-02, Loss_bcs: 3.187e-02, Loss_ics: 5.372e-03, Loss_res: 1.404e-03, Time: 0.35
# It: 39820, Loss: 3.641e-02, Loss_bcs: 3.038e-02, Loss_ics: 1.964e-03, Loss_res: 1.290e-03, Time: 0.35
# It: 39830, Loss: 4.070e-02, Loss_bcs: 3.249e-02, Loss_ics: 3.365e-03, Loss_res: 2.033e-03, Time: 0.35
# It: 39840, Loss: 5.994e-02, Loss_bcs: 5.232e-02, Loss_ics: 4.871e-03, Loss_res: 7.128e-04, Time: 0.32
# It: 39850, Loss: 3.509e-02, Loss_bcs: 2.832e-02, Loss_ics: 2.656e-03, Loss_res: 1.378e-03, Time: 0.35
# It: 39860, Loss: 4.908e-02, Loss_bcs: 4.022e-02, Loss_ics: 4.258e-03, Loss_res: 2.366e-03, Time: 0.35
# It: 39870, Loss: 3.844e-02, Loss_bcs: 3.278e-02, Loss_ics: 1.834e-03, Loss_res: 1.717e-03, Time: 0.33
# It: 39880, Loss: 4.113e-02, Loss_bcs: 3.226e-02, Loss_ics: 4.787e-03, Loss_res: 1.955e-03, Time: 0.35
# It: 39890, Loss: 3.724e-02, Loss_bcs: 3.093e-02, Loss_ics: 3.299e-03, Loss_res: 8.259e-04, Time: 0.34
# It: 39900, Loss: 4.800e-02, Loss_bcs: 3.961e-02, Loss_ics: 3.574e-03, Loss_res: 2.517e-03, Time: 0.33
# It: 39910, Loss: 5.881e-02, Loss_bcs: 5.209e-02, Loss_ics: 3.392e-03, Loss_res: 9.465e-04, Time: 0.34
# It: 39920, Loss: 4.375e-02, Loss_bcs: 3.459e-02, Loss_ics: 6.420e-03, Loss_res: 8.958e-04, Time: 0.35
# It: 39930, Loss: 3.866e-02, Loss_bcs: 3.201e-02, Loss_ics: 3.429e-03, Loss_res: 8.647e-04, Time: 0.34
# It: 39940, Loss: 5.260e-02, Loss_bcs: 4.672e-02, Loss_ics: 2.770e-03, Loss_res: 6.258e-04, Time: 0.34
# It: 39950, Loss: 2.283e-02, Loss_bcs: 1.620e-02, Loss_ics: 3.290e-03, Loss_res: 7.114e-04, Time: 0.34
# It: 39960, Loss: 3.722e-02, Loss_bcs: 2.970e-02, Loss_ics: 4.181e-03, Loss_res: 1.158e-03, Time: 0.34
# It: 39970, Loss: 2.505e-02, Loss_bcs: 1.986e-02, Loss_ics: 2.189e-03, Loss_res: 8.692e-04, Time: 0.33
# It: 39980, Loss: 3.187e-02, Loss_bcs: 2.311e-02, Loss_ics: 5.240e-03, Loss_res: 1.306e-03, Time: 0.34
# It: 39990, Loss: 1.865e-02, Loss_bcs: 1.144e-02, Loss_ics: 3.846e-03, Loss_res: 1.460e-03, Time: 0.36
# The relative errror is: 1.468068e-01

# %%
щгеerror_s_list = model.error_s_list
its = range(10, 10*len(error_s_list)+10, 10)
fig = plt.figure(figsize=(8, 5))
plt.plot(its, error_s_list)
plt.xlabel(r'iterations')
plt.ylabel(r'relative $s$ error')

with open('/content/drive/My Drive/Diploma/Test_2/error_s.pdf'.format(T), 'w') as f:
    pass
plt.savefig('/content/drive/My Drive/Diploma/Test_2/error_s.pdf'.format(T), dpi=200)

fig = plt.figure(figsize=(8, 5))
error_u_list = model.error_u_list
its = range(10, 10*len(error_u_list)+10, 10)
plt.plot(its, error_u_list)
plt.xlabel(r'iterations')
plt.ylabel(r'relative $u$ error')

with open('/content/drive/My Drive/Diploma/Test_2/error_u.pdf'.format(T), 'w') as f:
    pass
plt.savefig('/content/drive/My Drive/Diploma/Test_2/error_u.pdf'.format(T), dpi=200)

# %%
min(error_s_list)
# Out:
# 0.009808215230368135

# %%
  model.error_s_list[-1]
# Out:
# 0.01428449711109399

# %%
model.error_u_list[-1]
# Out:
# 0.01057705337893866

# %%
from matplotlib.animation import FuncAnimation
from IPython.display import HTML
font = {'size' : 10}

matplotlib.rc('font', **font)

fig = plt.figure(figsize=(18, 5))

from mpl_toolkits.axes_grid1 import make_axes_locatable

ax1 = plt.subplot(1,3,1)   
ax2 = plt.subplot(1, 3, 2)
ax3 = plt.subplot(1, 3, 3)



txt_title_1 = ax1.set_title('')
ax1.set_xlabel(r'$x$')
ax1.set_ylabel(r'$y$')

txt_title_2 = ax2.set_title('')
ax2.set_xlabel(r'$x$')
ax2.set_ylabel(r'$y$')

txt_title_3 = ax3.set_title('')
ax3.set_xlabel(r'$x$')
ax3.set_ylabel(r'$y$')

x = np.linspace(0, 3, 200)[:, None]
y = np.linspace(dom_coords[0, 1], dom_coords[1, 1], 200)[:, None]
t = np.linspace(dom_coords[0, 2], dom_coords[1, 2], 100)[:, None]

X, Y = np.meshgrid(x, y)
T_star = 0 * np.ones_like(X)
X_star = np.hstack((X.flatten()[:, None], Y.flatten()[:, None], T_star.flatten()[:, None]))

u_star = u(X_star)
u_pred = model.predict_u(X_star)

X_star = np.hstack((X.flatten()[:, None], Y.flatten()[:, None]))

U_star = griddata(X_star, u_star.flatten(), (X, Y), method='cubic')
U_pred = griddata(X_star, u_pred.flatten(), (X, Y), method='cubic')

            
pcol_plot1 = ax1.pcolormesh(X, Y, U_star, cmap='jet', vmin=-2, vmax=7)
divider = make_axes_locatable(ax1)
cax1 = divider.append_axes('right', size='5%', pad=0.1)
plt.colorbar(pcol_plot1, cax=cax1)

pcol_plot2 = ax2.pcolormesh(X, Y, U_pred, cmap='jet', vmin=-2, vmax=7)
divider = make_axes_locatable(ax2)
cax2 = divider.append_axes('right', size='5%', pad=0.1)
plt.colorbar(pcol_plot2, cax=cax2)

pcol_plot3 = ax3.pcolormesh(X, Y, np.abs(U_star - U_pred), cmap='jet', vmin=0.005, vmax=0.07)
divider = make_axes_locatable(ax3)
cax3 = divider.append_axes('right', size='5%', pad=0.1)
plt.colorbar(pcol_plot3, cax=cax3, format='%.0e')

def animate(T):

  T = T[0]


  X, Y = np.meshgrid(x, y)
  T_star = T * np.ones_like(X)
  X_star = np.hstack((X.flatten()[:, None], Y.flatten()[:, None], T_star.flatten()[:, None]))
  
  u_star = u(X_star)
  u_pred = model.predict_u(X_star)
  
  X_star = np.hstack((X.flatten()[:, None], Y.flatten()[:, None]))
  
  U_star = griddata(X_star, u_star.flatten(), (X, Y), method='cubic')
  U_pred = griddata(X_star, u_pred.flatten(), (X, Y), method='cubic')


  ax1.clear()
  ax2.clear()
  ax3.clear()

  ytemp = np.linspace(dom_coords[0, 1], dom_coords[1, 1], nn)[:, None]
  t = T * np.ones_like(ytemp)
  ytemp, t = np.meshgrid(ytemp, t)

  
  X_star = np.hstack((ytemp.flatten()[:, None], t.flatten()[:, None]))
  
  s_star = s(X_star)

  pcol_plot1 = ax1.pcolormesh(X, Y, U_star, cmap='jet', vmin=-2, vmax=7)
  ax1.plot(s_star, ytemp.flatten(), color='black', linewidth=2)

  pcol_plot2 = ax2.pcolormesh(X, Y, U_pred, cmap='jet', vmin=-2, vmax=7)
  ax2.plot(s_star, ytemp.flatten(), color='black', linewidth=2)

  pcol_plot3 = ax3.pcolormesh(X, Y, np.abs(U_star - U_pred), cmap='jet', vmin=0.005, vmax=0.07)

  ax1.set_title('Exact $u(x, y, {})$'.format(np.round(T, 2)))
  ax2.set_title('Predicted  $u(x, y, {})$'.format(np.round(T, 2)))
  ax3.set_title('Absolute Error')


anim = FuncAnimation(fig, animate, frames=t, repeat=False, interval=20)
HTML(anim.to_html5_video())
# Out:
# <video width="1296" height="360" controls autoplay>
#   <source type="video/mp4" src="...

# %%
np.exp(1 + 2.5 * 0.5 - 2 * 2.25) - 1
# Out:
# -0.8946007754381357
